# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# *Fill in your overview here*

# %% [markdown]
# # Name & PID
#
# - Name: WEIYUAN XU
# - PID: U08448717

# %% [markdown]
# # Research Question

# %% [markdown]
# What is the relationship between the restaurant's violations and restaurant's yelp ratings and ecomonic development in a specific place?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# *Fill in your background and prior work here*
#
# References (include links):
# - 1)
# - 2)

# %% [markdown]
# # Hypothesis

# %% [markdown]
# *My hypothesis is that if the restaurants open earlier, then it may have more violation. So we must consider the time.*
# *Besides, we should see the corraltion of the rating and the violations*

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name:
# - Link to the dataset:
# - Number of observations:
#
# 1-2 sentences describing each dataset.
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# # Setup

# %%
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Firstly, we should have a basic idea about our data. I will see the datasets in the following cells

# %%
inspections_data = pd.read_csv('inspections.csv')
print(inspections_data.columns)
inspections_data.head()
# Out:
# Index(['hsisid', 'date', 'name', 'address1', 'address2', 'city', 'state',
#        'postalcode', 'phonenumber', 'restaurantopendate',
#        'days_from_open_date', 'facilitytype', 'x', 'y', 'geocodestatus', 'zip',
#        'type', 'description', 'inspectedby', 'inspection_num', 'inspector_id',
#        'previous_inspection_date', 'days_since_previous_inspection',
#        'previous_inspection_by_same_inspector', 'score', 'num_critical',
#        'num_non_critical', 'num_critical_previous',
#        'num_non_critical_previous', 'num_critical_mean_previous',
#        'num_non_critical_mean_previous', 'avg_neighbor_num_critical',
#        'avg_neighbor_num_non_critical', 'top_match', 'second_match',
#        'critical'],
#       dtype='object')
#        hsisid                  date                                      name  \
# 0  4092013748  2012-09-21T00:00:00Z                     Cafe 3000 At Wake Med
# 1  4092014046  2012-09-21T00:00:00Z                       Overtime Sports Pub
# 2  4092015191  2012-09-21T00:00:00Z                            TASTE OF CHINA
# 3  4092016122  2012-09-21T00:00:00Z                        Panera Bread #1643
# 4  4092021513  2012-09-21T00:00:00Z  WalMart Supercenter #4499-00 Deli/Bakery
#
#                address1 address2     city state postalcode  \
# 0     3000 New Bern Ave      NaN  raleigh    NC      27610
# 1  1030-149 N Rogers Ln      NaN  raleigh    NC      27610
# 2   6209 ROCK QUARRY RD  STE 126  raleigh    NC      27610
# 3    1065 Darrington DR      NaN     cary    NC      27513
# 4      841 E Gannon AVE      NaN  zebulon    NC      27597
#
#                phonenumber    restaurantopendate  ...  num_non_critical  \
# 0           (919) 350-8047  2002-12-21T00:00:00Z  ...                 7
# 1           (919) 255-9556  2004-05-04T00:00:00Z  ...                11
# 2           (919) 773-2285  2008-08-04T00:00:00Z  ...                 8
# 3                      NaN  2012-03-28T00:00:00Z  ...                 3
# 4  (919) 269-2221 ext. 304  2008-02-25T00:00:00Z  ...                 4
#
#   num_critical_previous  num_non_critical_previous  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
#
#    num_critical_mean_previous num_non_critical_mean_previous  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    avg_neighbor_num_critical avg_neighbor_num_non_critical top_match  \
# 0                        NaN                           NaN       NaN
# 1                        NaN                           NaN       NaN
# 2                        NaN                           NaN       NaN
# 3                        NaN                           NaN       NaN
# 4                        NaN                           NaN       NaN
#
#   second_match  critical
# 0          NaN         1
# 1          NaN         0
# 2          NaN         1
# 3          NaN         1
# 4          NaN         1
#
# [5 rows x 36 columns]

# %%
restaurants_data = pd.read_csv('restaurants.csv')
print(restaurants_data.columns)
restaurants_data.head()
# Out:
# Index(['X.objectid', 'hsisid', 'name', 'address1', 'address2', 'city', 'state',
#        'postalcode', 'phonenumber', 'restaurantopendate', 'facilitytype', 'x',
#        'y', 'geocodestatus'],
#       dtype='object')
#    X.objectid      hsisid                                      name  \
# 0        1001  4092017230                             SPRING CAFE 2
# 1        1002  4092040338  CAROLINA CLASSIC HOT DOGS #2 (WCID #549)
# 2        1003  4092014444                          Taco Bell #22798
# 3        1004  4092015333                          THE REMEDY DINER
# 4        1005  4092160069                   ZEBULON HOUSE (KITCHEN)
#
#                      address1 address2         city state  postalcode  \
# 0  2900-104 SPRING FOREST RD       NaN      RALEIGH    NC  27616-1895
# 1            309 HOLLOMAN ST       NaN         APEX    NC       27502
# 2             2207 S MAIN ST       NaN  WAKE FOREST    NC       27587
# 3           137 E HARGETT ST       NaN      RALEIGH    NC       27601
# 4                551 PONY RD       NaN      ZEBULON    NC       27597
#
#       phonenumber        restaurantopendate                facilitytype  \
# 0  (919) 977-3679  2016-05-26T00:00:00.000Z                  Restaurant
# 1             NaN  2016-07-01T00:00:00.000Z                   Pushcarts
# 2  (919) 554-4924  2005-12-05T00:00:00.000Z                  Restaurant
# 3  (919) 835-3553  2009-02-04T00:00:00.000Z                  Restaurant
# 4             NaN  2009-02-18T00:00:00.000Z  Institutional Food Service
#
#            x          y geocodestatus
# 0 -78.591634  35.855487             M
# 1 -78.855348  35.730219             M
# 2 -78.536145  35.946695             M
# 3 -78.636895  35.777999             M
# 4 -78.332138  35.816779             M

# %%
violations_data = pd.read_csv('violations.csv')
print(violations_data.columns)
violations_data.head()
# Out:
# Index(['X.objectid', 'hsisid', 'inspectdate', 'category', 'statecode',
#        'critical', 'questionno', 'violationcode', 'severity', 'shortdesc',
#        'inspectedby', 'comments', 'pointvalue', 'observationtype',
#        'violationtype', 'count', 'cdcriskfactor', 'cdcdataitem'],
#       dtype='object')
#    X.objectid      hsisid               inspectdate  category    statecode  \
# 0        2149  4092015279  2014-09-22T00:00:00.000Z  Chemical  .2653,.2657
# 1        2150  4092014572  2014-09-29T00:00:00.000Z  Chemical  .2653,.2657
# 2        2151  4092015906  2014-10-01T00:00:00.000Z  Chemical  .2653,.2657
# 3        2152  4092013840  2014-10-08T00:00:00.000Z  Chemical  .2653,.2657
# 4        2153  4092021788  2014-10-09T00:00:00.000Z  Chemical  .2653,.2657
#
#   critical  questionno violationcode             severity  \
# 0      Yes          26      7-102.11  Priority Foundation
# 1      Yes          26      7-102.11  Priority Foundation
# 2      Yes          26      7-102.11  Priority Foundation
# 3      Yes          26      7-102.11  Priority Foundation
# 4      Yes          26      7-102.11  Priority Foundation
#
#                                            shortdesc    inspectedby  \
# 0  Toxic substances properly identified, stored, ...    Lucy Schrum
# 1  Toxic substances properly identified, stored, ...  Daryl Beasley
# 2  Toxic substances properly identified, stored, ...    Lucy Schrum
# 3  Toxic substances properly identified, stored, ...    Lucy Schrum
# 4  Toxic substances properly identified, stored, ...    Lucy Schrum
#
#                                             comments  pointvalue  \
# 0  7-102.11; Priority Foundation - Found unlabele...           0
# 1  7-102.11; Priority Foundation; One sanitizer b...           0
# 2  7-102.11; Priority Foundation - Found an unlab...           1
# 3  7-102.11; Priority Foundation - Found unlabele...           0
# 4  7-102.11; Priority Foundation - Found one unla...           0
#
#   observationtype violationtype  count cdcriskfactor cdcdataitem
# 0             Out             R    NaN           NaN         NaN
# 1             Out           CDI    NaN           NaN         NaN
# 2             Out           CDI    NaN           NaN         NaN
# 3             Out           CDI    NaN           NaN         NaN
# 4             Out           CDI    NaN           NaN         NaN

# %%
yelp_data = pd.read_csv('yelp.csv')
print(yelp_data.columns)
yelp_data.head()
# Out:
# Index(['id', 'name', 'is_closed', 'rating', 'review_count', 'address1',
#        'zip_code', 'latitude', 'longitude', 'price', 'phone', 'hotdogs',
#        'sandwiches', 'pizza', 'tradamerican', 'burgers', 'mexican', 'grocery',
#        'breakfast_brunch', 'coffee', 'chinese', 'italian', 'newamerican',
#        'chicken_wings', 'delis', 'bars', 'salad', 'seafood', 'bbq', 'bakeries',
#        'sushi'],
#       dtype='object')
#                                                id  \
# 0  42nd-street-oyster-bar-rdu-airport-morrisville
# 1                                 aldi-foods-cary
# 2   luciano-pizzeria-ristorante-northwest-raleigh
# 3          olive-garden-italian-restaurant-wilson
# 4                                 subway-wilson-4
#
#                                    name  is_closed  rating  review_count  \
# 0  42nd street oyster bar - rdu airport      False     2.5            23
# 1                            aldi foods      False     4.0            17
# 2           luciano pizzeria ristorante      False     5.0             2
# 3       olive garden italian restaurant      False     3.0            16
# 4                                subway      False     3.5             3
#
#                   address1  zip_code   latitude  longitude price  ... italian  \
# 0  2400 John Brantley Blvd     27560  35.873808 -78.790896    $$  ...   False
# 1       2303 NW Maynard Rd     27519  35.802840 -78.785930     $  ...   False
# 2     Crabtree Valley Mall     27612  35.839681 -78.678791     $  ...    True
# 3   3401 Raleigh Rd Pkwy W     27893  35.743170 -77.964160    $$  ...    True
# 4          4934 Raleigh Rd     27896  35.762936 -77.999428     $  ...   False
#
#    newamerican  chicken_wings  delis   bars  salad  seafood    bbq  bakeries  \
# 0         True          False  False  False  False     True  False     False
# 1        False          False  False  False  False    False  False     False
# 2        False          False  False  False  False    False  False     False
# 3        False          False  False  False   True    False  False     False
# 4        False          False  False  False  False    False  False     False
#
#    sushi
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 31 columns]

# %%
zipcodes_data = pd.read_csv('zipcodes.csv')
zipcodes_data.head()
# Out:
#      zip  median_family_income_dollars  median_household_income_dollars  \
# 0  27501                         59408                            51121
# 1  27502                        109891                            95857
# 2  27511                         82292                            67392
# 3  27513                        109736                            87262
# 4  27518                        125432                            98247
#
#    per_capita_income_dollars  percent_damilies_below_poverty_line  \
# 0                      21631                                 10.5
# 1                      36763                                  3.4
# 2                      33139                                  9.6
# 3                      41232                                  3.8
# 4                      49865                                  5.5
#
#    percent_snap_benefits  percent_supplemental_security_income  \
# 0                   15.5                                   5.2
# 1                    2.4                                   0.8
# 2                    4.5                                   2.2
# 3                    2.4                                   1.5
# 4                    1.0                                   1.7
#
#    percent_nonwhite
# 0              17.9
# 1              18.9
# 2              24.8
# 3              27.8
# 4              19.9

# %% [markdown]
# Then we only find the columns we need in the dataset to analysis them and verify our hypothesis

# %%
new_yelp_data = yelp_data.drop(['is_closed', 'latitude', 'latitude', 'longitude', 'price', 'phone', 'hotdogs',
       'sandwiches', 'pizza', 'tradamerican', 'burgers', 'mexican', 'grocery',
       'breakfast_brunch', 'coffee', 'chinese', 'italian', 'newamerican',
       'chicken_wings', 'delis', 'bars', 'salad', 'seafood', 'bbq', 'bakeries',
       'sushi'], axis = 1)

# %%
new_yelp_data.head()
# Out:
#                                                id  \
# 0  42nd-street-oyster-bar-rdu-airport-morrisville
# 1                                 aldi-foods-cary
# 2   luciano-pizzeria-ristorante-northwest-raleigh
# 3          olive-garden-italian-restaurant-wilson
# 4                                 subway-wilson-4
#
#                                    name  rating  review_count  \
# 0  42nd street oyster bar - rdu airport     2.5            23
# 1                            aldi foods     4.0            17
# 2           luciano pizzeria ristorante     5.0             2
# 3       olive garden italian restaurant     3.0            16
# 4                                subway     3.5             3
#
#                   address1  zip_code
# 0  2400 John Brantley Blvd     27560
# 1       2303 NW Maynard Rd     27519
# 2     Crabtree Valley Mall     27612
# 3   3401 Raleigh Rd Pkwy W     27893
# 4          4934 Raleigh Rd     27896

# %%
new_inspections_data = inspections_data.drop(['address2', 'city', 'state',
       'phonenumber', 'restaurantopendate',
       'days_from_open_date', 'facilitytype', 'x', 'y', 'geocodestatus',
       'type', 'description', 'inspectedby', 'inspection_num', 'inspector_id',
       'previous_inspection_date', 'days_since_previous_inspection',
       'previous_inspection_by_same_inspector', 'score', 'num_critical',
       'num_non_critical', 'num_critical_previous',
       'num_non_critical_previous', 'num_critical_mean_previous',
       'num_non_critical_mean_previous', 'avg_neighbor_num_critical',
       'avg_neighbor_num_non_critical', 'top_match', 'second_match',
       'critical'],
      axis = 1 )
new_inspections_data.head()
# Out:
#        hsisid                  date                                      name  \
# 0  4092013748  2012-09-21T00:00:00Z                     Cafe 3000 At Wake Med
# 1  4092014046  2012-09-21T00:00:00Z                       Overtime Sports Pub
# 2  4092015191  2012-09-21T00:00:00Z                            TASTE OF CHINA
# 3  4092016122  2012-09-21T00:00:00Z                        Panera Bread #1643
# 4  4092021513  2012-09-21T00:00:00Z  WalMart Supercenter #4499-00 Deli/Bakery
#
#                address1 postalcode    zip
# 0     3000 New Bern Ave      27610  27610
# 1  1030-149 N Rogers Ln      27610  27610
# 2   6209 ROCK QUARRY RD      27610  27610
# 3    1065 Darrington DR      27513  27513
# 4      841 E Gannon AVE      27597  27597

# %%
new_violations_data = violations_data.drop(['category', 'statecode',
       'critical', 'questionno', 'violationcode', 'severity', 'shortdesc',
       'inspectedby', 'comments', 'pointvalue', 'observationtype',
       'violationtype', 'count', 'cdcriskfactor', 'cdcdataitem'], axis = 1)
print(len(new_violations_data['hsisid'].unique()))
new_violations_data.head()
# Out:
# 4270
#    X.objectid      hsisid               inspectdate
# 0        2149  4092015279  2014-09-22T00:00:00.000Z
# 1        2150  4092014572  2014-09-29T00:00:00.000Z
# 2        2151  4092015906  2014-10-01T00:00:00.000Z
# 3        2152  4092013840  2014-10-08T00:00:00.000Z
# 4        2153  4092021788  2014-10-09T00:00:00.000Z

# %%
new_restaurants_data = restaurants_data.drop(['address2', 'city', 'state',
        'phonenumber', 'restaurantopendate', 'facilitytype', 'x',
       'y', 'geocodestatus'], axis = 1)
new_restaurants_data.head()
# Out:
#    X.objectid      hsisid                                      name  \
# 0        1001  4092017230                             SPRING CAFE 2
# 1        1002  4092040338  CAROLINA CLASSIC HOT DOGS #2 (WCID #549)
# 2        1003  4092014444                          Taco Bell #22798
# 3        1004  4092015333                          THE REMEDY DINER
# 4        1005  4092160069                   ZEBULON HOUSE (KITCHEN)
#
#                      address1  postalcode
# 0  2900-104 SPRING FOREST RD   27616-1895
# 1            309 HOLLOMAN ST        27502
# 2             2207 S MAIN ST        27587
# 3           137 E HARGETT ST        27601
# 4                551 PONY RD        27597

# %% [markdown]
# After we drop some columns that are not useful for our analysis, we could combine the dataset what we need.
#
# Then we combine the restaurant data, yelp data and violation data together

# %%
my_health_data = pd.merge(new_restaurants_data, new_violations_data, on = ["hsisid"])
print(len(my_health_data['hsisid'].unique()))
my_health_data.head()
# Out:
# 3199
#    X.objectid_x      hsisid           name                    address1  \
# 0          1001  4092017230  SPRING CAFE 2  2900-104 SPRING FOREST RD
# 1          1001  4092017230  SPRING CAFE 2  2900-104 SPRING FOREST RD
# 2          1001  4092017230  SPRING CAFE 2  2900-104 SPRING FOREST RD
# 3          1001  4092017230  SPRING CAFE 2  2900-104 SPRING FOREST RD
# 4          1001  4092017230  SPRING CAFE 2  2900-104 SPRING FOREST RD
#
#    postalcode  X.objectid_y               inspectdate
# 0  27616-1895          6992  2016-10-12T00:00:00.000Z
# 1  27616-1895          7791  2016-09-13T00:00:00.000Z
# 2  27616-1895          7801  2016-10-12T00:00:00.000Z
# 3  27616-1895         10429  2016-09-13T00:00:00.000Z
# 4  27616-1895         15176  2016-09-13T00:00:00.000Z

# %%
my_health_and_rating_data = pd.merge(my_health_data, new_yelp_data, on = ['address1'])
my_health_and_rating_data.head()
# Out:
#    X.objectid_x      hsisid             name_x           address1 postalcode  \
# 0          1028  4092014271  Salvio`s Pizzeria  2428 SW Cary Pkwy      27513
# 1          1028  4092014271  Salvio`s Pizzeria  2428 SW Cary Pkwy      27513
# 2          1028  4092014271  Salvio`s Pizzeria  2428 SW Cary Pkwy      27513
# 3          1028  4092014271  Salvio`s Pizzeria  2428 SW Cary Pkwy      27513
# 4          1028  4092014271  Salvio`s Pizzeria  2428 SW Cary Pkwy      27513
#
#    X.objectid_y               inspectdate                     id  \
# 0          6975  2016-07-27T00:00:00.000Z  salvios-pizzeria-cary
# 1          9133  2012-11-30T00:00:00.000Z  salvios-pizzeria-cary
# 2          7492  2015-10-15T00:00:00.000Z  salvios-pizzeria-cary
# 3         10307  2012-11-30T00:00:00.000Z  salvios-pizzeria-cary
# 4         14176  2014-05-19T00:00:00.000Z  salvios-pizzeria-cary
#
#               name_y  rating  review_count  zip_code
# 0  salvio's pizzeria     4.0            56     27513
# 1  salvio's pizzeria     4.0            56     27513
# 2  salvio's pizzeria     4.0            56     27513
# 3  salvio's pizzeria     4.0            56     27513
# 4  salvio's pizzeria     4.0            56     27513

# %% [markdown]
# Besides, we have also noticed that the length of postalcode is different in different rows. As a result, we should standradlize those codes
# in the dataframe

# %%
for index, row in my_health_data.iterrows():
    if len(row['postalcode']) > 5 :
        my_health_data.at[index, 'postalcode'] = row['postalcode'][0:5]
my_health_data
# Out:
#         X.objectid_x      hsisid                         name  \
# 0               1001  4092017230                SPRING CAFE 2
# 1               1001  4092017230                SPRING CAFE 2
# 2               1001  4092017230                SPRING CAFE 2
# 3               1001  4092017230                SPRING CAFE 2
# 4               1001  4092017230                SPRING CAFE 2
# 5               1001  4092017230                SPRING CAFE 2
# 6               1001  4092017230                SPRING CAFE 2
# 7               1001  4092017230                SPRING CAFE 2
# 8               1001  4092017230                SPRING CAFE 2
# 9               1001  4092017230                SPRING CAFE 2
# 10              1001  4092017230                SPRING CAFE 2
# 11              1001  4092017230                SPRING CAFE 2
# 12              1001  4092017230                SPRING CAFE 2
# 13              1001  4092017230                SPRING CAFE 2
# 14              1001  4092017230                SPRING CAFE 2
# 15              1001  4092017230                SPRING CAFE 2
# 16              1001  4092017230                SPRING CAFE 2
# 17              1001  4092017230                SPRING CAFE 2
# 18              1001  4092017230                SPRING CAFE 2
# 19              1001  4092017230                SPRING CAFE 2
# 20              1001  4092017230                SPRING CAFE 2
# 21              1001  4092017230                SPRING CAFE 2
# 22              1001  4092017230                SPRING CAFE 2
# 23              1001  4092017230                SPRING CAFE 2
# 24              1001  4092017230                SPRING CAFE 2
# 25              1003  4092014444             Taco Bell #22798
# 26              1003  4092014444             Taco Bell #22798
# 27              1003  4092014444             Taco Bell #22798
# 28              1003  4092014444             Taco Bell #22798
# 29              1003  4092014444             Taco Bell #22798
# ...              ...         ...                          ...
# 156886          2998  4092016557           BURGER KING #19795
# 156887          2998  4092016557           BURGER KING #19795
# 156888          2998  4092016557           BURGER KING #19795
# 156889          2998  4092016557           BURGER KING #19795
# 156890          2998  4092016557           BURGER KING #19795
# 156891          2999  4092017227                      QUICKLY
# 156892          2999  4092017227                      QUICKLY
# 156893          2999  4092017227                      QUICKLY
# 156894          2999  4092017227                      QUICKLY
# 156895          2999  4092017227                      QUICKLY
# 156896          2999  4092017227                      QUICKLY
# 156897          2999  4092017227                      QUICKLY
# 156898          2999  4092017227                      QUICKLY
# 156899          2999  4092017227                      QUICKLY
# 156900          2999  4092017227                      QUICKLY
# After we standardlize the dataset, we should also consider that in different regions, the amount of restaurants is also different. So we should average the total violations by the amount of restaurants in different regions.

# %%
all_zipcodes_1 = my_health_data['postalcode'].unique()
print(all_zipcodes_1)
# Out:
# ['27616' '27587' '27601' '27597' '27610' '27617' '27513' '27591' '27612'
#  '27526' '27606' '27603' '27609' '27520' '27502' '27545' '27613' '27604'
#  '27529' '27614' '27511' '27607' '27540' '27615' '27608' '27605' '27602'
#  '27539' '27560' '27512' '27518' '27519' '27695' '28277' '27571' '27592'
#  '27652' '27709' '27623' '27579' '27501' '27523' '27595' '27573' '27619'
#  '27562' '27628' '27596' '27522' '27263' '27514' '28587' '28145' '27624'
#  '27650']

# %%
all_zipcodes_2 = zipcodes_data['zip'].unique()
print(all_zipcodes_2)
print(type(all_zipcodes_2[0]))
# Out:
# [27501 27502 27511 27513 27518 27519 27520 27522 27523 27526 27529 27539
#  27540 27545 27560 27562 27571 27587 27591 27592 27596 27597 27601 27603
#  27604 27605 27606 27607 27608 27609 27610 27612 27613 27614 27615 27616
#  27617 27703]
# <class 'numpy.int64'>

# %% [markdown]
# In previous cell, we have found that the postalcode in our 'my_health_data' dataset is at least a little different from that in the 'zipcodes_data' dataset. Then we have to deal with this issue and drop some restaurant's data if this restaurant's postalcode is not in the 'zipcodes_data' dataset.

# %%
my_health_data = my_health_data[my_health_data['postalcode'].astype(int).isin(list(all_zipcodes_2))]

# %%
my_health_data
# Out:
#         X.objectid_x      hsisid                         name  \
# 0               1001  4092017230                SPRING CAFE 2
# 1               1001  4092017230                SPRING CAFE 2
# 2               1001  4092017230                SPRING CAFE 2
# 3               1001  4092017230                SPRING CAFE 2
# 4               1001  4092017230                SPRING CAFE 2
# 5               1001  4092017230                SPRING CAFE 2
# 6               1001  4092017230                SPRING CAFE 2
# 7               1001  4092017230                SPRING CAFE 2
# 8               1001  4092017230                SPRING CAFE 2
# 9               1001  4092017230                SPRING CAFE 2
# 10              1001  4092017230                SPRING CAFE 2
# 11              1001  4092017230                SPRING CAFE 2
# 12              1001  4092017230                SPRING CAFE 2
# 13              1001  4092017230                SPRING CAFE 2
# 14              1001  4092017230                SPRING CAFE 2
# 15              1001  4092017230                SPRING CAFE 2
# 16              1001  4092017230                SPRING CAFE 2
# 17              1001  4092017230                SPRING CAFE 2
# 18              1001  4092017230                SPRING CAFE 2
# 19              1001  4092017230                SPRING CAFE 2
# 20              1001  4092017230                SPRING CAFE 2
# 21              1001  4092017230                SPRING CAFE 2
# 22              1001  4092017230                SPRING CAFE 2
# 23              1001  4092017230                SPRING CAFE 2
# 24              1001  4092017230                SPRING CAFE 2
# 25              1003  4092014444             Taco Bell #22798
# 26              1003  4092014444             Taco Bell #22798
# 27              1003  4092014444             Taco Bell #22798
# 28              1003  4092014444             Taco Bell #22798
# 29              1003  4092014444             Taco Bell #22798
# ...              ...         ...                          ...
# 156886          2998  4092016557           BURGER KING #19795
# 156887          2998  4092016557           BURGER KING #19795
# 156888          2998  4092016557           BURGER KING #19795
# 156889          2998  4092016557           BURGER KING #19795
# 156890          2998  4092016557           BURGER KING #19795
# 156891          2999  4092017227                      QUICKLY
# 156892          2999  4092017227                      QUICKLY
# 156893          2999  4092017227                      QUICKLY
 4092020992: 2.5, 4092021007: 1.0, 4092010237: 3.5, 4092020237: 4.0, 4092011235: 3.0, 4092014002: 3.0, 4092010795: 4.0, 4092013006: 4.0, 4092012067: 2.5, 4092013453: 4.5, 4092013971: 4.0, 4092010065: 4.0, 4092012004: 1.5, 4092013542: 4.0, 4092020973: 4.0, 4092300151: 4.0, 4092010302: 4.5, 4092013811: 2.5, 4092300210: 3.5, 4092021181: 3.0, 4092013955: 3.5, 4092021092: 4.0, 4092010625: 4.5, 4092014115: 2.5, 4092012896: 2.5, 4092013962: 3.5, 4092013707: 3.5, 4092021203: 4.0, 4092021202: 4.0, 4092013897: 3.5, 4092013907: 3.5, 4092012231: 4.0, 4092014225: 1.5, 4092021233: 2.0, 4092016291: 4.0, 4092021216: 1.0, 4092013714: 4.0, 4092013673: 4.0, 4092300149: 3.5}

# %%
x = []
y = []
# After we get the rating data, we could analysis the correlation between the two variables
for i in range(len(unique_id)):
    x.append(violations.get(unique_id[i]))
    y.append(rating_data.get(unique_id[i]))
print(x)
print(y)
# Out:
# [69, 42, 262, 87, 165, 139, 41, 99, 440, 85, 119, 10, 107, 184, 82, 60, 692, 148, 32, 25, 208, 96, 54, 35, 54, 164, 15, 126, 86, 68, 62, 133, 96, 129, 50, 112, 57, 36, 37, 68, 58, 68, 41, 68, 34, 93, 36, 45, 86, 90, 40, 108, 66, 213, 41, 50, 27, 33, 40, 8, 35, 25]
# [4.0, 3.5, 3.5, 1.0, 1.0, 4.0, 3.0, 3.0, 4.0, 5.0, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0, 4.5, 3.5, 1.5, 4.0, 4.0, 4.0, 3.0, 2.5, 1.0, 3.5, 4.0, 3.0, 3.0, 4.0, 4.0, 2.5, 4.5, 4.0, 4.0, 1.5, 4.0, 4.0, 4.0, 4.5, 2.5, 3.5, 3.0, 3.5, 4.0, 4.5, 2.5, 2.5, 3.5, 3.5, 4.0, 4.0, 3.5, 3.5, 4.0, 1.5, 2.0, 4.0, 1.0, 4.0, 4.0, 3.5]

# %%
data_list = [x,y]
df = pd.DataFrame(data_list).transpose()
df.columns =  ['violations', 'rating']
df

ax1 = df.plot.scatter(x = 'violations',
                      y = 'rating',
                      c = 'DarkBlue')

# %%
df.corr()
# Out:
#             violations    rating
# violations    1.000000  0.162556
# rating        0.162556  1.000000

# %% [markdown]
# Then we could get the conclusion that the correlation between the variable 'violations' and 'rating' is not really high. We could assume that
# those two vatiables are almost independent

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %%
#besides, we could analysis the correlation between the violations and economic development in a specific place
print((my_health_data['postalcode'].unique()))
# Out:
# ['27616' '27587' '27601' '27597' '27610' '27617' '27513' '27591' '27612'
#  '27526' '27606' '27603' '27609' '27520' '27502' '27545' '27613' '27604'
#  '27529' '27614' '27511' '27607' '27540' '27615' '27608' '27605' '27539'
#  '27560' '27518' '27519' '27571' '27592' '27501' '27523' '27562' '27596'
#  '27522']

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# *Fill in your ethics & privacy discussion here*

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*
