# %% [markdown]
# # Introduction
#
# Seeing that in Piazza, concerning the research question, you said: "If it's restaurant focused and using the data provided, I'll allow it."
#
# I decided to ask the hypothesis question:
# #### Are certain foods served more in certain neighborhoods?
#
#
#
#
# *Before ultimately focusing on:*
# #### Is the percetange of restaurants serving sushi correlated with the wealth of a neighborhood?
#
# The yelp dataset and zipcodes dataset can aid me in this question.
# The yelp dataset contained data (in True or False) about the types of food that is served there.
# The zipcodes dataset contained information about a zipcodes's area wealth, including median family income, median household income, income per capita, etc.
#
# These two datasets can be connect using zipcodes that they both provide in their datasets.

# %%
#Normal Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
sns.set_context('talk')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
#Filepaths
fp_ins = 'Data Finals/inspections.csv'
fp_res = 'Data Finals/restaurants.csv'
fp_vio = 'Data Finals/violations.csv'
fp_yel = 'Data Finals/yelp.csv'
fp_zip = 'Data Finals/zipcodes.csv'

#Reading the data
df_ins = pd.read_csv(fp_ins)
df_res = pd.read_csv(fp_res)
df_vio = pd.read_csv(fp_vio)
df_yel = pd.read_csv(fp_yel)
df_zip = pd.read_csv(fp_zip)

# %%
#Cleaning the data with Nan or Nulls
df_ins = df_ins.dropna(axis=1)
df_res = df_res.dropna(axis=1)
df_vio = df_vio.dropna(axis=1)
df_yel = df_yel.dropna(axis=1)
df_zip = df_zip.dropna(axis=1)

# %%
df_zip
df_zip.columns = ['zip','median_family_income','median_household_income','per_capita_income','percent_families_below_poverty_line','percent_snap_benefits','percent_supplemental_security_income','percent_nonwhite']

# %%
df_yel
# Out:
#                                                   id  \
# 0     42nd-street-oyster-bar-rdu-airport-morrisville
# 1                                    aldi-foods-cary
# 2      luciano-pizzeria-ristorante-northwest-raleigh
# 3             olive-garden-italian-restaurant-wilson
# 4                                    subway-wilson-4
# ...                                              ...
# 3683                   carter-finley-stadium-raleigh
# 3684                  raleigh-little-theatre-raleigh
# 3685          sky-zone-trampoline-park-durham-durham
# 3686                  highgrove-estate-fuquay-varina
# 3687                 banfield-pet-hospital-raleigh-6
#
#                                       name  is_closed  rating  review_count  \
# 0     42nd street oyster bar - rdu airport      False     2.5            23
# 1                               aldi foods      False     4.0            17
# 2              luciano pizzeria ristorante      False     5.0             2
# 3          olive garden italian restaurant      False     3.0            16
# 4                                   subway      False     3.5             3
# ...                                    ...        ...     ...           ...
# 3683                 carter-finley stadium      False     3.5            23
# 3684                raleigh little theatre      False     3.5            24
# 3685      sky zone trampoline park, durham      False     4.0            12
# 3686                      highgrove estate      False     3.5             4
# 3687                 banfield pet hospital      False     2.0             5
#
#       zip_code   latitude  longitude  hotdogs  sandwiches  ...  italian  \
# 0        27560  35.873808 -78.790896    False       False  ...    False
# 1        27519  35.802840 -78.785930    False       False  ...    False
# 2        27612  35.839681 -78.678791    False       False  ...     True
# 3        27893  35.743170 -77.964160    False       False  ...     True
# 4        27896  35.762936 -77.999428     True        True  ...    False
# ...        ...        ...        ...      ...         ...  ...      ...
# 3683     27607  35.801217 -78.719568    False       False  ...    False
# 3684     27607  35.791430 -78.668820    False       False  ...    False
# 3685     27701  36.020901 -78.914003    False       False  ...    False
# 3686     27526  35.557201 -78.807747    False       False  ...    False
# 3687     27612  35.871144 -78.679313    False       False  ...    False
#
#       newamerican  chicken_wings  delis   bars  salad  seafood    bbq  \
# 0            True          False  False  False  False     True  False
# 1           False          False  False  False  False    False  False
# 2           False          False  False  False  False    False  False
# 3           False          False  False  False   True    False  False
# 4           False          False  False  False  False    False  False
# ...           ...            ...    ...    ...    ...      ...    ...
# 3683        False          False  False  False  False    False  False
# 3684        False          False  False  False  False    False  False
# 3685        False          False  False  False  False    False  False
# 3686        False          False  False  False  False    False  False
# 3687        False          False  False  False  False    False  False
#
#       bakeries  sushi
# 0        False  False
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# ...        ...    ...
# 3683     False  False
# 3684     False  False
# 3685     False  False
# 3686     False  False
# 3687     False  False
#
# [3688 rows x 28 columns]

# %% [markdown]
# # Cleaning up the Data

# %% [markdown]
# First, I clean-up the data for zipcodes.csv.
#
# Whilst creating an array for clean_df_yel method.

# %%
df_yel = df_yel.rename(columns={'zip_code':'zip'})
zip_ar = df_zip['zip'].values

# %% [markdown]
# This clean_df_yel method allows me to check and then tag all yelp restaurants outside the range of zipcodes.csv using the apply method from Pandas.
#
# After tagging all zipcodes outside the range of zipcodes.csv, I simply use the dropna method from Pandas to remove them. Leaving me with only zipcodes inside the range of zipcodes.csv

# %%
def clean_df_yel(int):
    if int in zip_ar:
        return int
    else:
        return np.nan

# %%
df_yel['zip'] = df_yel['zip'].apply(clean_df_yel)

#Checking and dropping any closed stores.
df_yel.drop(df_yel[df_yel.is_closed == True].index, inplace=True)
#Dropping the columns that serve no purpose in the context of my question
df_yel = df_yel.drop(columns=['is_closed','latitude','longitude'])

# %%
#Removes all the rows I tagged
df_yel = df_yel.dropna()

# %%
#As there are 38 different zipcodes in df_zip, I wanted to confirm that the same for our df_yel after cleaning up.
df_yel['zip'].unique().size
# Out:
# 38

# %% [markdown]
# # Data Visualization
#
# Below this is the averages of all columns based on zip. Which we will use later to merge with zipcodes to see wealth vs. types of food.

# %%
yel_avg_rating = df_yel.groupby(['zip']).mean()
df_yel['zip'] = df_yel['zip'].astype(int)

yel_avg_rating
# Out:
#            rating  review_count   hotdogs  sandwiches     pizza  tradamerican  \
# zip
# 27501.0  4.055556     25.888889  0.111111    0.222222  0.222222      0.111111
# 27502.0  3.610526     32.726316  0.126316    0.084211  0.094737      0.094737
# 27511.0  3.631841     42.179104  0.079602    0.079602  0.044776      0.064677
# 27513.0  3.707006     44.159236  0.114650    0.114650  0.101911      0.050955
# 27518.0  3.561856     39.969072  0.092784    0.123711  0.082474      0.061856
# 27519.0  3.610294     33.808824  0.117647    0.117647  0.044118      0.058824
# 27520.0  3.346154     17.128205  0.153846    0.128205  0.102564      0.102564
# 27522.0  3.000000      9.000000  0.500000    0.000000  0.500000      0.000000
# 27610.0  0.044776  0.014925  0.014925
# 27612.0  0.000000  0.005814  0.023256
# 27613.0  0.012048  0.012048  0.036145
# 27614.0  0.017241  0.051724  0.051724
# 27615.0  0.006329  0.012658  0.018987
# 27616.0  0.008929  0.000000  0.017857
# 27617.0  0.009615  0.019231  0.028846
# 27703.0  0.018182  0.000000  0.000000
#
# [38 rows x 22 columns]

# %% [markdown]
# We can see from the graph below that the average median family income seems to be around the $70,000.
#
# Considering the median family income in the US is about $59,000 this group of neighborhood, on average, is pretty wealthy.

# %%
sns.distplot(df_zip['median_family_income'], bins= 20)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_zip
# Out:
#       zip  median_family_income  median_household_income  per_capita_income  \
# 0   27501                 59408                    51121              21631
# 1   27502                109891                    95857              36763
# 2   27511                 82292                    67392              33139
# 3   27513                109736                    87262              41232
# 4   27518                125432                    98247              49865
# 5   27519                137193                   121815              45778
# 6   27520                 67939                    58455              25628
# 7   27522                 66250                    59221              25513
# 8   27523                 89184                    68342              36976
# 9   27526                 74666                    66025              28074
# 10  27529                 68627                    59613              25807
# 11  27539                 88121                    82614              34877
# 12  27540                 96650                    88638              33308
# 13  27545                 72301                    60825              26568
# 14  27560                 97917                    80324              38830
# 15  27562                 71161                    61097              31161
# 16  27571                 86250                    81809              30502
# 17  27587                 96247                    83416              34731
# 18  27591                 59892                    50868              24239
# 19  27592                 66160                    56747              23355
# 20  27596                 68750                    59712              26241
# 21  27597                 59395                    51266              21573
# 22  27601                 28641                    27564              17363
# 23  27603                 68608                    54889              27843
# 24  27604                 57419                    50365              25532
# 25  27605                109886                    49309              42632
# 26  27606                 61324                    44422              25385
# 27  27607                 85325                    53825              26007
# 28  27608                125019                    83986              59155
# 29  27609                 73715                    53640              39008
# 30  27610                 49213                    45209              19207
# 31  27612                 98452                    68864              45080
# 32  27613                106854                    79698              42435
# 33  27614                119232                    94727              45317
# 34  27615                 98884                    78378              44747
# 35  27616                 60033                    56323              24549
# 36  27617                 98642                    76959              49205
# 37  27703                 60783                    54674              24280
#
#     percent_families_below_poverty_line  percent_snap_benefits  \
# 0                                  10.5                   15.5
# 1                                   3.4                    2.4
# 2                                   9.6                    4.5
# 3                                   3.8                    2.4
# 4                                   5.5                    1.0
# 5                                   3.2                    2.3
# 6                                   5.0                    7.8
# 7                                   6.0                    7.0
# 8                                   3.1                    3.1
# 9                                   8.4                    8.3
# 10                                  9.5                    7.6
# 11                                  2.2                    4.1
# 12                                  3.0                    4.5
# 13                                  6.1                    6.1
# 14                                  3.6                    3.9
# 15                                 10.4                    1.4
# 16                                  8.2                   12.6
# 17                                  5.5                    6.4
# 18                                 10.1                   12.9
# 19                                  6.3                    7.2
# 20                                  5.6                    9.6
# 21                                 11.3                   15.5
# 22                                 35.9                   33.5
# 23                                 12.6                   10.4
# 24                                 14.4                   10.2
# 25                                  4.1                    6.5
# 26                                 13.8                    7.6
# 27                                 12.8                    8.8
# 28                                  5.5                    2.6
# 29                                  8.9                    9.0
# 30                                 19.2                   16.9
# 31                                  5.5                    4.8
# 32                                  4.7                    4.2
# 33                                  3.7                    3.3
# 34                                  4.2                    4.2
# 35                                 11.7                   10.6
# 36                                  2.0                    1.3
# 37                                 12.7                   15.4
#
#     percent_supplemental_security_income  percent_nonwhite
# 0                                    5.2              17.9
# 1                                    0.8              18.9
# 2                                    2.2              24.8
# 3                                    1.5              27.8
# 4                                    1.7              19.9
# 5                                    2.3              35.2
# 6                                    2.4              23.5
# 7                                    4.2              31.4
# 8                                    1.8              22.4
# 9                                    3.9              22.5
# 10                                   4.8              33.9
# 11                                   1.4              19.0
# 12                                   2.4              19.7
# 13                                   1.8              44.4
# 14                                   1.1              53.3
# 15                                  15.4              13.6
# 16                                   3.7              17.4
# 17                                   3.2              18.0
# 18                                   3.0              32.8
# 19                                   1.9              14.6
# 20                                   4.1              18.9
# 21                                   7.5              26.3
# 22                                  10.8              69.9
# 23                                   3.8              25.6
# 24                                   3.8              41.3
# 25                                   4.0              14.8
# 26                                   2.0              31.8
# 27                                   3.9              25.0
# 28                                   2.7               8.7
# 29                                   1.6              27.2
# 30                                   5.9              72.7
# 31                                   1.3              23.2
# 32                                   1.7              22.6
# 33                                   1.2              16.6
# 34                                   1.5              19.6
# 35                                   4.6              52.6
# 36                                   0.5              30.4
# 37                                   3.6              61.5

# %% [markdown]
# #### Merging the Data

# %%
df_yel_zip = pd.merge(df_zip,yel_avg_rating,on='zip')
df_yel_zip
# Out:
#       zip  median_family_income  median_household_income  per_capita_income  \
# 0   27501                 59408                    51121              21631
# 1   27502                109891                    95857              36763
# 2   27511                 82292                    67392              33139
# 3   27513                109736                    87262              41232
# 4   27518                125432                    98247              49865
# 5   27519                137193                   121815              45778
# 6   27520                 67939                    58455              25628
# 7   27522                 66250                    59221              25513
# 8   27523                 89184                    68342              36976
# 9   27526                 74666                    66025              28074
# 10  27529                 68627                    59613              25807
# 11  27539                 88121                    82614              34877
# 12  27540                 96650                    88638              33308
# 13  27545                 72301                    60825              26568
# 14  27560                 97917                    80324              38830
# 15  27562                 71161                    61097              31161
# 16  27571                 86250                    81809              30502
# 17  27587                 96247                    83416              34731
# 18  27591                 59892                    50868              24239
# 19  27592                 66160                    56747              23355
# 20  27596                 68750                    59712              26241
# 21  27597                 59395                    51266              21573
# 22  27601                 28641                    27564              17363
# 23  27603                 68608                    54889              27843
# 24  27604                 57419                    50365              25532
# 25  27605                109886                    49309              42632
# 26  27606                 61324                    44422              25385
# 27  27607                 85325                    53825              26007
# 28  27608                125019                    83986              59155
# 29  27609                 73715                    53640              39008
# 30  27610                 49213                    45209              19207
# 31  27612                 98452                    68864              45080
# 32  27613                106854                    79698              42435
# 33  27614                119232                    94727              45317
# 34  27615                 98884                    78378              44747
# 35  27616                 60033                    56323              24549
# 36  27617                 98642                    76959              49205
# 37  27703                 60783                    54674              24280
#
#     percent_families_below_poverty_line  percent_snap_benefits  \
# 0                                  10.5                   15.5
# 1                                   3.4                    2.4
# 2                                   9.6                    4.5
# 3                                   3.8                    2.4
# 4                                   5.5                    1.0
# 5                                   3.2                    2.3
# 6                                   5.0                    7.8
# 7                                   6.0                    7.0
# 8                                   3.1                    3.1
# 9                                   8.4                    8.3
# 10                                  9.5                    7.6
# 11                                  2.2                    4.1
# 12                                  3.0                    4.5
# 13                                  6.1                    6.1
# 14                                  3.6                    3.9
# 15                                 10.4                    1.4
# 16                                  8.2                   12.6
# 17                                  5.5                    6.4
# 18                                 10.1                   12.9
# 19                                  6.3                    7.2
# 20                                  5.6                    9.6
# 21                                 11.3                   15.5
# 22                                 35.9                   33.5
# 23                                 12.6                   10.4
# 24                                 14.4                   10.2
# 25                                  4.1                    6.5
# 26                                 13.8                    7.6
# 27                                 12.8                    8.8
# 28                                  5.5                    2.6
# 29                                  8.9                    9.0
# 30                                 19.2                   16.9
# 31                                  5.5                    4.8
# 32                                  4.7                    4.2
# 33                                  3.7                    3.3
# 34                                  4.2                    4.2
# 35                                 11.7                   10.6
# 36                                  2.0                    1.3
# 37                                 12.7                   15.4
#
#     percent_supplemental_security_income  percent_nonwhite    rating  \
# 0                                    5.2              17.9  4.055556
# 1                                    0.8              18.9  3.610526
# 2                                    2.2              24.8  3.631841
# 3                                    1.5              27.8  3.707006
# 4                                    1.7              19.9  3.561856
# 5                                    2.3              35.2  3.610294
# 6                                    2.4              23.5  3.346154
# 7                                    4.2              31.4  3.000000
# 8                                    1.8              22.4  3.547619
# 9                                    3.9              22.5  3.596154
# 10                                   4.8              33.9  3.344037
# 11                                   1.4              19.0  3.708333
# 12                                   2.4              19.7  3.600000
# 13                                   1.8              44.4  3.204082
# 14                                   1.1              53.3  3.524242
# 15                                  15.4              13.6  4.500000
# 16                                   3.7              17.4  3.647059
# 17                                   3.2              18.0  3.798701
# 18                                   3.0              32.8  3.934783
# 19                                   1.9              14.6  3.750000
# 20                                   4.1              18.9  3.250000
# 21                                   7.5              26.3  3.706897
# 22                                  10.8              69.9  3.816547
# 23                                   3.8              25.6  3.617143
# 24                                   3.8              41.3  3.661972
# 25                                   4.0              14.8  3.522727
# 26                                   2.0              31.8  3.525773
# 27                                   3.9              25.0  3.616279
# 28                                   2.7               8.7  3.990196
# 29                                   1.6              27.2  3.519663
# 30                                   5.9              72.7  3.283582
# 31                                   1.3              23.2  3.502907
# 32                                   1.7              22.6  3.518072
# 33                                   1.2              16.6  3.612069
# 34                                   1.5              19.6  3.810127
# 35                                   4.6              52.6  3.464286
# 36                                   0.5              30.4  3.649038
# 37                                   3.6              61.5  3.600000
#
#     review_count  ...   italian  newamerican  chicken_wings     delis  \
# 0      25.888889  ...  0.222222     0.111111       0.111111  0.000000
# 1      32.726316  ...  0.031579     0.031579       0.042105  0.042105
# 2      42.179104  ...  0.024876     0.024876       0.009950  0.029851
# 3      44.159236  ...  0.031847     0.019108       0.038217  0.031847
# 4      39.969072  ...  0.041237     0.030928       0.010309  0.030928
# 5      33.808824  ...  0.000000     0.000000       0.000000  0.014706
# 6      17.128205  ...  0.025641     0.051282       0.102564  0.076923
# 7       9.000000  ...  0.250000     0.000000       0.250000  0.000000
  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.034483  0.000000  0.000000
# 22  0.107914  0.014388  0.007194  0.021583  0.028777  0.007194
# 23  0.080000  0.011429  0.034286  0.005714  0.022857  0.011429
# 24  0.007042  0.021127  0.021127  0.007042  0.014085  0.007042
# 25  0.075758  0.015152  0.030303  0.000000  0.075758  0.015152
# 26  0.010309  0.020619  0.020619  0.010309  0.010309  0.000000
# 27  0.007752  0.023256  0.000000  0.000000  0.023256  0.015504
# 28  0.019608  0.019608  0.000000  0.000000  0.019608  0.019608
# 29  0.016854  0.028090  0.039326  0.011236  0.011236  0.028090
# 30  0.000000  0.014925  0.059701  0.044776  0.014925  0.014925
# 31  0.017442  0.017442  0.011628  0.000000  0.005814  0.023256
# 32  0.036145  0.024096  0.012048  0.012048  0.012048  0.036145
# 33  0.017241  0.034483  0.034483  0.017241  0.051724  0.051724
# 34  0.018987  0.037975  0.025316  0.006329  0.012658  0.018987
# 35  0.017857  0.044643  0.017857  0.008929  0.000000  0.017857
# 36  0.038462  0.019231  0.000000  0.009615  0.019231  0.028846
# 37  0.018182  0.018182  0.000000  0.018182  0.000000  0.000000
#
# [38 rows x 30 columns]

# %% [markdown]
# #### Where I'd get my question from?
#
# At first, I started with is there any correlation between food and the wealth of the neighborhood.
#
# Looking at this graph, I saw a decent spurious correlation between sushi and the median family income, so I focused my question deeply on one specfic item and investigated further to confirm whether it's coincidence or correlated.
# Logically speaking, it shouldn't be autocorrelated as well.

# %% [markdown]
# ## Approaching the data
#
# I figured to use Inferential Analysis because I felt like there was a trend between the two variables and then using linear regression to see if there really was a relationship and the magnitude of said relationship.
#
# The percentage of restaurants serving sushi and median family income also wasn't too correlated which avoided multicollinearity.

# %%
df_yel_zip.corr()
# Out:
#                                            zip  median_family_income  \
# zip                                   1.000000             -0.209730
# median_family_income                 -0.209730              1.000000
# median_household_income              -0.361328              0.881468
# per_capita_income                    -0.027070              0.903884
# percent_families_below_poverty_line   0.306144             -0.723360
# percent_snap_benefits                 0.314024             -0.763552
# percent_supplemental_security_income  0.078607             -0.518530
# percent_nonwhite                      0.297128             -0.515274
# rating                                0.054443              0.063763
# review_count                          0.238587              0.047190
# hotdogs                              -0.242693             -0.162535
# sandwiches                            0.117455              0.106075
# pizza                                -0.334146             -0.085759
# tradamerican                         -0.085529              0.040717
# burgers                              -0.064377             -0.250132
# mexican                              -0.157487              0.171480
# grocery                              -0.320527             -0.074229
# breakfast_brunch                      0.254111              0.028277
# coffee                                0.211414              0.201069
# chinese                              -0.038879             -0.171465
# italian                              -0.226750             -0.223139
# newamerican                          -0.015034             -0.137686
# chicken_wings                        -0.252479             -0.279719
# delis                                 0.062245             -0.020462
# bars                                  0.149235             -0.059411
# salad                                -0.193541              0.075115
# seafood                              -0.040978             -0.026561
# bbq                                   0.034330             -0.153126
# bakeries                             -0.078082              0.243230
# sushi                                 0.039407              0.544693
#
#                                       median_household_income  \
# zip                                                 -0.361328
# median_family_income                                 0.881468
# median_household_income                              1.000000
# per_capita_income                                    0.724968
# percent_families_below_poverty_line                 -0.695488
# percent_snap_benefits                               -0.700279
# percent_supplemental_security_income                -0.477990
# percent_nonwhite                                    -0.400670
# rating                                               0.055314
# review_count                                        -0.128220
# hotdogs                                             -0.019434
# sandwiches                                           0.116408
# pizza                                               -0.016632
# tradamerican                                        -0.017720
# burgers                                             -0.156927
# mexican                                              0.190834
# grocery                                              0.021608
# breakfast_brunch                                    -0.177029
# coffee                                               0.041934
# chinese                                             -0.081435
# italian                                             -0.135859
# newamerican                                         -0.230575
# chicken_wings                                       -0.156840
# delis                                               -0.020126
# bars                                                -0.204214
# salad                                                0.088028
# seafood                                             -0.067250
# bbq                                                 -0.112663
# bakeries                                             0.098083
# sushi                                                0.433652
#
#                                       per_capita_income  \
# zip                                           -0.027070
# median_family_income                           0.903884
# median_household_income                        0.724968
# per_capita_income                              1.000000
# percent_families_below_poverty_line           -0.619224
# percent_snap_benefits                         -0.703885
# percent_supplemental_security_income          -0.471805
# percent_nonwhite                              -0.457737
# rating                                         0.142334
# review_count                                   0.207210
# hotdogs                                       -0.251472
# sandwiches                                     0.009320
# pizza                                         -0.174187
# tradamerican                                   0.025638
# burgers                                       -0.331258
# mexican                                        0.122872
# grocery                                       -0.179039
# breakfast_brunch                               0.123088
# coffee                                         0.252051
# chinese                                       -0.231933
# italian                                       -0.257474
# newamerican                                   -0.057135
# chicken_wings                                 -0.337431
# delis                                         -0.041289
# bars                                           0.048815
# salad                                          0.037221
# seafood                                       -0.040730
# bbq                                           -0.207494
# bakeries                                       0.204590
# sushi                                          0.592079
#
#                                       percent_families_below_poverty_line  \
# zip                                                              0.306144
# median_family_income                                            -0.723360
# median_household_income                                         -0.695488
# per_capita_income                                               -0.619224
# percent_families_below_poverty_line                              1.000000
# percent_snap_benefits                                            0.876882
# percent_supplemental_security_income                             0.618236
# percent_nonwhite                                                 0.636133
# rating                                                           0.120144
# review_count                                                     0.428886
# hotdogs                                                         -0.124053
# sandwiches                                                       0.006408
# pizza                                                           -0.153131
# tradamerican                                                     0.021045
# burgers                                                          0.125695
# mexican                                                         -0.109099
# grocery                                                         -0.064089
# breakfast_brunch                                                 0.148256
# coffee                                                           0.102329
# chinese                                                         -0.008208
# italian                                                          0.042342
# newamerican                                                      0.309024
# chicken_wings                                                    0.035861
# delis                                                           -0.038559
# bars                                                             0.337454
# salad                                                           -0.055070
# seafood                                                         -0.000131
# bbq                                                             -0.020172
# bakeries                                                        -0.075597
# sushi                                                           -0.242945
#
#                                       percent_snap_benefits  \
# zip                                                0.314024
# median_family_income                              -0.763552
# median_household_income                           -0.700279
# per_capita_income                                 -0.703885
# percent_families_below_poverty_line                0.876882
# percent_snap_benefits                              1.000000
# percent_supplemental_security_income               0.493867
# percent_nonwhite                                   0.595707
# rating                                             0.005017
# review_count                                       0.295384
# hotdogs                                            0.057675
# sandwiches                                         0.240715
# pizza                                              0.034338
# tradamerican                                       0.053158
# burgers                                            0.256489
# mexican                                           -0.149428
# grocery                                            0.091339
# breakfast_brunch                                   0.155812
# coffee                                             0.118909
# chinese                                            0.142004
# italian                                            0.227838
# newamerican                                        0.383641
# chicken_wings                                      0.191107
# delis                                              0.023802
# bars                                               0.316900
# salad                                              0.047265
# seafood                                           -0.019888
# bbq                                                0.015259
# bakeries                                          -0.019853
# sushi                                             -0.365445
#
#                                       percent_supplemental_security_income  \
# zip                                                               0.078607
# median_family_income                                             -0.518530
# median_household_income                                          -0.477990
# per_capita_income                                                -0.471805
# percent_families_below_poverty_line                               0.618236
# percent_snap_benefits                                             0.493867
# percent_supplemental_security_income                              1.000000
# percent_nonwhite                                                  0.203640
# rating                                                            0.438762
# review_count                                                      0.004610
# hotdogs                                                          -0.102921
# sandwiches                                                       -0.165160
# pizza                                                            -0.040841
# tradamerican                                                     -0.186464
# burgers                                                          -0.105701
# mexican                                                          -0.275048
# grocery                                                          -0.085510
# breakfast_brunch                                                 -0.036077
# coffee                                                           -0.140853
# chinese                                                          -0.071636
# italian                                                           0.045293
# newamerican                                                       0.152785
# chicken_wings                                                     0.049327
# delis                                                            -0.181765
# bars                                                              0.119398
# salad                                                            -0.160368
# seafood                                                          -0.203176
# bbq                                                              -0.084870
# bakeries                                                         -0.137060
# sushi                                                            -0.364715
#
#                                       percent_nonwhite    rating  \
# zip                                           0.297128  0.054443
# median_family_income                         -0.515274  0.063763
# median_household_income                      -0.400670  0.055314
# per_capita_income                            -0.457737  0.142334
# percent_families_below_poverty_line           0.636133  0.120144
# percent_snap_benefits                         0.595707  0.005017
# percent_supplemental_security_income          0.203640  0.438762
# percent_nonwhite                              1.000000 -0.308664
# rating                                       -0.308664  1.000000
# review_count                                  0.274138  0.163282
# hotdogs                                       0.124282 -0.613082
# sandwiches                                    0.048691 -0.097081
# pizza                                        -0.085720 -0.403293
# tradamerican                                  0.098669 -0.173013
# burgers                                       0.336845 -0.314360
# mexican                                       0.043367 -0.233737
# grocery                                      -0.033751 -0.080954
# breakfast_brunch                              0.039298 -0.170236
# coffee                                        0.070791 -0.111775
# chinese                                       0.124114 -0.066469
# italian                                       0.075728 -0.166083
# newamerican                                  -0.019804  0.273481
# chicken_wings                                 0.142168 -0.403782
# delis                                         0.252871 -0.399224
# bars                                          0.118737  0.014903
# salad                                         0.002414  0.251908
# seafood                                       0.185310 -0.311132
# bbq                                          -0.077640  0.016066
# bakeries                                     -0.135078  0.087839
# sushi                                        -0.147006 -0.090593
#
#                                       review_count  ...   italian  \
# zip                                       0.238587  ... -0.226750
# median_family_income                      0.047190  ... -0.223139
# median_household_income                  -0.128220  ... -0.135859
# per_capita_income                         0.207210  ... -0.257474
# percent_families_below_poverty_line       0.428886  ...  0.042342
# percent_snap_benefits                     0.295384  ...  0.227838
# percent_supplemental_security_income      0.004610  ...  0.045293
# percent_nonwhite                          0.274138  ...  0.075728
# rating                                    0.163282  ... -0.166083
# review_count                              1.000000  ... -0.282362
# hotdogs                                  -0.475789  ...  0.638606
# sandwiches                               -0.067417  ...  0.182256
# pizza                                    -0.450047  ...  0.844662
# tradamerican                              0.082961  ... -0.044147
# burgers                                  -0.244232  ...  0.068244
# mexican                                   0.025331  ... -0.255156
# grocery                                  -0.292693  ...  0.309812
# breakfast_brunch                          0.417155  ... -0.474212
# coffee                                    0.313543  ... -0.283607
# chinese                                  -0.304802  ...  0.224435
# italian                                  -0.282362  ...  1.000000
# newamerican                               0.411062  ...  0.122617
# chicken_wings                            -0.385352  ...  0.744542
# delis                                    -0.017834  ... -0.177315
# bars                                      0.647322  ... -0.239270
# salad                                    -0.062694  ...  0.362265
# seafood                                   0.022137  ... -0.050827
# bbq                                       0.072462  ... -0.157345
# bakeries                                  0.071560  ... -0.055736
# sushi                                     0.246199  ... -0.119600
#
#                                       newamerican  chicken_wings     delis  \
# zip                                     -0.015034      -0.252479  0.062245
# median_family_income                    -0.137686      -0.279719 -0.020462
# median_household_income                 -0.230575      -0.156840 -0.020126
# per_capita_income                       -0.057135      -0.337431 -0.041289
# percent_families_below_poverty_line      0.309024       0.035861 -0.038559
# percent_snap_benefits                    0.383641       0.191107  0.023802
# percent_supplemental_security_income     0.152785       0.049327 -0.181765
# percent_nonwhite                        -0.019804       0.142168  0.252871
# rating                                   0.273481      -0.403782 -0.399224
# review_count                             0.411062      -0.385352 -0.017834
# hotdogs                                 -0.222266       0.744181  0.078240
# sandwiches                               0.189184       0.031649  0.355636
# pizza                                   -0.047828       0.850755 -0.148853
# tradamerican                             0.289892      -0.100338  0.291231
# burgers                                  0.044805       0.086322  0.218479
# mexican                                 -0.092163      -0.091693  0.211017
# grocery                                  0.209083       0.214454  0.078078
# breakfast_brunch                         0.355250      -0.375351  0.352981
# coffee                                  -0.137810      -0.298624  0.087919
# chinese                                  0.160961      -0.029011  0.331093
# italian                                  0.122617       0.744542 -0.177315
# newamerican                              1.000000      -0.003720 -0.099002
# chicken_wings                           -0.003720       1.000000 -0.146024
# delis                                   -0.099002      -0.146024  1.000000
# bars                                     0.506288      -0.174854  0.106053
# salad                                    0.102803      -0.028075 -0.082001
# seafood                                  0.000383       0.153422  0.378091
# bbq                                     -0.149932      -0.112866 -0.131142
# bakeries                                -0.177747      -0.176215  0.174529
# sushi                                   -0.019875      -0.198059  0.148175
#
#                                           bars     salad   seafood       bbq  \
# zip                                   0.149235 -0.193541 -0.040978  0.034330
# median_family_income                 -0.059411  0.075115 -0.026561 -0.153126
# median_household_income              -0.204214  0.088028 -0.067250 -0.112663
# per_capita_income                     0.048815  0.037221 -0.040730 -0.207494
# percent_families_below_poverty_line   0.337454 -0.055070 -0.000131 -0.020172
# percent_snap_benefits                 0.316900  0.047265 -0.019888  0.015259
# percent_supplemental_security_income  0.119398 -0.160368 -0.203176 -0.084870
# percent_nonwhite                      0.118737  0.002414  0.185310 -0.077640
# rating                                0.014903  0.251908 -0.311132  0.016066
# review_count                          0.647322 -0.062694  0.022137  0.072462
# hotdogs                              -0.279348 -0.091323 -0.045464 -0.225768
# sandwiches                           -0.026225  0.315228  0.094355 -0.303301
# pizza                                -0.265669  0.089969 -0.084236 -0.202363
# tradamerican                          0.258440  0.323333  0.381890 -0.246757
# burgers                              -0.015411  0.365047  0.225386 -0.212539
# mexican                               0.022792 -0.043698  0.379776 -0.185640
# grocery                              -0.231984  0.522476  0.164491 -0.180980
# breakfast_brunch                      0.481551 -0.260083  0.149498 -0.238984
# coffee                                0.235315  0.168210 -0.025876 -0.285854
# chinese                              -0.322419  0.347028 -0.074712 -0.212411
# italian                              -0.239270  0.362265 -0.050827 -0.157345
# newamerican                           0.506288  0.102803  0.000383 -0.149932
# chicken_wings                        -0.174854 -0.028075  0.153422 -0.112866
# delis                                 0.106053 -0.082001  0.378091 -0.131142
# bars                                  1.000000 -0.174461  0.229779 -0.107867
# salad                                -0.174461  1.000000 -0.073612 -0.210968
# seafood                               0.229779 -0.073612  1.000000 -0.027342
# bbq                                  -0.107867 -0.210968 -0.027342  1.000000
# bakeries                              0.121060  0.311762  0.005864 -0.182216
# sushi                                 0.232774  0.066917  0.308956 -0.130142
#
#                                       bakeries     sushi
# zip                                  -0.078082  0.039407
# median_family_income                  0.243230  0.544693
# median_household_income               0.098083  0.433652
# per_capita_income                     0.204590  0.592079
# percent_families_below_poverty_line  -0.075597 -0.242945
# percent_snap_benefits                -0.019853 -0.365445
# percent_supplemental_security_income -0.137060 -0.364715
# percent_nonwhite                     -0.135078 -0.147006
# rating                                0.087839 -0.090593
# review_count                          0.071560  0.246199
# hotdogs                              -0.013322 -0.281100
# sandwiches                            0.223089  0.172466
# pizza                                 0.001463 -0.182751
# tradamerican                         -0.007357  0.345278
# burgers                              -0.064630 -0.036578
# mexican                               0.192101  0.220882
# grocery                              -0.138331 -0.027659
# breakfast_brunch                      0.048931  0.075541
# coffee                                0.480262  0.227099
# chinese                              -0.067768 -0.143094
# italian                              -0.055736 -0.119600
# newamerican                          -0.177747 -0.019875
# chicken_wings                        -0.176215 -0.198059
# delis                                 0.174529  0.148175
# bars                                  0.121060  0.232774
# salad                                 0.311762  0.066917
# seafood                               0.005864  0.308956
# bbq                                  -0.182216 -0.130142
# bakeries                              1.000000  0.095013
# sushi                                 0.095013  1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# #### Graphing the relationship

# %%
med_fam_income_v = df_yel_zip['median_family_income'].values.tolist()
sushi_v = df_yel_zip['sushi'].values.tolist()

a1, b1 = np.polyfit(med_fam_income_v,sushi_v,1)

# %%
x1 = np.arange(min(df_yel_zip['median_family_income']),max(df_yel_zip['median_family_income']))

plt.scatter(med_fam_income_v, sushi_v)
plt.plot(x1, a1 * x1 + b1, color = "red")

# %% [markdown]
# Looking at this graph, confirmed that Inferential Analysis was the right approach, the graph showed a straight line showing a linear relationship.
# Similarly, there doesn't seem to be any sign of multivariate normality, where the data points are spread out between the typical range of a median family income.
# Not homoscedastic as well.
# Which ticks all the assumptions for Inferential Analysis: Regression.
#
# Looking below, I tried using the pivot table to see how an ordered list would look like. Similar to the graph, the percentage of restaurants serving sushi rose from 0 starting from around the lower half of the list.

# %%
sushi_pv = pd.pivot_table(df_yel_zip,values = 'sushi',index='median_family_income')
sushi_pv
# Out:
#                          sushi
# median_family_income
# 28641                 0.007194
# 49213                 0.014925
# 57419                 0.007042
# 59395                 0.000000
# 59408                 0.000000
# 59892                 0.000000
# 60033                 0.017857
# 60783                 0.000000
# 61324                 0.000000
# 66160                 0.000000
# 66250                 0.000000
# 67939                 0.025641
# 68608                 0.011429
# 68627                 0.018349
# 68750                 0.000000
# 71161                 0.000000
# 72301                 0.000000
# 73715                 0.028090
# 74666                 0.009615
# 82292                 0.034826
# 85325                 0.015504
# 86250                 0.000000
# 88121                 0.000000
# 89184                 0.000000
# 96247                 0.032468
# 96650                 0.013333
# 97917                 0.018182
# 98452                 0.023256
# 98642                 0.028846
# 98884                 0.018987
# 106854                0.036145
# 109736                0.019108
# 109886                0.015152
# 109891                0.010526
# 119232                0.051724
# 125019                0.019608
# 125432                0.041237
# 137193                0.014706

# %% [markdown]
# #### Using OLS (Ordinary Least Squares)

# %%
outcome_1,predictors_1 = patsy.dmatrices('median_family_income~sushi',df_yel_zip)
mod_1 = sm.OLS(outcome_1,predictors_1)
res_1 = mod_1.fit()

# %%
print(res_1.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     median_family_income   R-squared:                       0.297
# Model:                              OLS   Adj. R-squared:                  0.277
# Method:                   Least Squares   F-statistic:                     15.19
# Date:                  Wed, 10 Jun 2020   Prob (F-statistic):           0.000407
# Time:                          14:01:02   Log-Likelihood:                -430.29
# No. Observations:                    38   AIC:                             864.6
# Df Residuals:                        36   BIC:                             867.9
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.948e+04   4821.461     14.410      0.000    5.97e+04    7.93e+04
# sushi       9.656e+05   2.48e+05      3.897      0.000    4.63e+05    1.47e+06
# ==============================================================================
# Omnibus:                        1.156   Durbin-Watson:                   2.187
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                0.419
# Skew:                           0.191   Prob(JB):                        0.811
# Kurtosis:                       3.343   Cond. No.                         74.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The OLS Regression shows that there is an upwards trend for the Median Family Income as the percentage of restaurants serving sushi increases as well. To translate the sushi coefficient, the median household income increases by 966.10 dollars for each 1 percent increase in restaurants serving sushi.
#
# The OLS also shows that the P-value is smaller than 0.000, meaning that we can reject the Null Hypothesis or that there is indeed a pattern betweeen percentage of restaurants serving sushi versus the median family income.
#
# Even with P-value support this, to confirm that this isn't just a coincidence,  I propose that we try the same thing with median household income instead. If median household income gets similar results, it confirms that this pattern relates to the wealth of the neighboorhood.

# %%
med_hh_income_v = df_yel_zip['median_household_income'].values.tolist()
a2, b2 = np.polyfit(med_hh_income_v,sushi_v,1)

# %%
x2 = np.arange(min(df_yel_zip['median_household_income']),max(df_yel_zip['median_household_income']))
plt.scatter(med_fam_income_v, sushi_v)
plt.plot(x2, a2 * x2 + b2, color = "orange")

# %%
outcome_2,predictors_2 = patsy.dmatrices('median_household_income~sushi',df_yel_zip)
mod_2 = sm.OLS(outcome_2,predictors_2)
res_2 = mod_2.fit()

# %%
print(res_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     median_household_income   R-squared:                       0.188
# Model:                                 OLS   Adj. R-squared:                  0.165
# Method:                      Least Squares   F-statistic:                     8.338
# Date:                     Wed, 10 Jun 2020   Prob (F-statistic):            0.00653
# Time:                             14:01:03   Log-Likelihood:                -423.50
# No. Observations:                       38   AIC:                             851.0
# Df Residuals:                           36   BIC:                             854.3
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.905e+04   4032.672     14.644      0.000    5.09e+04    6.72e+04
# sushi       5.985e+05   2.07e+05      2.888      0.007    1.78e+05    1.02e+06
# ==============================================================================
# Omnibus:                        7.567   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                6.449
# Skew:                           0.768   Prob(JB):                       0.0398
# Kurtosis:                       4.310   Cond. No.                         74.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
per_cap_income_v = df_yel_zip['per_capita_income'].values.tolist()
a3, b3 = np.polyfit(per_cap_income_v,sushi_v,1)

# %%
x3 = np.arange(min(df_yel_zip['per_capita_income']),max(df_yel_zip['per_capita_income']))
plt.scatter(per_cap_income_v, sushi_v)
plt.plot(x3, a3 * x3 + b3, color = "green")

# %%
outcome_3,predictors_3 = patsy.dmatrices('per_capita_income~sushi',df_yel_zip)
mod_3 = sm.OLS(outcome_3,predictors_3)
res_3 = mod_3.fit()

# %%
print(res_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      per_capita_income   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     19.43
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):           9.02e-05
# Time:                        14:01:03   Log-Likelihood:                -395.05
# No. Observations:                  38   AIC:                             794.1
# Df Residuals:                      36   BIC:                             797.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.692e+04   1907.501     14.112      0.000     2.3e+04    3.08e+04
# sushi       4.321e+05    9.8e+04      4.408      0.000    2.33e+05    6.31e+05
# ==============================================================================
# Omnibus:                        3.249   Durbin-Watson:                   2.554
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.123
# Skew:                           0.541   Prob(JB):                        0.346
# Kurtosis:                       3.415   Cond. No.                         74.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Conclusion
#
# Both Per Capita Income and Median Household Income showed the same patterns as Median Family Income, Per Capita also had a less than 0.000 p-value while Median Family Income had a 0.007, considering the typical P-value to reject the Null Hypotehsis is 0.05, all our OLS Regression results showed that we can accept the can reject the Null Hypothesis and confirm our Alternative Hypothesis that there is a correlation between percentage of restaurants serving sushi and the wealth of the neighborhoods.
# Although, to know why is another problem. It could be that sushi restaurants whose owner lives nearby, on average, earn more thus improving the median income or wealth of the neighborhood. Or it could be that more wealthier neighborhoods have people that can afford or enjoy sushi more, thus more sushi is put in their menu.
#
# Although, based on the limitations and small collection of data, I can only confirm this pattern for the small neighborhoods that the data "zip_code" had.
# Any reliable inference to a larger neighborhood needs to be supported with a larger quantity of data that spans states or countries.
#
# Though this data isn't Earth-shattering, it believe it does have some uses. If this pattern can be supported with more data, it can be used to recommend areas that might have sushi.
# For example, let's say yelp doesn't have complete data in a new country it just tried to reach out to, the customer wants to eat sushi, maybe due to the limited data or lack of actually sushi restaurants, it can't find one inside the city. It can instead try to recommend going to certain areas of higher wealth that has a better chance of finding restaurants that has a sidemenu serving sushi.
