# %% [markdown]
# # Same or Different Inspector: Any Bias?

# %% [markdown]
# # Overview

# %% [markdown]
# My hypothesis was rejected. The analysis is very simple, a unpaired t-test. Since the p-value exceeded the alpha value. The conclusion was that there isn't a statistically significant difference between in the number of critical risk factor reported by different inspectors and the number of critical risk factor report by the same inspector.

# %% [markdown]
# # Name & PID
#
# - Name: Brittney
# - PID: A15056364

# %% [markdown]
# # Research Question

# %% [markdown]
# Are restaurants—that are previously inspected by the same inspector —more likely to have more critical citations compared to restaurants that are inspected by a different inspector?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Food health and sanitation inspection standards aren't singular, meaning facilities are not inspected on the same basis. According to counties in North Carolina, inspection on facilites are categorized into four risk category based on what kind of food is provided and how the food is prepared or processed. The number of visitation per year also depends on the risk category--the higher the risk category, the more frequent the visits. Thus, public health inspectors need to keep up with these standards.
#
# The length and types of visits depends on the type of facility, the risk category, and other factors, plus health inspectors often do multiple inspection per day. These assessments are for the safety for the public, so it’s important that the inspection scores reflect the risk of food-borne illness. The ones who score and inspect facilities are people so they too are prone to biases or human factors such as fatigue. A study from Harvard says that the time of when the inspector visits a facility is related to how much violation is found. Health inspectors cite less violations as the day progresses or when working later in the day. They also found that inspectors find more violation in one location will more likely exhibit more scrutiny to the next location. Therefore, the study suggests that health inspector’s bias and behavior are related to scheduling which impacts the inspection results.
#
# References (include links):
# 1)https://hbswk.hbs.edu/item/a-simple-way-for-restaurant-inspectors-to-improve-food-safety
# 2)http://data-wake.opendata.arcgis.com/datasets/food-inspection-violations?selectedAttribute=CRITICAL

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Restaurants—that are inspected by the same inspector previously—on average are more likely to have less critical citations compared to restaurants that are inspected by different inspectors. If inspection are consistently done by the same inspector, perhaps the inspector may exhibit some bias just based on inspection in restaurant they are more familiar with.

# %% [markdown]
# # Dataset

# %% [markdown]
# - Dataset Name: Inspections
# - Number of observations: 18466
#
# This dataset contains information of regarding the food inspection report. It includes food inspection score reports or each respective facility in the state of North Carolina

# %% [markdown]
# # Setup

# %%
# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

#import libraries
import pandas as pd
import numpy as np

#for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", font_scale=2)

#for conducting t-test
from scipy.stats import ttest_ind
import scipy.stats as stats

# plotting size parameter
plt.rcParams['figure.figsize'] = (17, 7)


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %%
#import data
df = pd.read_csv('inspections.csv')

#Taking certain columns to take general look at the data
insp_df = df[['inspector_id', 'address1', 'facilitytype', 'name', 'previous_inspection_by_same_inspector','num_critical', 'num_non_critical','score' ]]
insp_df = insp_df[df.facilitytype == 'Restaurant']
insp_df = insp_df.rename(columns ={'address1':'address'})

#delete at end
pd.reset_option('display.max_rows')

# %%
insp_df
# Out:
#        inspector_id                address facilitytype  \
# 0              27.0      3000 New Bern Ave   Restaurant
# 1               7.0   1030-149 N Rogers Ln   Restaurant
# 2               3.0    6209 ROCK QUARRY RD   Restaurant
# 3              24.0     1065 Darrington DR   Restaurant
# 6              18.0    3215 AVENT FERRY RD   Restaurant
# ...             ...                    ...          ...
# 18453          13.0    5160 SUNSET LAKE RD   Restaurant
# 18454           5.0      1910 ENTREPRENUUR   Restaurant
# 18455           1.0      904 NE MAYNARD RD   Restaurant
# 18456           8.0    326 HILLSBOROUGH ST   Restaurant
# 18457          22.0  1144 KILDAIRE FARM RD   Restaurant
#
#                                     name  \
# 0                  Cafe 3000 At Wake Med
# 1                    Overtime Sports Pub
# 2                         TASTE OF CHINA
# 3                     Panera Bread #1643
# 6               Pearl Chinese Restaurant
# ...                                  ...
# 18453                 ARCHIBALD`S TAVERN
# 18454                           THE OVAL
# 18455  AWAZ'E ETHIOPIAN/ERITREAN CUISINE
# 18456                      TAVERNA AGORA
# 18457                NEWK'S EATERY #1107
#
#       previous_inspection_by_same_inspector  num_critical  num_non_critical  \
# 0                                       NaN             9                 7
# 1                                       NaN             0                11
# 2                                       NaN             4                 8
# 3                                       NaN             2                 3
# 6                                       NaN             6                 7
# ...                                     ...           ...               ...
# 18453                                 False             2                 7
# 18454                                 False             3                 6
# 18455                                 False             3                 5
# 18456                                 False             3                 6
# 18457                                 False             4                 3
#
#        score
# 0       96.0
# 1       98.0
# 2       97.0
# 3       99.0
# 6       96.0
# ...      ...
# 18453   93.5
# 18454   97.0
# 18455   97.0
# 18456   96.0
# 18457   95.0
#
# [11985 rows x 8 columns]

# %% [markdown]
# At first look, the data needs to be cleaned up as evidence of the NaN values. To further explore the data, I standardized name and address, so grouping the variable would be easier.

# %%
#Standardizing address

def standardize_address(address):
    address = address.upper()
    address = address.strip()
    
    address = address.replace('.', '')
    
    address = address.replace('LANE', 'LN')
    address = address.replace('DRIVE', 'DR')
    address = address.replace('ROAD', 'RD')
    address = address.replace('STREET', 'ST')
    address = address.replace('AVENUE', 'AVE')
    address = address.replace('BOULEVARD', 'BLVD')
    address = address.replace('BLV ', 'BLVD')
    address = address.replace('CIRCLE', 'CIR')
    
    address = address.replace('WEST', 'W')
    address = address.replace('NORTH', 'N')
    address = address.replace('SOUTH', 'S')
    address = address.replace('EAST', 'E')

    
    return address

#checking output
print(standardize_address('W. Main Street'))

#applying standardization
insp_df['address'] = insp_df['address'].apply(standardize_address)
# Out:
# W MAIN ST

# %% [markdown]
# Next, standardizing names which is less compared to address. This standardization the name as much as address because I only needed enough standardization to look at the overall dataset. I wasn't going to merge with another dataset, so I chose not to standardize strictly.

# %%
def standardize_name(name):
    name = name.upper()
    name = name.strip()
    
    return name

#applying standardization
insp_df['name'] = insp_df['name'].apply(standardize_name)

# %%
#checking for missing values
insp_df.isna().any()

#dropping rows with missing values 
insp_df = insp_df.dropna()

#converting column to bool
insp_df['previous_inspection_by_same_inspector'] = df['previous_inspection_by_same_inspector'].astype(bool)
insp_df.dtypes

#creating dataframe for restaurants previously inspected with the same inspector
same_df = insp_df[insp_df.previous_inspection_by_same_inspector == True]

#creating dataframe for restaurants inspected by a different inspector
diff_df = insp_df[insp_df.previous_inspection_by_same_inspector == False]

# %%
table = pd.pivot_table(insp_df, values = 'num_critical', index = ['previous_inspection_by_same_inspector','name', 'address', 'inspector_id'])
pd.options.display.max_rows = None
table
# Out:
#                                                                                                                                               num_critical
# previous_inspection_by_same_inspector name                                               address                                inspector_id
# False                                 #1 CHINA                                           764 W WILLIAMS ST                      10.0              0.000000
#                                                                                                                                 22.0              3.000000
#                                                                                                                                 31.0              3.000000
#                                       #1 CHINA WOK                                       942 GATEWAY COMMONS CIR                7.0               7.000000
#                                                                                                                                 29.0              2.000000
#                                       115 MIDTOWNE                                       4421-115 SIX FORKS RD                  6.0               2.000000
#                                                                                                                                 29.0              1.000000
#                                       1250 HERITAGE                                      1250 HERITAGE CLUB AVE                 7.0               4.000000
#                                       1705 PRIME CATERING AND EVENTS                     1705 E MILLBROOK RD                    14.0              2.000000
#                                                                                                                                 20.0              1.000000
#                                                                                                                                 21.0              0.000000
#                                                                                                                                 27.0              7.000000
#                                       18 SEABOARD                                        18 SEABOARD AVE                        8.0               2.000000
#                                                                                                                                 16.0              1.500000
#                                       1853 GRILLE                                        1025 BLUE RIDGE RD                     5.0               1.000000
#                                                                                                                                 10.0              1.000000
#                                                                                                                                 25.0              7.000000
#                                       1887 BISTRO                                        2610 CATES AVE                         5.0               1.000000
#                                       42ND ST OYSTER BAR                                 508 W JONES ST                         11.0              5.000000
#                                                                                                                                 18.0              6.000000
#                                                                                                                                 23.0              3.000000
#                                       4TH FLOOR CAFE                                     310 NEW BERN AVE                       8.0               5.000000
#                                                                                                                                 16.0              4.000000
#                                       510 TAVERN                                         510-101 GLENWOOD AVE                   23.0              4.000000
#                                       701 CAFE                                           701 CORPORATE CENTER DR                2.0               0.000000
#                                                                                                                                 25.0             11.000000
#                                       A SLICE OF NY PIZZA                                8301 BRIER CREEK PKY                   2.0              12.000000
#                                       A'NETS KATCH                                       2009 VILLAGE PARK DR                   28.0              3.000000
#                                       ABBEY ROAD TAVERN &AMP; GRILL                      1195 W CHATHAM ST                      3.0               0.000000
#                                                                                                                                 22.0              4.000000
#                                       ABBOTSWOOD ASSISTED LIVING DINING SERVICES         7900 CREEDMOOR RD                      9.0               2.000000
#                                                                                                                                 11.0              2.000000
#                                                                                                                                 22.0              5.000000
#                                                                                                                                 29.0              1.000000
#                                       ABYSSINIA ETHIOPIAN RESTAURANT                     2109 AVENT FERRY RD                    10.0              1.000000
#                                                                                                                                 23.0              1.000000
#                                       ACME PIZZA CO                                      204 VILLAGE WALK DR                    1.0               5.000000
#                                                                                                                                 13.0              6.000000
#                                                                                                                                 22.0              5.000000
#                                       ACRO CAFE                                          11 W JONES ST                          8.0               3.000000
#                                                                                                                                 16.0              1.000000
#                                       ADMINISTRATION BLDG. SNACK BAR                     116 W JONES ST                         16.0              4.000000
#                                       ADVENTURE LANDING                                  3311 CAPITAL BLVD                      10.0              1.000000
#                                                                                                                                 11.0              0.000000
#                                       AGAVE MEXICAN BAR &AMP; GRILL                      18 W THIRD ST                          11.0              4.000000
#                                                                                                                                 28.0              3.500000
#                                       AGGIE'S GRILL STATION                              3027 CAPITAL  BLVD                     1.0               8.000000
#                                                                                                                                 11.0              2.000000
#                                                                                                                                 23.0              1.000000
#                                       AGRICULTURE BLDG. SNACK BAR                        2 W EDENTON ST                         16.0              1.000000
#                                       AJISAI JAPANESE FUSION                             427 WOODBURN RD                        3.0               1.000000
#                                                                                                                                 23.0              3.000000
#                                       ALBARAKA DELI AND GRILL                            3815 HILLSBOROUGH ST                   5.0               0.000000
#                                       ALEXANDER'S MEDITERRANEAN CUISINE                  263 W TIMBER DR                        5.0               3.000000
#                                                                                                                                 18.0              3.000000
#                                       ALLSCRIPTS CAFETERIA                               8529 SIX FORKS RD                      2.0               1.000000
#                                                                                                                                 9.0               0.000000
#                                                                                                                                 29.0              2.000000
#                                       ALPACA PERUVIAN CHARCOAL CHICKEN                   4614 CAPITAL BLVD                      21.0              3.000000
#                                                                                                                                 25.0             10.000000
#                                                                                          9575 CHAPEL HILL  RD                   1.0              11.000000
#                                                                                                                                 6.0               1.000000
#                                       AMANTE GOURMET PIZZA                               9545 CHAPEL HILL RD                    6.0               1.000000
#                                       AMEDEO'S PIZZA                                     2045 CREEKSIDE LANDING DR              10.0              1.000000
#                                       AMEDEO`S                                           3905 WERN  BLVD                        10.0              2.000000
#                                       AMF SNACK BAR AND LOUNGE                           5501 COMMERCIAL AVE                    2.0               6.000000
#                                       AMF SOUTH HILLS SNACK BAR                          301 NOTTINGHAM DR                      3.0               0.000000
#                                                                                                                                 10.0              1.000000
#                                       ANDRES` COFFEE & CREPES                            315 CROSSRDS BLVD                      2.0               5.000000
#                                                                                                                                 3.0               3.000000
#                                                                                                                                 10.0              1.000000
#                                       ANGIE'S RESTAURANT                                 1340 W GARNER RD                       5.0               6.000000
#                                                                                                                                 18.0              6.000000
#                                       ANGUS BARN                                         9401 GLENWOOD AVE                      2.0               5.000000
#                                       ANNAS PIZZERIA                                     138 S MAIN ST                          1.0               9.000000
#                                                                                                                                 13.0              2.000000
#                                       ANNA`S PIZZERIA                                    100 N SALEM ST                         10.0              0.000000
#                                                                                                                                 22.0              2.000000
#                                       ANOTHER BROKEN EGG                                 1211 MARKET CENTER  DR                 1.0               7.000000
#                                                                                                                                 6.0               0.000000
#                                                                                                                                 15.0              7.000000
#                                                                                          160 PARK AT N HILLS ST                 29.0              0.000000
#                                       ANVIL`S CHEESESTEAKS                               2893 JONES FRANKLIN RD                 10.0              1.000000
#                                       APEX HIGH CULINARY ARTS                            1501 LAURA DUNCAN RD                   10.0              0.000000
#                                                                                                                                 22.0              4.000000
#                                       APEX WINGS                                         518 E WILLIAMS ST                      10.0              1.000000
#                                                                                                                                 22.0              5.000000
#                                       APPLEBEE'S #329                                    1165 US 70 HWY W                       5.0               5.000000
#                                                                                                                                 18.0              3.000000
#                                       APPLEBEE`S                                         1480 N MAIN ST                         1.0               5.000000
#                                                                                                                                 13.0              1.000000
#                                                                                          3625 HILLSBOROUGH ST                   10.0              3.000000
#                                                                                          501 E SIX FORKS RD                     1.0               6.000000
#                                                                                                                                 11.0              5.000000
#                                                                                          8701 BRIER CREEK PKY                   2.0               4.000000
#                                       APPLEBEE`S #353                                    7831 TARGET CIR                        4.0               7.000000
#                                                                                                                                 14.0              5.000000
#                                                                                                                                 20.0              3.000000
#                                                                                                                                 21.0              2.000000
#                                                                                                                                 25.0              4.000000
#                                       APPLEBEE`S #7                                      11805 RETAIL DR                        7.0               2.000000
#                                                                                                                                 21.0              0.000000
#                                       APPLEBEE`S AG 352                                  6609 KNIGHTDALE BLVD                   4.0               1.000000
#                                                                                                                                 9.0               2.000000
#                                                                                                                                 11.0              4.000000
#                                                                                                                                 28.0              3.500000
#                                       ARBY'S #6554                                       1031 HARRISON AVE                      31.0              9.000000
#                                       ARBY`S #7814                                       2601 WAKE FOREST RD                    6.0               2.000000
#                                                                                                                                 11.0              4.000000
#                                                                                                                                 23.0              1.000000
#                                       ARBY`S #7820                                       6725 KNIGHTDALE BLVD                   11.0              0.000000
#                                                                                                                                 28.0              1.000000
#                                       ARBY`S RESTAURANT                                  1401 N MAIN ST                         1.0               6.000000
#                                       ARCHDALE BLDG. SNACK BAR                           512 N SALISBURY ST                     8.0               4.000000
#                                                                                                                                 16.0              3.000000
#                                       ARCHIBALD`S TAVERN                                 5160 SUNSET LAKE RD                    1.0               5.000000
#                                                                                                                                 13.0              2.000000
#                                       ARMADILLO GRILL                                    439 GLENWOOD AVE                       18.0              7.000000
#                                                                                                                                 23.0              6.000000
#                                       AROMA                                              160 NE MAYNARD  RD                     1.0               6.000000
#                                                                                                                                 15.0              0.000000
#                                       ASHWORTH REXALL DRUG                               105 W CHATHAM ST                       25.0              3.000000
#                                       ASIAN BISTRO                                       1318 S MAIN ST                         7.0               4.000000
#                                                                                                                                 11.0              3.000000
#                                       ASIAN GARDEN                                       13654 CAPITAL  BLVD                    29.0              1.000000
#                                                                                          242 GRANDE HEIGHTS DR                  25.0              4.000000
#                                       ASSAGGIO`S                                         3501 W MILLBROOK RD                    2.0               5.000000
#                                       ASSAGIOS PIZZERIA RISTORANTE                       7417 SUNSET LAKE RD                    1.0               2.000000
#                                                                                                                                 13.0              1.000000
#                                       ASUKA                                              2101 S MAIN ST                         7.0              11.000000
#                                                                                                                                 29.0              1.000000
#                                       ATRIA OAKRIDGE DINING                              10810 SANDY OAK LN                     9.0               0.000000
#                                                                                                                                 20.0              5.000000
#                                                                                                                                 21.0              1.500000
#                                                                                                                                 24.0              5.000000
#                                       ATRIUM                                             2600 FOUNDERS DR                       10.0              3.000000
#                                                                                                                                 23.0              3.000000
#                                       ATRIUM CAFE, THE                                   500 SAS CAMPUS DR,  BLDG R             25.0             10.000000
#                                       AU BON PAIN CAFE #254                              3000 NEW BERN AVE                      3.0               2.000000
#                                                                                                                                 5.0               0.000000
#                                                                                                                                 22.0              6.000000
#                                                                                                                                 23.0              4.000000
#                                       AUBREY & PEEDI`S GRILL                             38 N MAIN ST                           11.0              2.000000
#                                                                                                                                 28.0              2.500000
#                                       AVERSBORO RESTAURANT AND SPORTS BAR                1411 AVERSBORO RD                      5.0               5.000000
#                                       AVIATOR BREWING TAP HOUSE                          600 E BRD ST                           13.0              1.000000
#                                       AVIATOR SMOKEHOUSE                                 525 BRD  ST                            1.0               8.000000
#                                                                                                                                 13.0              3.000000
#                                       AWAZ'E ETHIOPIAN/ERITREAN CUISINE                  904 NE MAYNARD RD                      1.0               3.000000
#                                                                                                                                 25.0              7.000000
#                                       AZITRA INDIAN RESTAURANT                           8411 BRIER CREEK PKY                   2.0               7.000000
#                                       BA-DA WINGS                                        2161 AVENT FERRY RD                    5.0               3.000000
#                                                                                                                                 10.0              1.000000
#                                                                                                                                 23.0              1.000000
#                                       BAAN THAI RESTAURANT                               758 WILLIAMS ST                        10.0              0.000000
#                                                                                                                                 22.0              3.000000
#                                       BABA GHANNOUJ MEDITERRANEAN BISTRO                 2468  WALNUT ST                        2.0               3.000000
#                                       BABYLON RESTAURANT                                 309 N DAWSON ST                        18.0             11.000000
#                                       BABYMOON CAFE                                      100 JERUSALEM DR                       2.0               7.000000
#                                                                                                                                 13.0              1.000000
#                                                                                                                                 22.0              3.000000
#                                       BACK 9 PUB                                         4220 NW CARY PKY                       6.0               1.000000
#                                                                                                                                 15.0              6.000000
#                                       BACKFINS CRABHOUSE                                 110 S WHITE  ST                        7.0               3.000000
#                                                                                                                                 11.0              3.000000
#                                       BACKYARD BISTRO                                    1235 HURRICANE ALLEY WAY               2.0               5.000000
#                                                                                                                                 25.0              9.000000
#                                       BACKYARD BURGERS #1130                             13250 STRICKLAND RD                    2.0               4.000000
#                                                                                                                                 9.0               1.000000
#                                       BAD DADDY'S BURGER BAR                             111 SEABOARD AVE                       16.0              2.000000
#                                                                                                                                 23.0              6.000000
#                                                                                          3300 VILLAGE MARKET PL                 1.0               6.000000
#                                                                                                                                 6.0               2.000000
#                                       BAGELS PLUS                                        100 DICKENS DR                         1.0               7.000000
#                                                                                                                                 13.0              2.000000
#                                       BAJA BURRITO                                       2109 AVENT FERRY RD                    10.0              1.000000
#                                                                                                                                 23.0              2.000000
#                                       BANANA LEAF                                        1026  RYAN RD                          2.0               3.000000
#                                                                                                                                 3.0               1.000000
#                                                                                                                                 25.0              9.000000
#                                       BARBECUE LODGE                                     4600 CAPITAL BLV                       20.0              4.000000
#                                                                                                                                 21.0              0.000000
#                                       BARHAM`S RESTAURANT                                122 N ARENDELL AVE                     11.0              5.000000
#                                                                                                                                 28.0              6.000000
#                                       BARNES &AMP; NOBLE BOOK SELLERS #2126              5959 TRIANGLE TOWN BLV                 20.0              0.000000
#                                                                                                                                 21.0              1.000000
#                                                                                                                                 25.0              0.000000
#                                       BARNES &AMP; NOBLE CAFE #2171                      8431 BRIER CREEK PKY                   2.0               0.000000
#                                       BARNES AND NOBLE                                   760 SE MAYNARD RD                      3.0               1.000000
#                                       BARNES AND NOBLE CAFE                              4325 GLENWOOD AVE                      6.0               1.000000
#                                                                                                                                 25.0              5.000000
#                                       BARRYS CAFE                                        2851 JONES FRANKLIN RD                 10.0              2.000000
#                                       BASS LAKE DRAFT HOUSE                              124 BASS LAKE RD                       1.0               8.000000
#                                                                                                                                 13.0              1.000000
#                                       BAWARCHI                                           9601 CHAPEL HILL RD                    1.0              18.000000
#                                       BB&AMP;Y CAFE &AMP; CATERING                       3700 NATIONAL DR                       6.0               1.000000
#                                                                                                                                 25.0              3.000000
#                                       BB`S GRILL                                         2950  42 HWY                           1.0               0.000000
#                                       BEANSPROUT CHINESE RESTAURANT                      3721 HILLSBOROUGH ST                   5.0               1.000000
#                                                                                                                                 10.0              2.000000
#                                       BEASLEY'S/CHUCK'S/FOX                              237  S WILMINGTON ST                   8.0               5.000000
#                                       BEAVER CREEK CINEMAS 12                            1441 BEAVER CREEK COMMONS DR           10.0              0.000000
#                                                                                                                                 22.0              3.000000
#                                       BEDFORD BISTRO &AMP; BAR                           3607 FALLS RIVER  AVE                  9.0               1.000000
#                                       BEE HIVE CAFE                                      3800 HILLSBOROUGH ST                   5.0               2.000000
#                                                                                                                                 10.0              1.000000
#                                       BELGIAN CAFE                                       1232 W WILLIAMS ST                     10.0              1.000000
#                                       BELLA ITALIA PIZZERIA                              109 CAPCOM AVE                         7.0               5.000000
#                                       BELLA ITALIA RISTORANTE                            10630 DURANT RD                        9.0               0.000000
#                                                                                                                                 18.0              7.000000
#                                                                                                                                 20.0              0.000000
#                                                                                                                                 21.0              1.000000
#                                       BELLA MONICA                                       3121-103 EDWARDS MILL RD               19.0              1.000000
#                                                                                                                                 25.0              8.000000
#                                       BENELUX CAFE                                       1603 HILLSBOROUGH ST                   18.0              5.000000
#                                                                                                                                 23.0              4.000000
#                                       BENELUX COFFEE                                     402-118 OBERLIN RD                     23.0              2.000000
#                                       BEST STEAK &AMP; SUBS                              323 CROSSRDS BLVD                      2.0               4.000000
#                                                                                                                                 10.0              1.000000
#                                       BEST WESTERN CARY CAFE                             1722 WALNUT ST                         2.0               3.000000
#                                                                                                                                 10.0              3.000000
#                                       BEST WESTERN FOODSERVICE                           2715 CAPITAL BLVD                      25.0              6.000000
#                                       BIDA MANDA                                         222 S BLOUNT ST                        8.0               8.000000
#                                                                                                                                 24.0              3.000000
#                                       BIG AL'S BBQ                                       2920 FORESTVILLE  RD                   7.0               2.000000
#                                                                                                                                 20.0              1.000000
#                                                                                                                                 21.0              0.000000
#                                       BIG APPLE BAGELS                                   1141 FALLS RIVER  AVE                  21.0              1.000000
#                                       BIG ED`S CITY MARKET RESTAURANT                    220 WOLFE ST                           8.0               2.000000
#                                       BIG JOHN'S NEW HAVEN STYLE                         1839-138 S MAIN ST                     7.0              11.000000
#                                                                                                                                 29.0              1.000000
#                                       BIRYANI HOUSE                                      744-A E CHATHAM ST                     15.0             15.000000
#                                                                                                                                 22.0             13.000000
#                                                                                                                                 25.0             15.000000
#                                       BIRYANI MAXX                                       590 E CHATHAM ST                       15.0              2.000000
#                                                                                                                                 22.0              4.000000
#                                       BIRYANI XPRX                                       748-A E CHATHAM ST                     15.0              5.000000
#                                                                                                                                 22.0              1.000000
#                                       BISCUITVILLE                                       2426 WAKE FOREST RD                    11.0              6.000000
#                                                                                                                                 15.0              4.000000
#                                                                                                                                 23.0              3.000000
#                                       BISCUITVILLE # 169                                 605 STELLATA DR                        1.0               6.000000
#                                       BISCUITVILLE #175                                  2820 NC HWY 55                         6.0               1.000000
#                                                                                                                                 15.0              1.500000
#                                                                                                                                 31.0              5.000000
#                                       BITTERSWEET                                        16 E MARTIN ST                         8.0               3.000000
#                                       BJ`S MEMBERSHIP CLUB #177 FOOD COURT               6301 TRIANGLE PLANTATION DR            20.0              0.000000
#                                                                                                                                 21.0              0.000000
#                                                                                                                                 25.0              1.000000
#                                       BJ`S WAREHOUSE CLUB #123                           8811 BRIER CREEK PKY                   2.0               1.000000
#                                       BJ`S WHOLESALE CLUB FAST FOOD EXPRESS              2370 WALNUT ST                         3.0               1.000000
#                                                                                                                                 10.0              0.000000
#                                       BLACKFINN AMERIPUB                                 3201 VILLAGE MARKET PLACE              1.0               6.000000
#                                                                                                                                 6.0               2.000000
#                                       BLAZE PIZZA #1062                                  1024 MARKET CENTER DR                  6.0               0.000000
#                                       BLAZE PIZZA #1125                                  140 CABELA DR                          18.0              1.000000
#                                       BLOOMSBURY BISTRO                                  509 W WHITAKER MILL RD                 16.0              1.000000
#                                                                                                                                 23.0              4.000000
#                                       BLUE PLATE RESTAURANT                              3400 N MAIN ST                         1.0              10.000000
#                                       BLUE RIDGE - THE MUSEUM RESTAURANT                 2110 BLUE RIDGE RD                     6.0               4.000000
#                                                                                                                                 25.0              6.500000
#                                       BOB EVAN`S #427                                    8001 BRIER CREEK PKY                   2.0               1.000000
#                                       BOB EVAN`S RESTAURANT                              2001 WALNUT ST                         3.0               2.000000
#                                                                                                                                 10.0              1.000000
#                                       BOCCI TRATTORIA &AMP; PIZZERIA                     2425 KILDAIRE FARM  RD                 3.0               6.000000
#                                                                                                                                 23.0              5.000000
#                                       BOJANGLES                                          1209 LAURA VILLAGE RD                  10.0              0.000000
#                                                                                                                                 22.0              3.000000
#                                                                                          1400 N MAIN ST                         1.0               6.000000
#                                                                                          2620 ATLANTIC AVE                      2.0               1.000000
#                                                                                                                                 11.0              7.000000
#                                                                                                                                 23.0              3.000000
#                                                                                          3023 WINSTON HILL DR                   1.0               6.000000
#                                                                                                                                 6.0               1.000000
#                                                                                                                                 15.0              1.000000
#                                                                                          4621 NEW BERN AVE                      19.0              2.000000
#                                                                                                                                 28.0              3.000000
#                                       BOJANGLES # 12                                     3808 WERN BLV                          10.0              0.000000
#                                       BOJANGLES # 2                                      4405 FALLS OF NEUSE RD                 6.0               2.000000
#                                                                                                                                 9.0               2.000000
#                                                                                                                                 11.0              5.000000
#                                                                                                                                 15.0              4.000000
#                                                                                                                                 21.0              0.000000
#                                                                                                                                 25.0              5.000000
#                                       BOJANGLES # 29                                     12109 CLOVERLEAF DR                    7.0               4.000000
#                                                                                                                                 29.0              1.000000
#                                       BOJANGLES # 3                                      1013 NEW BERN AVE                      8.0               2.000000
#                                                                                                                                 16.0              1.000000
#                                       BOJANGLES # 31                                     10610 DURANT RD                        9.0               1.000000
#                                                                                                                                 11.0              3.000000
#                                                                                                                                 20.0              1.000000
#                                       BOJANGLES #15                                      5409 CAPITAL BLVD                      11.0              3.000000
#                                                                                                                                 20.0              0.000000
#                                                                                                                                 21.0              1.000000
#                                                                                                                                 25.0              7.000000
#                                                                                                                                 31.0              9.000000
#                                       BOJANGLES #36                                      8680 GLENWOOD AVE                      2.0               2.000000
#                                                                                                                                 9.0               1.000000
#                                       BOJANGLES #39                                      1581 E WILLIAMS ST                     10.0              0.000000
#                                                                                                                                 22.0              1.000000
#                                       BOJANGLES #42                                      840 E CHATHAM ST                       15.0              2.000000
#                                                                                                                                 22.0              7.000000
#                                                                                                                                 25.0              4.000000
#                                       BOJANGLES #45                                      900 S MAIN ST                          7.0               2.000000
#                                       BOJANGLES #46                                      1513 N ARENDELL AVE                    28.0              2.000000
#                                       BOJANGLES#37                                       1000 CLAREN CIR                        2.0               2.000000
#                                                                                                                                 9.0               1.000000
# ...
#                                       WALTONWOOD AT CARY DINING                          750 SE CARY PKY                        3.0               3.833333
#                                                                                                                                 10.0              1.000000
#                                       WANG`S BISTRO                                      877-405 E GANNON AVE                   7.0               6.000000
#                                                                                                                                 28.0              3.400000
#                                       WANG`S KITCHEN                                     1030-109 N ROGERS LN                   7.0               9.000000
#                                                                                                                                 28.0              3.833333
#                                                                                          1601-41 CROSS LINK RD                  3.0               0.000000
#                                                                                                                                 5.0               2.000000
#                                                                                          3416 POOLE RD                          5.0               4.000000
#                                                                                                                                 27.0              4.000000
#                                                                                                                                 28.0              7.000000
#                                                                                          3631 NEW BERN AVE                      11.0              5.000000
#                                                                                                                                 23.0              6.000000
#                                                                                                                                 27.0              2.000000
#                                                                                          4701 ATLANTIC AVE                      14.0              5.000000
#                                                                                          6300-114 CREEDMOOR RD                  9.0               2.000000
#                                                                                                                                 32.0             17.000000
#                                       WARAJI JAPANESE RESTAURANT                         5910 DURALEIGH RD                      2.0               0.666667
#                                                                                                                                 25.0             14.000000
#                                       WASABI                                             107 EDINBURGH S, ST 135                22.0              4.500000
#                                       WATKINS GRILL                                      1625 WAKE FOREST RD                    8.0               3.000000
#                                                                                                                                 11.0              5.000000
#                                       WELCOME MART                                       3252 AUBURN KNIGHTDALE RD              4.0               0.000000
#                                                                                                                                 5.0               0.000000
#                                       WELLS FARGO  CAFE                                  1100 CORPORATE CENTER DR               25.0             11.600000
#                                       WENDELL COUNTRY CLUB FOODSERVICE                   180 JAKE MAY DR                        28.0              2.000000
#                                       WENDELL MART                                       2901 WENDELL BLVD                      7.0               6.000000
#                                                                                                                                 28.0              2.000000
#                                       WEST PARK TAVERN                                   2734 NC HWY 55                         1.0               8.000000
#                                                                                                                                 22.0              3.333333
#                                       WHICH WICH                                         145 GRAND HILL PL                      31.0              5.000000
#                                       WHICH WICH? #192                                   4120 MAIN AT N HILLS SUITE 140 ST      6.0               2.000000
#                                       WHISPERING PINES DINING                            7501 LEADMINE  RD                      6.0               4.000000
#                                                                                                                                 29.0              0.000000
#                                       WHITE OAK STADIUM 14                               1205 TIMBER DR E                       5.0               0.000000
#                                       WHITE STREET BREWING CO                            218 S WHITE ST                         7.0               0.000000
#                                                                                                                                 28.0              0.000000
#                                       WHOLE FOODS #10338 PREPARED FOODS                  8710 SIX FORKS RD                      9.0               2.000000
#                                                                                                                                 32.0              9.000000
#                                       WHOLE FOODS MARKET CAFE                            3540 WADE AVE                          10.0              3.600000
#                                                                                                                                 18.0              2.000000
#                                       WICKED TACO                                        3928 WERN BLVD                         10.0              3.000000
#                                       WILD WING CAFE                                     2300 WALNUT  ST                        3.0               3.000000
#                                                                                                                                 10.0              0.000000
#                                                                                                                                 18.0              4.000000
#                                                                                          7900 BRIER CREEK PKY                   2.0               7.000000
#                                                                                                                                 15.0             12.000000
#                                       WILDWOOD GREEN SNACK BAR                           3000 BALLYBUNION WAY                   9.0               3.000000
#                                       WILLIAM PEACE UNIVERSITY CAFETERIA                 15 E PEACE ST                          16.0              1.166667
#                                       WILLOW CREEK EXXON                                 1133 OLD HONEYCUTT RD                  1.0               8.333333
#                                       WINDSOR POINT RESTAURANT                           1221 BRD ST                            1.0               3.444444
#                                                                                                                                 22.0              4.000000
#                                       WINE AUTHORITIES                                   211 E FRANKLIN ST                      16.0              0.750000
#                                       WING STOP # 527                                    1721-112 NEW HOPE CHURCH RD            25.0              3.500000
#                                       WING STOP #816                                     7880 ALEXANDER PROMENADE PLACE         2.0               0.500000
#                                       WINGATE BY WYNDHAM BREAKFAST                       1542 MECHANICAL BLVD                   3.0               2.000000
#                                                                                                                                 5.0               1.000000
#                                       WINGATE BY WYNDHAM FOODSERVICE                     2610 WINGHOUSE BLVD                    11.0              2.000000
#                                                                                                                                 27.0              2.000000
#                                       WINGIN'IT                                          1625 N MAIN ST                         1.0               5.000000
#                                                                                                                                 31.0              3.000000
#                                       WINSTON CLUBHOUSE                                  17001 SEARSTONE DR                     15.0              4.500000
#                                       WINSTON`S GRILLE                                   6401 FALLS OF NEUSE RD                 9.0               0.000000
#                                                                                                                                 32.0              6.000000
#                                       WOODLAND TERRACE INDEPENDENT LIVING FOODSERVICES   300 KILDAIRE WOODS DR                  3.0               1.200000
#                                                                                                                                 10.0              1.000000
#                                       WOODY`S @ CITY MARKET                              205 WOLFE ST                           8.0               3.428571
#                                       WOODY`S SPORTS TAVERN &AMP; GRILL                  8322 CHAPEL HILL RD                    25.0             11.000000
#                                       WORLD OF BEER                                      2036 RENAISSANCE PARK PLACE            25.0             15.000000
#                                       YAMATO                                             700 E WILLIAMS ST                      22.0              3.000000
#                                       YOHO ASIAN BISTRO                                  8204-106 TRYON WOODS DR                10.0              0.625000
#                                                                                                                                 18.0              5.000000
#                                       YUM YUM THAI CUISINE                               1861 N HARRISON AVE                    6.0               6.000000
#                                                                                                                                 25.0              9.500000
#                                       YURI JAPANESE RESTAURANT                           1361  KILDAIRE FARM RD                 3.0               0.600000
#                                                                                                                                 10.0              1.000000
#                                       Z PIZZA CARY                                       96 CORNERSTONE DR                      15.0              4.000000
#                                       ZAXBY'S                                            1021 N HARRISON  AVE                   6.0               1.000000
#                                                                                                                                 25.0              6.666667
#                                                                                          1341 N MAIN ST                         1.0               5.750000
#                                       ZAXBY'S #44901                                     101 GRAND HILL PL                      22.0              3.500000
#                                       ZAXBY'S #46101                                     995 DURHAM RD                          7.0               2.600000
#                                       ZAXBY`S                                            2901 HILLSBOROUGH ST                   10.0              2.500000
#                                                                                                                                 23.0              2.000000
#                                                                                          8812 HARVEST OAKS  DR                  9.0               0.000000
#                                                                                                                                 32.0              5.000000
#                                       ZAXBY`S OF KNIGHTDALE                              6702 KNIGHTDALE  BLVD                  7.0               3.000000
#                                                                                                                                 28.0              2.500000
#                                       ZAXBY`S RESTAURANT                                 4150 FAYETTEVILLE RD                   5.0               1.000000
#                                                                                                                                 18.0              0.000000
#                                       ZAYKA INDIAN CUISINE                               10410-103 MONCREIFFE  RD               2.0               6.200000
#                                                                                                                                 15.0              8.000000
#                                       ZEBON HIBACHI &AMP; DELI                           3524 DAVIS DR                          31.0              4.000000
#                                       ZEBULON BP GRILL                                   603 W GANNON AVE                       28.0              5.333333
#                                       ZEST, INC                                          8831 SIX FORKS RD                      9.0               0.000000
#                                       ZOE'S KITCHEN                                      1017 MARKET CENTER DR                  6.0               1.000000
#                                                                                                                                 15.0              4.500000
#                                       ZOES KITCHEN                                       1028 OBERLIN RD                        10.0              1.000000
#                                       ZOE`S KITCHEN AT NORTH HILLS                       141-112 PARK AT N HILLS ST             6.0               2.000000
#                                                                                                                                 25.0              8.000000
#                                                                                                                                 29.0              0.000000
#                                       ZPIZZA                                             421-103 FAYETTEVILLE ST                18.0              8.000000
#                                       ÃN                                                 2800 RENAISSANCE PARK PL               25.0             10.000000

# %%
pd.reset_option('display.max_rows') #remove at the end

# %%
#checking data distribution for any need for transformation

# %%
#distribution of same inspectors
sns.distplot(same_df['num_critical']).set_title('Number of Critical Citations by Different Inspectors', x = 0.3)

print('Inspected Previously by Same Inspector')
print(same_df.describe())
print(' ')
# Out:
# Inspected Previously by Same Inspector
#        inspector_id  num_critical  num_non_critical        score
# count   6234.000000   6234.000000       6234.000000  6234.000000
# mean      12.994867      3.207571          5.642284    95.589429
# std        9.098158      3.106676          3.796912     2.757162
# min        1.000000      0.000000          0.000000    72.500000
# 25%        5.000000      1.000000          3.000000    94.000000
# 50%       10.000000      2.000000          5.000000    96.000000
# 75%       22.000000      5.000000          7.000000    97.500000
# max       32.000000     22.000000         33.000000   100.000000

# %%
#plt.hist(diff_df['num_critical'],bins = 23)
sns.distplot(diff_df['num_critical'], color = '#de772f').set_title('Number of Critical Citations by Same Inspectors', x = 0.3)

print('Inspected by Different Inspector')
print(diff_df.describe())
# Out:
# Inspected by Different Inspector
#        inspector_id  num_critical  num_non_critical        score
# count   3693.000000   3693.000000       3693.000000  3693.000000
# mean      14.251557      3.240455          6.252099    95.445708
# std        8.971776      2.925699          3.870685     2.739546
# min        1.000000      0.000000          0.000000    75.000000
# 25%        6.000000      1.000000          4.000000    94.000000
# 50%       13.000000      3.000000          6.000000    96.000000
# 75%       22.000000      5.000000          8.000000    97.500000
# max       32.000000     23.000000         32.000000   100.000000

# %% [markdown]
# Both distribution are skewed to the right and the spread is pretty wide when you look at standard deviation of both distribution.

# %%
#data transformation using log to use for data analysis

same_df = same_df.assign(num_critical10 = same_df['num_critical']+1)
diff_df = diff_df.assign(num_critical10 = diff_df['num_critical']+1)

same_df['num_critical10'] = np.log10(same_df['num_critical10'])
diff_df['num_critical10'] = np.log10(diff_df['num_critical10'])

# %%
#plotting both distribution in one graph
sns.distplot(diff_df['num_critical10'])
sns.distplot(same_df['num_critical10'])

# %% [markdown]
# Data is closer to normal distribution, but now there is signs or bimodality in the distribution or some form of outlier.

# %%
pd.plotting.scatter_matrix(insp_df[['inspector_id','num_critical', 'score']], figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f57223bd828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f572261ec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f57225584a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5722504d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f57224bf748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f572247b128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f57224aaac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f57223a34e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f57223a3518>]],
#       dtype=object)

# %% [markdown]
# Out of the three variables displayed on the scatter matrix. There's a relationship between score and num_critical which makes sense as scores are higher, there are less critical citations.

# %% [markdown]
# # Data Analysis

# %%
#using t-test to compare 
same_crit = same_df['num_critical10']
diff_crit = diff_df['num_critical10']

t_val, p_val = stats.ttest_ind(diff_crit,same_crit)

print(t_val)
print(p_val)
# Out:
# 2.194639532670395
# 0.02821255085512604

# %% [markdown]
# Using a alpha level of 0.01, the p-value is 0.02821 meaning that we fail to reject the null hypothesis that there is no difference between  in the number of critical risk factor reported for different inspectors and the same inspectors.
#
# In short, there is no statically significant difference.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# There was no explicit permission to use this data. Although inspection report--done by public health inspector--are open to the public. To attain explicit permission, I could ask the local county to where the information was attained and ask for permission to use information.
#
# The only privacy concern with the data shown is the inspector's ID, anyone can look up their ID and find their full name online. Otherwise, all other data shown are compliant with the Safe Harbor method for this report.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# My research question is whether restaurants—that are previously inspected by the same inspector —more likely to have more critical citations compared to restaurants that are inspected by a different inspector.
# Based on the analysis using the data--the average number of critical citation done by different inspectors and the average number of critical citation done by the same inspector--my hypothesis that there is a significant difference was rejected. One reason maybe due to the way I grouped my data. Instead of taking the scores of the inspection report and dividing by the inspector, I could've have divided the data by restaraunts that exclusively only have the same inspector and restaurants that only have different inspector upon each inspection, thus having a more distinct groups to analyze.
#
# Even if group the data better, my analysis is very simple, and only touches on the surface of the dataset. It only concluded that there isn't a statistically significant difference between  in the number of critical risk factor reported by different inspectors and the number of critical risk factor report by the same inspector.Evidence from the t-test only implies that the same inspectors tend to give different scores compared to different inspectors. The t-test doesn't give predictive evidence, so there needs to be more analysis, through regression model, to determine whether the same or different inspectors are more likely to give certain scoring or citations.
#
# Another thing to note is the distribution of the data, even after the transformation, the distribution appears to be bimodal, thus there is an underlying data that maybe influences the distribution of the number of critical citations. This could also be done using a regression model and measuring the effect size of different variables.
