# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# *Fill in your overview here*

# %% [markdown]
# # Name & PID
#
# - Name: Sophie Truong
# - PID: A15279448

# %% [markdown]
# # Research Question

# %% [markdown]
# Do health inspection ratings differ based on the socioeconomic areas chain restaurants are located in?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# References found refer to violations in restaurants and how health inspections are done according to the restaurants' socioeconomic locations. It was commonly found that the number of violations positively correlate with populations that have a higher minority concentration and that health inspections are done more frequently in those areas.
#
# In a 2-year study where they explored the outcomes of health inspections in relation to restaurant inspection frequency and neighborhood sociodemographic, chain restaurants were found to have significantly fewer violations per inspection (1). Chain restaurants serve less perishable food so the chance of foodborne illnesses were less likely. Also, the number of total violations per inspection was not associated with any block group sociodemographic characteristics. However, it was also noted that “the number of foodborne-illness risk factor violations per inspection was significantly associated with the proportion of black residents, whereas the number of good retail practice violations per inspection was significantly positively associated with proportion of black residents and hispanics.” The takeaway message of this study was that it doesn’t matter if a restaurant is non-chain or chain; health inspections should be done in a way that focuses more on restaurants in areas that seem to be in higher risk to reduce frequency of violations.
#
# Another study focused on tracking critical health violations (CHV) in communities with different socioeconomic status and demographics. They were able to pinpoint health indicators to specific geographic locations in Philadelphia through geographic information systems (GIS). “Overall, food service facilities in higher poverty areas had a greater number of [food service facilities] (with at least one CHV) and had more frequent inspections than facilities in lower poverty areas. The facilities in lower poverty areas, however, had a higher average number of CHV per inspection” (2). In high concentrations of minority populations, Hispanic facilities had more CHV than other demographics, and Hispanic and African American facilities had fewer days between inspections. This study reveals how subjective health inspections can be and that it indicates that other factors might be affecting inspection frequency and identification of CHV.
#
# References (include links):
# - 1) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3323064/
# - 2) https://www.ncbi.nlm.nih.gov/pubmed/21902922/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# My hypothesis is that chain restaurants in regions associated with lower socioeconomic statuses tend to receive a lower health inspection score. After the research that I have done, I have noticed that there is a trend of more health violations in areas with more residents that have lower income, and that it being chain or non-chain restaurant doesn't have too much of an influence on the outcome.|

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name: df_restaurants
# - Link to the dataset: restaurants.csv
# - Number of observations: 18466
#
# Dataset of restaurants' name and locations. This will be used match their zip codes with df_violations and df_zipcodes to determine their socioeconomic rating.
#
# - Dataset Name: df_violations
# - Link to the dataset: violations.csv
# - Number of observations: 189802
#
# Dataset of violations from restauants with a short description and labels. This will be used match their zip codes with df_restaurants and df_zipcodes to determine their socioeconomic rating.
#
# - Dataset Name: df_zipcodes
# - Link to the dataset: zipcodes.csv
# - Number of observations: 38
#
# Dataset of zipcodes and their associated income and poverty rate. This will be used match their zip codes with df_restaurants and df_violations to determine their socioeconomic rating.

# %% [markdown]
# # Setup

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
# Reading in CSVs
df_inspections = pd.read_csv('inspections.csv')
df_restaurants = pd.read_csv('restaurants.csv')
df_violations = pd.read_csv('violations.csv')
df_yelp = pd.read_csv('yelp.csv')
df_zipcodes = pd.read_csv('zipcodes.csv')

# %%
# inspections
df_inspections
# Out:
#            hsisid                  date  \
# 0      4092013748  2012-09-21T00:00:00Z
# 1      4092014046  2012-09-21T00:00:00Z
# 2      4092015191  2012-09-21T00:00:00Z
# 3      4092016122  2012-09-21T00:00:00Z
# 4      4092021513  2012-09-21T00:00:00Z
# ...           ...                   ...
# 18461  4092021142  2016-11-03T00:00:00Z
# 18462  4092110100  2016-11-03T00:00:00Z
# 18463  4092110487  2016-11-03T00:00:00Z
# 18464  4092300177  2016-11-03T00:00:00Z
# 18465  4092300225  2016-11-03T00:00:00Z
#
#                                            name                      address1  \
# 0                         Cafe 3000 At Wake Med             3000 New Bern Ave
# 1                           Overtime Sports Pub          1030-149 N Rogers Ln
# 2                                TASTE OF CHINA           6209 ROCK QUARRY RD
# 3                            Panera Bread #1643            1065 Darrington DR
# 4      WalMart Supercenter #4499-00 Deli/Bakery              841 E Gannon AVE
# ...                                         ...                           ...
# 18461                                  Sino Wok   5959-1108 Triangle Town Blv
# 18462         Weatherstone Elem. Sch. Cafeteria    1000 Olde Weatherstone Way
# 18463  ALSTON RIDGE ELEMENTARY SCHOOL CAFETERIA  11555 GREEN LEVEL CHURCH  RD
# 18464                Food Lion #996 Meat Market          7971 FAYETTEVILLE RD
# 18465                         LA CAMPANA MARKET           1701 N ARENDELL AVE
#
#       address2     city state  postalcode              phonenumber  \
# 0          NaN  raleigh    NC       27610           (919) 350-8047
# 1          NaN  raleigh    NC       27610           (919) 255-9556
# 2      STE 126  raleigh    NC       27610           (919) 773-2285
# 3          NaN     cary    NC       27513                      NaN
# 4          NaN  zebulon    NC       27597  (919) 269-2221 ext. 304
# ...        ...      ...   ...         ...                      ...
# 18461      NaN  raleigh    NC       27616           (919) 792-2499
# 18462      NaN     cary    NC       27513           (919) 380-6985
# 18463      NaN     cary    NC       27519                      NaN
# 18464      NaN  raleigh    NC  27603-5631           (919) 772-0317
# 18465      NaN  zebulon    NC       27597           (919) 269-0032
#
#          restaurantopendate  ...  num_non_critical num_critical_previous  \
# 0      2002-12-21T00:00:00Z  ...                 7                   NaN
# 1      2004-05-04T00:00:00Z  ...                11                   NaN
# 2      2008-08-04T00:00:00Z  ...                 8                   NaN
# 3      2012-03-28T00:00:00Z  ...                 3                   NaN
# 4      2008-02-25T00:00:00Z  ...                 4                   NaN
# ...                     ...  ...               ...                   ...
# 18461  2002-08-19T00:00:00Z  ...                13                   1.0
# 18462  1995-09-05T00:00:00Z  ...                 3                   2.0
# 18463  2009-11-13T00:00:00Z  ...                 4                   0.0
# 18464  2000-07-01T00:00:00Z  ...                 2                   0.0
# 18465  2005-03-31T00:00:00Z  ...                 7                   5.0
#
#        num_non_critical_previous  num_critical_mean_previous  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 18461                        4.0                    1.000000
# 18462                        5.0                    0.750000
# 18463                        2.0                    0.875000
# 18464                        3.0                    1.111111
# 18465                        8.0                    4.250000
#
#       num_non_critical_mean_previous  avg_neighbor_num_critical  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
# ...                              ...                        ...
# 18461                       4.777778                   4.692525
# 18462                       3.250000                   5.853333
# 18463                       1.750000                   2.466667
# 18464                       2.000000                   3.737302
# 18465                       6.375000                   2.048810
#
#       avg_neighbor_num_non_critical     top_match  second_match  critical
# 0                               NaN           NaN           NaN         1
# 1                               NaN           NaN           NaN         0
# 2                               NaN           NaN           NaN         1
# 3                               NaN           NaN           NaN         1
# 4                               NaN           NaN           NaN         1
# ...                             ...           ...           ...       ...
# 18461                      9.863838  4.092022e+09  4.092017e+09         1
# 18462                      5.972381  4.092013e+09  4.092016e+09         1
# 18463                      3.000000  4.092017e+09  4.092015e+09         1
# 18464                      4.606349  4.092016e+09  4.092015e+09         1
# 18465                      3.235714  4.092016e+09  4.092015e+09         1
#
# [18466 rows x 36 columns]

# %%
# restaurants
df_restaurants
# Out:
#       X.objectid      hsisid                                      name  \
# 0           1001  4092017230                             SPRING CAFE 2
# 1           1002  4092040338  CAROLINA CLASSIC HOT DOGS #2 (WCID #549)
# 2           1003  4092014444                          Taco Bell #22798
# 3           1004  4092015333                          THE REMEDY DINER
# 4           1005  4092160069                   ZEBULON HOUSE (KITCHEN)
# ...          ...         ...                                       ...
# 3319        2996  4092016658                             LA ROMA PIZZA
# 3320        2997  4092016663                              BOJANGLES #5
# 3321        2998  4092016557                        BURGER KING #19795
# 3322        2999  4092017227                                   QUICKLY
# 3323        3000  4092017274               HARRIS TEETER #43 STARBUCKS
#
#                         address1 address2         city state  postalcode  \
# 0     2900-104 SPRING FOREST RD       NaN      RALEIGH    NC  27616-1895
# 1               309 HOLLOMAN ST       NaN         APEX    NC       27502
# 2                2207 S MAIN ST       NaN  WAKE FOREST    NC       27587
# 3              137 E HARGETT ST       NaN      RALEIGH    NC       27601
# 4                   551 PONY RD       NaN      ZEBULON    NC       27597
# ...                          ...      ...          ...   ...         ...
# 3319             1322 FIFTH AVE       NaN       GARNER    NC       27529
# 3320       3301 S WILMINGTON ST       NaN      RALEIGH    NC       27603
# 3321            22114 S MAIN ST       NaN  Wake Forest    NC       27587
# 3322              4141 DAVIS DR       NaN  MORRISVILLE    NC       27560
# 3323             3638 ROGERS RD       NaN  WAKE FOREST    NC       27587
#
#          phonenumber        restaurantopendate                facilitytype  \
# 0     (919) 977-3679  2016-05-26T00:00:00.000Z                  Restaurant
# 1                NaN  2016-07-01T00:00:00.000Z                   Pushcarts
# 2     (919) 554-4924  2005-12-05T00:00:00.000Z                  Restaurant
# 3     (919) 835-3553  2009-02-04T00:00:00.000Z                  Restaurant
# 4                NaN  2009-02-18T00:00:00.000Z  Institutional Food Service
# ...              ...                       ...                         ...
# 3319  (919) 662-1700  2014-04-03T00:00:00.000Z                  Restaurant
# 3320  (919) 772-4512  2014-04-08T00:00:00.000Z                  Restaurant
# 3321  (919) 556-7773  2013-10-31T00:00:00.000Z                  Restaurant
# 3322  (984) 465-0347  2016-05-19T00:00:00.000Z                  Restaurant
# 3323  (919) 562-9521  2016-06-24T00:00:00.000Z                  Restaurant
#
#               x          y geocodestatus
# 0    -78.591634  35.855487             M
# 1    -78.855348  35.730219             M
# 2    -78.536145  35.946695             M
# 3    -78.636895  35.777999             M
# 4    -78.332138  35.816779             M
# ...         ...        ...           ...
# 3319 -78.621859  35.709485             M
# 3320 -78.649803  35.735063             M
# 3321   0.000000   0.000000             U
# 3322 -78.858116  35.835626             M
# 3323 -78.504827  35.944642             M
#
# [3324 rows x 14 columns]

# %%
# violations
df_violations
# Out:
#         X.objectid      hsisid               inspectdate  category  \
# 0             2149  4092015279  2014-09-22T00:00:00.000Z  Chemical
# 1             2150  4092014572  2014-09-29T00:00:00.000Z  Chemical
# 2             2151  4092015906  2014-10-01T00:00:00.000Z  Chemical
# 3             2152  4092013840  2014-10-08T00:00:00.000Z  Chemical
# 4             2153  4092021788  2014-10-09T00:00:00.000Z  Chemical
# ...            ...         ...                       ...       ...
# 189797        2144  4092015549  2014-09-10T00:00:00.000Z  Chemical
# 189798        2145  4092016135  2014-09-11T00:00:00.000Z  Chemical
# 189799        2146  4092020997  2014-09-12T00:00:00.000Z  Chemical
# 189800        2147  4092021798  2014-09-19T00:00:00.000Z  Chemical
# 189801        2148  4092015279  2014-09-22T00:00:00.000Z  Chemical
#
#           statecode critical  questionno violationcode             severity  \
# 0       .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 1       .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 2       .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 3       .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 4       .2653,.2657      Yes          26      7-102.11  Priority Foundation
# ...             ...      ...         ...           ...                  ...
# 189797  .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 189798  .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 189799  .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 189800  .2653,.2657      Yes          26      7-102.11  Priority Foundation
# 189801  .2653,.2657      Yes          26      7-102.11  Priority Foundation
#
#                                                 shortdesc     inspectedby  \
# 0       Toxic substances properly identified, stored, ...     Lucy Schrum
# 1       Toxic substances properly identified, stored, ...   Daryl Beasley
# 2       Toxic substances properly identified, stored, ...     Lucy Schrum
# 3       Toxic substances properly identified, stored, ...     Lucy Schrum
# 4       Toxic substances properly identified, stored, ...     Lucy Schrum
# ...                                                   ...             ...
# 189797  Toxic substances properly identified, stored, ...     Lucy Schrum
# 189798  Toxic substances properly identified, stored, ...     James Smith
# 189799  Toxic substances properly identified, stored, ...   Andrea Anover
# 189800  Toxic substances properly identified, stored, ...  Thomas Jumalon
# 189801  Toxic substances properly identified, stored, ...     Lucy Schrum
#
#                                                  comments  pointvalue  \
# 0       7-102.11; Priority Foundation - Found unlabele...           0
# 1       7-102.11; Priority Foundation; One sanitizer b...           0
# 2       7-102.11; Priority Foundation - Found an unlab...           1
# 3       7-102.11; Priority Foundation - Found unlabele...           0
# 4       7-102.11; Priority Foundation - Found one unla...           0
# ...                                                   ...         ...
# 189797  7-102.11; Priority Foundation - Found a few un...           0
# 189798  7-102.11; Priority Foundation;  Spray bottle o...           1
# 189799  7-102.11; Priority Foundation; 1 bottle of oil...           0
# 189800  7-102.11; Priority Foundation;  REQUIRES CHEMC...           1
# 189801  7-102.11; Priority Foundation - Found unlabele...           0
#
#        observationtype violationtype  count cdcriskfactor cdcdataitem
# 0                  Out             R    NaN           NaN         NaN
# 1                  Out           CDI    NaN           NaN         NaN
# 2                  Out           CDI    NaN           NaN         NaN
# 3                  Out           CDI    NaN           NaN         NaN
# 4                  Out           CDI    NaN           NaN         NaN
# ...                ...           ...    ...           ...         ...
# 189797             Out           CDI    NaN           NaN         NaN
# 189798             Out             R    NaN           NaN         NaN
# 189799             Out           CDI    NaN           NaN         NaN
# 189800             Out           NaN    NaN           NaN         NaN
# 189801             Out           CDI    NaN           NaN         NaN
#
# [189802 rows x 18 columns]

# %%
# zipcodes
df_zipcodes
# Out:
#       zip  median_family_income_dollars  median_household_income_dollars  \
# 0   27501                         59408                            51121
# 1   27502                        109891                            95857
# 2   27511                         82292                            67392
# 3   27513                        109736                            87262
# 4   27518                        125432                            98247
# 5   27519                        137193                           121815
# 6   27520                         67939                            58455
# 7   27522                         66250                            59221
# 8   27523                         89184                            68342
# 9   27526                         74666                            66025
# 10  27529                         68627                            59613
# 11  27539                         88121                            82614
# 12  27540                         96650                            88638
# 13  27545                         72301                            60825
# 14  27560                         97917                            80324
# 15  27562                         71161                            61097
# 16  27571                         86250                            81809
# 17  27587                         96247                            83416
# 18  27591                         59892                            50868
# 19  27592                         66160                            56747
# 20  27596                         68750                            59712
# 21  27597                         59395                            51266
# 22  27601                         28641                            27564
# 23  27603                         68608                            54889
# 24  27604                         57419                            50365
# 25  27605                        109886                            49309
# 26  27606                         61324                            44422
# 27  27607                         85325                            53825
# 28  27608                        125019                            83986
# 29  27609                         73715                            53640
# 30  27610                         49213                            45209
# 31  27612                         98452                            68864
# 32  27613                        106854                            79698
# 33  27614                        119232                            94727
# 34  27615                         98884                            78378
# 35  27616                         60033                            56323
# 36  27617                         98642                            76959
# 37  27703                         60783                            54674
#
#     per_capita_income_dollars  percent_damilies_below_poverty_line  \
# 0                       21631                                 10.5
# 1                       36763                                  3.4
# 2                       33139                                  9.6
# 3                       41232                                  3.8
# 4                       49865                                  5.5
# 5                       45778                                  3.2
# 6                       25628                                  5.0
# 7                       25513                                  6.0
# 8                       36976                                  3.1
# 9                       28074                                  8.4
# 10                      25807                                  9.5
# 11                      34877                                  2.2
# 12                      33308                                  3.0
# 13                      26568                                  6.1
# 14                      38830                                  3.6
# 15                      31161                                 10.4
# 16                      30502                                  8.2
# 17                      34731                                  5.5
# 18                      24239                                 10.1
# 19                      23355                                  6.3
# 20                      26241                                  5.6
# 21                      21573                                 11.3
# 22                      17363                                 35.9
# 23                      27843                                 12.6
# 24                      25532                                 14.4
# 25                      42632                                  4.1
# 26                      25385                                 13.8
# 27                      26007                                 12.8
# 28                      59155                                  5.5
# 29                      39008                                  8.9
# 30                      19207                                 19.2
# 31                      45080                                  5.5
# 32                      42435                                  4.7
# 33                      45317                                  3.7
# 34                      44747                                  4.2
# 35                      24549                                 11.7
# 36                      49205                                  2.0
# 37                      24280                                 12.7
#
#     percent_snap_benefits  percent_supplemental_security_income  \
# 0                    15.5                                   5.2
# 1                     2.4                                   0.8
# 2                     4.5                                   2.2
# 3                     2.4                                   1.5
# 4                     1.0                                   1.7
# 5                     2.3                                   2.3
# 6                     7.8                                   2.4
# 7                     7.0                                   4.2
# 8                     3.1                                   1.8
# 9                     8.3                                   3.9
# 10                    7.6                                   4.8
# 11                    4.1                                   1.4
# 12                    4.5                                   2.4
# 13                    6.1                                   1.8
# 14                    3.9                                   1.1
# 15                    1.4                                  15.4
# 16                   12.6                                   3.7
# 17                    6.4                                   3.2
# 18                   12.9                                   3.0
# 19                    7.2                                   1.9
# 20                    9.6                                   4.1
# 21                   15.5                                   7.5
# 22                   33.5                                  10.8
# 23                   10.4                                   3.8
# 24                   10.2                                   3.8
# 25                    6.5                                   4.0
# 26                    7.6                                   2.0
# 27                    8.8                                   3.9
# 28                    2.6                                   2.7
# 29                    9.0                                   1.6
# 30                   16.9                                   5.9
# 31                    4.8                                   1.3
# 32                    4.2                                   1.7
# 33                    3.3                                   1.2
# 34                    4.2                                   1.5
# 35                   10.6                                   4.6
# 36                    1.3                                   0.5
# 37                   15.4                                   3.6
#
#     percent_nonwhite
# 0               17.9
# 1               18.9
# 2               24.8
# 3               27.8
# 4               19.9
# 5               35.2
# 6               23.5
# 7               31.4
# 8               22.4
# 9               22.5
# 10              33.9
# 11              19.0
# 12              19.7
# 13              44.4
# 14              53.3
# 15              13.6
# 16              17.4
# 17              18.0
# 18              32.8
# 19              14.6
# 20              18.9
# 21              26.3
# 22              69.9
# 23              25.6
# 24              41.3
# 25              14.8
# 26              31.8
# 27              25.0
# 28               8.7
# 29              27.2
# 30              72.7
# 31              23.2
# 32              22.6
# 33              16.6
# 34              19.6
# 35              52.6
# 36              30.4
# 37              61.5

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
# to later use to merge 
df_zipcodes.rename(columns={'zip':'postalcode'}, inplace=True)

df_zipcodes['postalcode'] = df_zipcodes['postalcode'].astype(str)

# %%
# matching restaurants and their violations using their IDs
df_restViol = pd.merge(left = df_restaurants, right = df_violations, left_on = 'X.objectid', right_on = 'X.objectid') 
df_restViol.head()
# Out:
#    X.objectid    hsisid_x                                      name  \
# 0        1001  4092017230                             SPRING CAFE 2
# 1        1002  4092040338  CAROLINA CLASSIC HOT DOGS #2 (WCID #549)
# 2        1003  4092014444                          Taco Bell #22798
# 3        1004  4092015333                          THE REMEDY DINER
# 4        1005  4092160069                   ZEBULON HOUSE (KITCHEN)
#
#                      address1 address2         city state  postalcode  \
# 0  2900-104 SPRING FOREST RD       NaN      RALEIGH    NC  27616-1895
# 1            309 HOLLOMAN ST       NaN         APEX    NC       27502
# 2             2207 S MAIN ST       NaN  WAKE FOREST    NC       27587
# 3           137 E HARGETT ST       NaN      RALEIGH    NC       27601
# 4                551 PONY RD       NaN      ZEBULON    NC       27597
#
#       phonenumber        restaurantopendate  ...             severity  \
# 0  (919) 977-3679  2016-05-26T00:00:00.000Z  ...  Priority Foundation
# 1             NaN  2016-07-01T00:00:00.000Z  ...  Priority Foundation
# 2  (919) 554-4924  2005-12-05T00:00:00.000Z  ...  Priority Foundation
# 3  (919) 835-3553  2009-02-04T00:00:00.000Z  ...  Priority Foundation
# 4             NaN  2009-02-18T00:00:00.000Z  ...  Priority Foundation
#
#                                            shortdesc    inspectedby  \
# 0  Required records available: shellstock tags, p...  Karla Crowder
# 1  Required records available: shellstock tags, p...    Lucy Schrum
# 2  Required records available: shellstock tags, p...    Lucy Schrum
# 3  Required records available: shellstock tags, p...  Karla Crowder
# 4  Required records available: shellstock tags, p...    Chris Askew
#
#                                             comments  pointvalue  \
# 0  3-402.12;(C) If raw, raw-marinated, partially ...           1
# 1  Pf - 3-402.12 - Observed improper parasite des...           0
# 2  Pf - 3-402.12 - Observed improper parasite des...           0
# 3  3-402.12; Priority Foundation; A written agree...           1
# 4  3-402.12;No records stating that aquacultered ...           0
#
#   observationtype violationtype count            cdcriskfactor  cdcdataitem
# 0             Out            VR   NaN  Food from Unsafe Source      Records
# 1             Out           CDI   NaN  Food from Unsafe Source      Records
# 2             Out             R   NaN  Food from Unsafe Source      Records
# 3             Out           CDI   NaN  Food from Unsafe Source      Records
# 4             Out           CDI   NaN  Food from Unsafe Source      Records
#
# [5 rows x 31 columns]

# %%
# combining df_zipcodes, df_restaurants, and df_violations based on their postal code
df_zipRestViol = pd.merge(left = df_zipcodes, right = df_restViol, left_on = 'postalcode', right_on = 'postalcode') 
lowest_income = df_zipRestViol['median_household_income_dollars'].min()
highest_income = df_zipRestViol['median_household_income_dollars'].max()
average_income = (lowest_income + highest_income)/ 2

# getting numbers for income
print('lowest avg household income: ', lowest_income)
print('highest avg household income: ', highest_income)
print('average household income: ', average_income)
# Out:
# lowest avg household income:  27564
# highest avg household income:  121815
# average household income:  74689.5

# %%
# dataframe for areas where household have less than the average income
df_belowAvgIncome = df_zipRestViol.loc[df_zipRestViol['median_household_income_dollars'] < average_income]

# using only necessary columns
df_cleanBelowAvgIncome = df_belowAvgIncome[['postalcode', 'median_household_income_dollars', 'percent_damilies_below_poverty_line', 'X.objectid',
                                             'name', 'facilitytype', 'category', 'critical', 'questionno', 'violationcode', 'severity',
                                           'shortdesc', 'comments', 'pointvalue', 'violationtype']]
# fixing column title
df_cleanBelowAvgIncome.rename(columns={'percent_damilies_below_poverty_line':'percent_below_poverty_line'}, inplace=True)
df_cleanBelowAvgIncome.head()
# Out:
#     postalcode  median_household_income_dollars  percent_below_poverty_line  \
# 0        27501                            51121                        10.5
# 116      27511                            67392                         9.6
# 117      27511                            67392                         9.6
# 118      27511                            67392                         9.6
# 119      27511                            67392                         9.6
#
#      X.objectid                     name facilitytype  category critical  \
# 0          1530         FILIPINO CUISINE   Restaurant  Chemical      Yes
# 116        1037               CHINA CARY   Restaurant  Chemical      Yes
# 117        1091  Harris Teeter #257 Deli   Restaurant  Chemical      Yes
# 118        1124      CARIBOU COFFEE #306   Restaurant  Chemical       No
# 119        1129        CASABLANCA MARKET  Meat Market  Chemical       No
#
#      questionno violationcode             severity  \
# 0            26      7-102.11  Priority Foundation
# 116          26      7-102.11  Priority Foundation
# 117          26      7-102.11  Priority Foundation
# 118          26      7-209.11                 Core
# 119          26      7-209.11                 Core
#
#                                              shortdesc  \
# 0    Toxic substances properly identified, stored, ...
# 116  Toxic substances properly identified, stored, ...
# 117  Toxic substances properly identified, stored, ...
# 118  Toxic substances properly identified, stored, ...
# 119  Toxic substances properly identified, stored, ...
#
#                                               comments  pointvalue  \
# 0    Pf - 7-102.11 - Found two unlabeled bottles of...           0
# 116  7-102.11/Pf; Bottle of green liquid mislabeled...           1
# 117  Pf - 7-102.11 - Found one bottle labeled "blea...           1
# 118  7-209.11 - Bottle of medication on same shelf ...           0
# 119  7-209.11 ; Core; Soap, shampoo and body wash s...           1
#
#     violationtype
# 0               R
# 116           NaN
# 117           CDI
# 118           CDI
# 119           CDI

# %%
# dataframe for areas where household have the average income or higher
df_AvgIncomeOrHigher = df_zipRestViol.loc[df_zipRestViol['median_household_income_dollars'] >= average_income]# using only necessary columns

# getting necessary columns
df_cleanAvgIncomeOrHigher = df_AvgIncomeOrHigher[['postalcode', 'median_household_income_dollars', 'percent_damilies_below_poverty_line', 'X.objectid',
                                             'name', 'facilitytype', 'category', 'critical', 'questionno', 'violationcode', 'severity',
                                           'shortdesc', 'comments', 'pointvalue', 'violationtype']]
# fixing column title
df_cleanAvgIncomeOrHigher.rename(columns={'percent_damilies_below_poverty_line':'percent_below_poverty_line'}, inplace=True)
df_cleanBelowAvgIncome.head()
# Out:
#     postalcode  median_household_income_dollars  percent_below_poverty_line  \
# 0        27501                            51121                        10.5
# 116      27511                            67392                         9.6
# 117      27511                            67392                         9.6
# 118      27511                            67392                         9.6
# 119      27511                            67392                         9.6
#
#      X.objectid                     name facilitytype  category critical  \
# 0          1530         FILIPINO CUISINE   Restaurant  Chemical      Yes
# 116        1037               CHINA CARY   Restaurant  Chemical      Yes
# 117        1091  Harris Teeter #257 Deli   Restaurant  Chemical      Yes
# 118        1124      CARIBOU COFFEE #306   Restaurant  Chemical       No
# 119        1129        CASABLANCA MARKET  Meat Market  Chemical       No
#
#      questionno violationcode             severity  \
# 0            26      7-102.11  Priority Foundation
# 116          26      7-102.11  Priority Foundation
# 117          26      7-102.11  Priority Foundation
# 118          26      7-209.11                 Core
# 119          26      7-209.11                 Core
#
#                                              shortdesc  \
# 0    Toxic substances properly identified, stored, ...
# 116  Toxic substances properly identified, stored, ...
# 117  Toxic substances properly identified, stored, ...
# 118  Toxic substances properly identified, stored, ...
# 119  Toxic substances properly identified, stored, ...
#
#                                               comments  pointvalue  \
# 0    Pf - 7-102.11 - Found two unlabeled bottles of...           0
# 116  7-102.11/Pf; Bottle of green liquid mislabeled...           1
# 117  Pf - 7-102.11 - Found one bottle labeled "blea...           1
# 118  7-209.11 - Bottle of medication on same shelf ...           0
# 119  7-209.11 ; Core; Soap, shampoo and body wash s...           1
#
#     violationtype
# 0               R
# 116           NaN
# 117           CDI
# 118           CDI
# 119           CDI

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Issues related to my topic area could include certain chain restaurants gaining less business and worst case scenario, possibly shutting down. Analyses that are potentially problematic in terms of data privacy are that people may find specific restaurant locations. Workers may be harassed as a result. However, to mitigate these issues, I would leave out names of restaurants and what city they belong to in my analysis. I would classify the restaurants as Restaurant 1 or Restaurant 2 in which socioeconomic status the city has. They would be described as Restaurant 1 in the high socioeconomic city.
#
# Race might be tracked down due to the bias that poorer neighborhoods are associated with minorities. I would try to minimize this risk by leaving out any way to identify the neighborhoods such as leaving out zipcodes or descriptions of the area.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*
