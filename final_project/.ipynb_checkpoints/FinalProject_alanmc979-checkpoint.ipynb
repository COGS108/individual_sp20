# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# *Fill in your overview here*

# %% [markdown]
# # Name & GitHub
#
# - Name: Alan Madrigal
# - GitHub Username: alanmc979

# %% [markdown]
# # Research Question

# %% [raw]
# Is there a correlation between the income in an area and the a restaurant's food inspection score? Can we predicted how likely a restaurant in North Carolina is to violate the local food health policy, by looking at the relationship between food policy violations and the type of food each restaurant serves? Will Yelp rating help us go to the safest restaurant's?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# First Reference: I found a similar work to what I am looking for in the city of Chicago. They showed how they predict food inspection violations which are similar to what I want to accomplish for the city of San Diego. Their method found out that they were able to improve the inspection process by finding faster the places that had food policy violations. By finding violations faster they help reduce food poisoning cases in that area.
#
# Second Reference: In the second reference, I found how the city of San Diego makes inspects restaurants.
# - 1. Each violation of the Food Inspection Report is assigned a point value depending on its importance. For example, a Major Risk Factor is worth four points, a Minor Risk Factor is worth two, and a Good Retail Practice is worth one.
# - 2. Once the Specialist completes an inspection, the points are added up and subtracted from 100. The resulting number is the inspection "score".
# - 3. A letter grade is assigned to the facility based on the inspection score. An "A" grade means the facility earned a score of 90 to 100 percent and is in satisfactory compliance with state law; a "B" means the facility earned a score of 80 to 89 percent and needs improvement; a "C" means the facility earned a score of 79 percent or less and is a failing grade.
# - 4. The grade card must be displayed near the public entrance during hours of operation. This information allows me to understand how data can be used. This information about the scoring of every place can be helpful for the prediction algorithm.
#
# Third Reference:
#     Food-borne illness affects an estimated 48 million Americans each year, resulting in 3,000 deaths and the hospitalization of 128,000 people, according to the Centers for Disease Control and Prevention (CDC). Beyond that, food-borne illness in the U.S. is enormously costly, with an estimated collective annual bill of $55 billion in medical treatment, lost productivity, and lost wages, not to mention litigation expenses. This article makes an emphasis on the impact of food poisoning and how important it is to prevent it. It also takes into consideration how inspection biases can hurt the inspection process. Hence we found that answering this data science question can help prevent food poisoning and improve the inspection process in San Diego. But we should focus on having accurate data from the inspectors without biases.
#
# References (include links):
# - 1) https://chicago.github.io/food-inspections-evaluation/
# - 2)https://www.sandiegocounty.gov/content/sdc/deh/fhd/ffis/intro.html.html
# - 3)https://hbr.org/2019/05/to-improve-food-inspections-change-the-way-theyre-scheduled
# - 4)https://www.forsyth.cc/PublicHealth/EnvironmentalHealth/aboutInspections.aspx

# %% [markdown]
# # Hypothesis

# %% [markdown]
# I believe that there is a relationship between the type of food a restaurant serves and their number of critical and non_critical violations they get. Also, I believe that Yelp is a reliable for selecting based on rating the restaurants that have less critical violations and better scores. Food poisoning is more likely to happen with certain types of food, therefore I believe there must be a relation between food policy violations and the type of food the restaurant serves. Hence by detecting the restaurants that are more likely to violate food policies, we can prioritize the restaurants to inspect first and this should improve the inspection process.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# The ideal data set will have the following variables: Name (of the restaurant), Type of food (the restaurant serves), Food Inspection Grade (0-100) Number of previous year violations The data will be stored in multiple spreadsheets, each sheet for each year, which should have as many observations as the number of restaurants in San Diego. This can be stored in a CSV for easy manipulation with the Pandas module. By having all this information we can determine the relationship between the type of food and food policy violations, as well as to set a queue, with this information, for the order of the next restaurants’ inspection to find food policy violations faster.
#
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name:
# - Link to the dataset:
# - Number of observations:
#
# 1-2 sentences describing each dataset.
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.
#
#
#
#
#
#
# Field
#
# Description
#
# HSISID
#
# State code identifying the restaurant (also the primary key to identify the restaurant)
#
# Name
#
# Name of the restaurant
#
# Address1
#
# Street address portion of the physical address of the restaurant
#
# Address2
#
# Street address portion of the physical address of the restaurant
#
# City
#
# City portion of the physical address of the restaurant
#
# State
#
# State portion of the physical address of the restaurant
#
# PostalCode
#
# Postal Code (Zip Code) portion of the physical address of the restaurant
#
# PhoneNumber
#
# Phone number of the restaurant
#
# RestaurantOpenDate
#
# Date that the restaurant opened for business
#
# FacilityType
#
# Restaurant, Food Stand, Mobile Food Unit, etc.
#
# X
#
# Coordinates of the restaurant location (X)
#
# Y
#
# Coordinates of the restaurant location (Y)
#
# GeocodeStatus
#
# Describes whether this particular record was geocoded, meaning the address that is listed was able to be matched
#
# to coordinates. M = Matched, U = Unmatched, T = Tied
#
# PermitID
#
# The permit issued for this facility
#
# Restaurants Metadata:
#
# | Field | Description|
# | --- | --- |
# | HSISID | .8 |
# | Name | .8 |
# | Address1 | .8 |
# | Address2 | .8 |
# | City | .8 |
# | State | .8 |
# | Postal/Code | .8 |
# | PhoneNumber | .8 |
# | RestaurantOpenDate | .8 |
# | FacilityType | .8 |
# | X | .8 |
# | Y | .8 |
# | GeocodeStatus | .8 |
# | PermitID | .8 |

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import collections
import numpy as np
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns, numpy as np
import patsy
pd.set_option('display.max_columns', None)

# %%
#Data Set
df_insp = pd.read_csv('./data/inspections.csv')
df_yelp = pd.read_csv('./data/yelp.csv')
df_zip = pd.read_csv('./data/zipcodes.csv')
df_restaurants = pd.read_csv('./data/restaurants.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %%
#check out data 
df_insp.head(3)
# Out:
#        hsisid                  date                   name  \
# 0  4092013748  2012-09-21T00:00:00Z  Cafe 3000 At Wake Med
# 1  4092014046  2012-09-21T00:00:00Z    Overtime Sports Pub
# 2  4092015191  2012-09-21T00:00:00Z         TASTE OF CHINA
#
#                address1 address2     city state postalcode     phonenumber  \
# 0     3000 New Bern Ave      NaN  raleigh    NC      27610  (919) 350-8047
# 1  1030-149 N Rogers Ln      NaN  raleigh    NC      27610  (919) 255-9556
# 2   6209 ROCK QUARRY RD  STE 126  raleigh    NC      27610  (919) 773-2285
#
#      restaurantopendate  days_from_open_date facilitytype          x  \
# 0  2002-12-21T00:00:00Z                 3562   Restaurant -78.587963
# 1  2004-05-04T00:00:00Z                 3062   Restaurant -78.549673
# 2  2008-08-04T00:00:00Z                 1509   Restaurant -78.547960
#
#            y geocodestatus    zip        type  \
# 0  35.783914             M  27610  Inspection
# 1  35.791986             M  27610  Inspection
# 2  35.723125             M  27610  Inspection
#
#                                          description         inspectedby  \
# 0  This facility cooks eggs to order in Grill sta...    Melissa Harrison
# 1                                                NaN  Christopher Walker
# 2                                                NaN        Anne Bartoli
#
#    inspection_num  inspector_id previous_inspection_date  \
# 0               1          27.0                      NaN
# 1               1           7.0                      NaN
# 2               1           3.0                      NaN
#
#    days_since_previous_inspection previous_inspection_by_same_inspector  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
#
#    score  num_critical  num_non_critical  num_critical_previous  \
# 0   96.0             9                 7                    NaN
# 1   98.0             0                11                    NaN
# 2   97.0             4                 8                    NaN
#
#    num_non_critical_previous  num_critical_mean_previous  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
#
#    num_non_critical_mean_previous  avg_neighbor_num_critical  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
#
#    avg_neighbor_num_non_critical  top_match  second_match  critical
# 0                            NaN        NaN           NaN         1
# 1                            NaN        NaN           NaN         0
# 2                            NaN        NaN           NaN         1

# %%
df_insp.describe()
# Out:
#              hsisid  days_from_open_date             x             y  \
# count  1.846600e+04         18466.000000  18466.000000  18466.000000
# mean   4.092039e+09          3262.693274    -78.674401     35.802919
# std    6.235295e+04          2569.271482      0.118368      0.083128
# min    4.092010e+09          -160.000000    -78.941986     35.539550
# 25%    4.092015e+09          1069.000000    -78.774820     35.763133
# 50%    4.092016e+09          2733.000000    -78.668185     35.797836
# 75%    4.092022e+09          4884.750000    -78.600152     35.856202
# max    4.092300e+09         10947.000000    -78.271228     36.051133
#
#                 zip  inspection_num  inspector_id  \
# count  18466.000000    18466.000000  18461.000000
# mean   27577.605816        4.191216     13.751151
# std       44.168085        2.578251      9.350358
# min    27501.000000        1.000000      1.000000
# 25%    27529.000000        2.000000      6.000000
# 50%    27603.000000        4.000000     11.000000
# 75%    27610.000000        6.000000     22.000000
# max    28587.000000       16.000000     32.000000
#
#        days_since_previous_inspection         score  num_critical  \
# count                    15421.000000  18466.000000  18466.000000
# mean                       192.886259     96.235324      2.844308
# std                         83.476608      2.654203      2.809652
# min                          0.000000     72.500000      0.000000
# 25%                        140.000000     95.000000      1.000000
# 50%                        182.000000     97.000000      2.000000
# 75%                        228.000000     98.000000      4.000000
# max                       1083.000000    100.000000     23.000000
#
#        num_non_critical  num_critical_previous  num_non_critical_previous  \
# count      18466.000000           15421.000000               15421.000000
# mean           5.161432               2.922962                   5.257052
# std            3.679451               2.831160                   3.738389
# min            0.000000               0.000000                   0.000000
# 25%            3.000000               1.000000                   3.000000
# 50%            4.000000               2.000000                   4.000000
# 75%            7.000000               4.000000                   7.000000
# max           33.000000              23.000000                  33.000000
#
#        num_critical_mean_previous  num_non_critical_mean_previous  \
# count                15421.000000                    15421.000000
# mean                     3.276783                        5.539424
# std                      2.320130                        3.201003
# min                      0.000000                        0.000000
# 25%                      1.600000                        3.000000
# 50%                      2.800000                        5.000000
# 75%                      4.428571                        7.250000
# max                     23.000000                       27.000000
#
#        avg_neighbor_num_critical  avg_neighbor_num_non_critical     top_match  \
# count               18460.000000                   18460.000000  1.846000e+04
# mean                    3.374616                       5.738676  4.092031e+09
# std                     1.563459                       2.100702  5.212564e+04
# min                     0.000000                       0.800000  4.092010e+09
# 25%                     2.190000                       4.294444  4.092014e+09
# 50%                     3.167976                       5.400000  4.092016e+09
# 75%                     4.273333                       6.800000  4.092021e+09
# max                    10.518095                      16.333333  4.092300e+09
#
#        second_match      critical
# count  1.846000e+04  18466.000000
# mean   4.092036e+09      0.818044
# std    6.600398e+04      0.385819
# min    4.092010e+09      0.000000
# 25%    4.092014e+09      1.000000
# 50%    4.092016e+09      1.000000
# 75%    4.092021e+09      1.000000
# max    4.092300e+09      1.000000

# %%
df_yelp.head(3)
# Out:
#                                                id  \
# 0  42nd-street-oyster-bar-rdu-airport-morrisville
# 1                                 aldi-foods-cary
# 2   luciano-pizzeria-ristorante-northwest-raleigh
#
#                                    name  is_closed  rating  review_count  \
# 0  42nd street oyster bar - rdu airport      False     2.5            23
# 1                            aldi foods      False     4.0            17
# 2           luciano pizzeria ristorante      False     5.0             2
#
#                   address1  zip_code   latitude  longitude price        phone  \
# 0  2400 John Brantley Blvd     27560  35.873808 -78.790896    $$          NaN
# 1       2303 NW Maynard Rd     27519  35.802840 -78.785930     $          NaN
# 2     Crabtree Valley Mall     27612  35.839681 -78.678791     $  12102230500
#
#    hotdogs  sandwiches  pizza  tradamerican  burgers  mexican  grocery  \
# 0    False       False  False         False    False    False    False
# 1    False       False  False         False    False    False     True
# 2    False       False  False         False    False    False    False
#
#    breakfast_brunch  coffee  chinese  italian  newamerican  chicken_wings  \
# 0              True   False    False    False         True          False
# 1             False   False    False    False        False          False
# 2             False   False    False     True        False          False
#
#    delis   bars  salad  seafood    bbq  bakeries  sushi
# 0  False  False  False     True  False     False  False
# 1  False  False  False    False  False     False  False
# 2  False  False  False    False  False     False  False

# %%
df_yelp.describe()
# Out:
#             rating  review_count      zip_code     latitude    longitude
# count  3688.000000   3688.000000   3688.000000  3688.000000  3688.000000
# mean      3.625407     46.025217  27583.225868    35.814380   -78.710406
# std       0.880160     82.669767    251.543699     0.117426     0.188572
# min       1.000000      1.000000  15035.000000    34.730420   -80.652878
# 25%       3.000000      6.000000  27526.000000    35.770085   -78.809305
# 50%       3.500000     18.000000  27603.000000    35.808073   -78.687993
# 75%       4.000000     52.000000  27612.000000    35.881480   -78.621470
# max       5.000000   1799.000000  32256.000000    36.431580   -76.777380

# %%
df_zip.head(10)
# Out:
#      zip  median_family_income_dollars  median_household_income_dollars  \
# 0  27501                         59408                            51121
# 1  27502                        109891                            95857
# 2  27511                         82292                            67392
# 3  27513                        109736                            87262
# 4  27518                        125432                            98247
# 5  27519                        137193                           121815
# 6  27520                         67939                            58455
# 7  27522                         66250                            59221
# 8  27523                         89184                            68342
# 9  27526                         74666                            66025
#
#    per_capita_income_dollars  percent_damilies_below_poverty_line  \
# 0                      21631                                 10.5
# 1                      36763                                  3.4
# 2                      33139                                  9.6
# 3                      41232                                  3.8
# 4                      49865                                  5.5
# 5                      45778                                  3.2
# 6                      25628                                  5.0
# 7                      25513                                  6.0
# 8                      36976                                  3.1
# 9                      28074                                  8.4
#
#    percent_snap_benefits  percent_supplemental_security_income  \
# 0                   15.5                                   5.2
# 1                    2.4                                   0.8
# 2                    4.5                                   2.2
# 3                    2.4                                   1.5
# 4                    1.0                                   1.7
# 5                    2.3                                   2.3
# 6                    7.8                                   2.4
# 7                    7.0                                   4.2
# 8                    3.1                                   1.8
# 9                    8.3                                   3.9
#
#    percent_nonwhite
# 0              17.9
# 1              18.9
# 2              24.8
# 3              27.8
# 4              19.9
# 5              35.2
# 6              23.5
# 7              31.4
# 8              22.4
# 9              22.5

# %%
df_zip.describe()
# Out:
#                 zip  median_family_income_dollars  \
# count     38.000000                     38.000000
# mean   27573.868421                  83039.263158
# std       45.914239                  24191.827473
# min    27501.000000                  28641.000000
# 25%    27526.750000                  66182.500000
# 50%    27591.500000                  78479.000000
# 75%    27607.750000                  98594.500000
# max    27703.000000                 137193.000000
#
#        median_household_income_dollars  per_capita_income_dollars  \
# count                        38.000000                  38.000000
# mean                      67460.473684               32987.789474
# std                       18831.833970                9959.962496
# min                       27564.000000               17363.000000
# 25%                       54037.250000               25517.750000
# 50%                       60961.000000               30831.500000
# 75%                       81437.750000               40676.000000
# max                      121815.000000               59155.000000
#
#        percent_damilies_below_poverty_line  percent_snap_benefits  \
# count                            38.000000              38.000000
# mean                              8.210526               7.773684
# std                               6.149084               6.097349
# min                               2.000000               1.000000
# 25%                               4.125000               3.950000
# 50%                               6.050000               6.750000
# 75%                              10.475000              10.050000
# max                              35.900000              33.500000
#
#        percent_supplemental_security_income  percent_nonwhite
# count                             38.000000         38.000000
# mean                               3.400000         28.939474
# std                                2.826133         15.305229
# min                                0.500000          8.700000
# 25%                                1.700000         18.925000
# 50%                                2.550000         24.150000
# 75%                                3.975000         32.550000
# max                               15.400000         72.700000

# %%
#Restaurants
df_restaurants.head(10)
# Out:
#    X.objectid      hsisid                                      name  \
# 0        1001  4092017230                             SPRING CAFE 2
# 1        1002  4092040338  CAROLINA CLASSIC HOT DOGS #2 (WCID #549)
# 2        1003  4092014444                          Taco Bell #22798
# 3        1004  4092015333                          THE REMEDY DINER
# 4        1005  4092160069                   ZEBULON HOUSE (KITCHEN)
# 5        1006  4092110477                    CHARLES BUGG CAFETERIA
# 6        1007  4092016679                               BITTERSWEET
# 7        1008  4092014493                         Chick-fil-A #1573
# 8        1009  4092015519           GOLDEN CHINA CHINESE RESTAURANT
# 9        1010  4092010037                    Aubrey & Peedi`s Grill
#
#                      address1    address2         city state  postalcode  \
# 0  2900-104 SPRING FOREST RD          NaN      RALEIGH    NC  27616-1895
# 1            309 HOLLOMAN ST          NaN         APEX    NC       27502
# 2             2207 S MAIN ST          NaN  WAKE FOREST    NC       27587
# 3           137 E HARGETT ST          NaN      RALEIGH    NC       27601
# 4                551 PONY RD          NaN      ZEBULON    NC       27597
# 5              825 COOPER ST          NaN      RALEIGH    NC       27610
# 6             16 E MARTIN ST          NaN      RALEIGH    NC       27601
# 7        8901 Brier Creek PKY         NaN      RALEIGH    NC       27617
# 8           2432 SW CARY PKY          NaN         CARY    NC       27513
# 9               38 N Main St   PO BOX 302      WENDELL    NC       27591
#
#       phonenumber        restaurantopendate                facilitytype  \
# 0  (919) 977-3679  2016-05-26T00:00:00.000Z                  Restaurant
# 1             NaN  2016-07-01T00:00:00.000Z                   Pushcarts
# 2  (919) 554-4924  2005-12-05T00:00:00.000Z                  Restaurant
# 3  (919) 835-3553  2009-02-04T00:00:00.000Z                  Restaurant
# 4             NaN  2009-02-18T00:00:00.000Z  Institutional Food Service
# 5  (919) 250-4756  2009-02-26T00:00:00.000Z    Public School Lunchrooms
# 6  (919) 977-3829  2014-04-23T00:00:00.000Z                  Restaurant
# 7  (919) 293-0100  2006-01-31T00:00:00.000Z                  Restaurant
# 8  (919) 380-7891  2009-11-24T00:00:00.000Z                  Restaurant
# 9  (919) 365-5528  1991-04-25T00:00:00.000Z                  Restaurant
#
#            x          y geocodestatus
# 0 -78.591634  35.855487             M
# 1 -78.855348  35.730219             M
# 2 -78.536145  35.946695             M
# 3 -78.636895  35.777999             M
# 4 -78.332138  35.816779             M
# 5 -78.586171  35.765199             M
# 6 -78.640023  35.777143             M
# 7 -78.790500  35.901065             M
# 8 -78.820859  35.763640             M
# 9 -78.369452  35.782462             M

# %%
df_restaurants.describe()
# Out:
#         X.objectid        hsisid            x            y
# count  3324.000000  3.324000e+03  3324.000000  3324.000000
# mean   1662.500000  4.092034e+09   -74.891038    34.080422
# std     959.700474  5.460962e+04    16.844072     7.665417
# min       1.000000  4.092010e+09   -78.941986     0.000000
# 25%     831.750000  4.092015e+09   -78.775873    35.753862
# 50%    1662.500000  4.092017e+09   -78.660442    35.795728
# 75%    2493.250000  4.092021e+09   -78.587171    35.854031
# max    3324.000000  4.092300e+09     0.000000    36.051133

# %%
num_of_rest = len(df_restaurants.name.unique())
num_of_rest
# Out:
# 3178

# %%
#Number of restaurants in inspection data set
len(df_insp.hsisid.unique())
# Out:
# 3045

# %%
#We have multiple inspections for one restaurant
#Lets Clean the Data frame by removing unecessary columns such as phone
df1 = df_insp.filter(['hsisid', 'date','postalcode', 'name', 'address1','x','y', 'city','score','num_critical_previous', 'num_non_critical_previous', 'num_non_critical','num_critical','critical'], axis=1)

# %%
def standardize_zipcode(string):
    string = str(string)
    #Get only first five digits
    return int(string[:5])

# %%
df1['postalcode'] = df1['postalcode'].apply(standardize_zipcode)

# %%
#Clean Date and sort it
df1["date"] = pd.to_datetime(df1["date"])
df1 = df1.sort_values(by="date",ascending=True)

# %%
#Look for all duplicate to check if we are able to eliminate duplicates hsisid

# %%
#Based on the above we have multiple inspections for the same restaurant through a period of time since they open.
#Lets store the latest inspection only since we want to see the latest inspections scores and used those

# %%
df_with_dups = df1
df1 = df1.drop_duplicates(subset=['hsisid'], keep='last')
df1 = df1.reset_index()
#Add column total inspections and set as 1
print(df1.shape)
df1.head()
# Out:
# (3045, 15)
#    index      hsisid                      date  postalcode  \
# 0   2247  4092014995 2013-04-22 00:00:00+00:00       27619
# 1   6100  4092030240 2014-04-16 00:00:00+00:00       27502
# 2   6606  4092016447 2014-06-12 00:00:00+00:00       27612
# 3   6667  4092040288 2014-06-17 00:00:00+00:00       27601
# 4   6804  4092011458 2014-06-27 00:00:00+00:00       27513
#
#                           name              address1          x          y  \
# 0  First Citizens Bank Kitchen     4300 Six Forks RD -78.641072  35.839137
# 1    BIG MIKES BBQ (WCID #418)  3200 Centregreen Way -78.797902  35.826444
# 2                     WINE 101     5910 DURALEIGH RD -78.711997  35.858720
# 3  SAINT GEORGE II (WCID #462)      300 SALISBURY ST -78.641119  35.776330
# 4   Pure Gold Club Drink Stand    301 N HARRISON AVE -78.783887  35.788729
#
#       city  score  num_critical_previous  num_non_critical_previous  \
# 0  raleigh   97.0                    NaN                        NaN
# 1     cary   89.5                    NaN                        NaN
# 2  raleigh   99.5                    1.0                        3.0
# 3  raleigh   94.5                    0.0                        1.0
# 4     cary   93.0                    NaN                        NaN
#
#    num_non_critical  num_critical  critical
# 0                 5             6         1
# 1                 5             7         1
# 2                 0             1         1
# 3                 3             2         1
# 4                 7             5         1

# %%
#First we need to store the number of inspections and total number of 
total_insp_lst = []
for hid in df1['hsisid']:
    #get total number of inspections done
    total_insp = len(df_with_dups[df_with_dups['hsisid'] == hid ])
    total_insp_lst.append(total_insp)

# %%
df1['total_num_inspections'] = total_insp_lst

# %%
#Get total critical from previous inspections hence add all num_critical_previous and num_critical
total_critical = []
for hid in df1['hsisid']:
    #get total number of inspections done
    df_cr = df_with_dups[df_with_dups['hsisid'] == hid ]
    total = df_cr['num_critical_previous'].sum()
    total_critical.append(total)

# %%
df1['total_critical'] = total_critical
df1['total_critical'] += df1['num_critical']
#Remove previous since it doesn't indicate the right number of previous critical violations
df1 = df1.drop(columns=['num_critical_previous'])

# %%
#Get total non_critical from previous inspections hence add all num_non_critical_previous and num_non_critical
total_non_critical = []
for hid in df1['hsisid']:
    #get total number of non_critical done
    df_cr = df_with_dups[df_with_dups['hsisid'] == hid ]
    total = df_cr['num_non_critical_previous'].sum()
    total_non_critical.append(total)
len(total_non_critical)
# Out:
# 3045

# %%
df1['total_non_critical'] = total_non_critical
df1['total_non_critical'] += df1['num_non_critical']
df1 = df1.drop(columns=['num_non_critical_previous'])

# %%
#From restaurants get facility type
df1 = pd.merge(df1, df_restaurants.filter(['hsisid','facilitytype']),  on='hsisid', how='inner')
#Remove any row that is not a restaurant
print(df1.shape)
df1 = df1[df1['facilitytype'] == 'Restaurant' ]
print(df1.shape)
# Out:
# (3045, 17)
# (2053, 17)

# %%
#df1 now stores only restaurants scores, total number of inspections (critical/non critical),
#and last score, as well as address

# %%
#Clean Yelp data to join with df
print(df_yelp.shape)
print(df_yelp.columns)
df_yelp.head()
# Out:
# (3688, 31)
# Index(['id', 'name', 'is_closed', 'rating', 'review_count', 'address1',
#        'zip_code', 'latitude', 'longitude', 'price', 'phone', 'hotdogs',
#        'sandwiches', 'pizza', 'tradamerican', 'burgers', 'mexican', 'grocery',
#        'breakfast_brunch', 'coffee', 'chinese', 'italian', 'newamerican',
#        'chicken_wings', 'delis', 'bars', 'salad', 'seafood', 'bbq', 'bakeries',
#        'sushi'],
#       dtype='object')
#                                                id  \
# 0  42nd-street-oyster-bar-rdu-airport-morrisville
# 1                                 aldi-foods-cary
# 2   luciano-pizzeria-ristorante-northwest-raleigh
# 3          olive-garden-italian-restaurant-wilson
# 4                                 subway-wilson-4
#
#                                    name  is_closed  rating  review_count  \
# 0  42nd street oyster bar - rdu airport      False     2.5            23
# 1                            aldi foods      False     4.0            17
# 2           luciano pizzeria ristorante      False     5.0             2
# 3       olive garden italian restaurant      False     3.0            16
# 4                                subway      False     3.5             3
#
#                   address1  zip_code   latitude  longitude price        phone  \
# 0  2400 John Brantley Blvd     27560  35.873808 -78.790896    $$          NaN
# 1       2303 NW Maynard Rd     27519  35.802840 -78.785930     $          NaN
# 2     Crabtree Valley Mall     27612  35.839681 -78.678791     $  12102230500
# 3   3401 Raleigh Rd Pkwy W     27893  35.743170 -77.964160    $$  12522061399
# 4          4934 Raleigh Rd     27896  35.762936 -77.999428     $  12522067187
#
#    hotdogs  sandwiches  pizza  tradamerican  burgers  mexican  grocery  \
# 0    False       False  False         False    False    False    False
# 1    False       False  False         False    False    False     True
# 2    False       False  False         False    False    False    False
# 3    False       False  False         False    False    False    False
# 4     True        True  False         False    False    False    False
#
#    breakfast_brunch  coffee  chinese  italian  newamerican  chicken_wings  \
# 0              True   False    False    False         True          False
# 1             False   False    False    False        False          False
# 2             False   False    False     True        False          False
# 3             False   False    False     True        False          False
# 4             False   False    False    False        False          False
#
#    delis   bars  salad  seafood    bbq  bakeries  sushi
# 0  False  False  False     True  False     False  False
# 1  False  False  False    False  False     False  False
# 2  False  False  False    False  False     False  False
# 3  False  False   True    False  False     False  False
# 4  False  False  False    False  False     False  False

# %%
#Take out all closed restaruants
df_yelp = df_yelp[df_yelp['is_closed'] == False]

# %%
df_yelp['zip_code'] = df_yelp['zip_code'].apply(standardize_zipcode)

# %%
# yelp['coordinates'] = list(zip(yelp.latitude, yelp.longitude))
# df['x'] = df['x'].round(3)
# df['y'] = df['y'].round(3)
# df['coordinates'] = list(zip(df.y, df.x))
# df = df.drop(columns=['x','y'])
# yelp = yelp.drop(columns=['latitude', 'longitude','is_closed'])
# yelp.head()

# %%
#Get type of food
food = ['hotdogs', 'sandwiches',
       'pizza', 'tradamerican', 'burgers', 'mexican', 'grocery',
       'breakfast_brunch', 'coffee', 'chinese', 'italian', 'newamerican',
       'chicken_wings', 'delis', 'bars', 'salad', 'seafood', 'bbq', 'bakeries',
       'sushi']
type_food = []
for i, row in df_yelp.iterrows():
    type_f = ''
    for f in food:  
        if row[f] == True:
            type_f =f+' '+type_f 
    if type_f == '':
        type_food.append(np.nan)
    else:
        type_food.append(type_f[:-1])
set(type_food)
# Out:
# {'bakeries',
#  'bakeries breakfast_brunch',
#  'bakeries breakfast_brunch sandwiches',
#  'bakeries breakfast_brunch tradamerican',
#  'bakeries coffee',
#  'bakeries coffee breakfast_brunch',
#  'bakeries coffee grocery',
#  'bakeries coffee tradamerican',
#  'bakeries delis',
#  'bakeries grocery',
#  'bakeries italian sandwiches',
#  'bakeries sandwiches',
#  'bakeries seafood tradamerican',
#  'bakeries tradamerican',
#  'bars',
#  'bars breakfast_brunch',
#  'bars breakfast_brunch tradamerican',
#  'bars burgers',
#  'bars burgers sandwiches',
#  'bars burgers tradamerican',
#  'bars chicken_wings',
#  'bars chinese',
#  'bars coffee sandwiches',
#  'bars italian',
#  'bars italian tradamerican',
#  'bars mexican',
#  'bars newamerican',
#  'bars newamerican breakfast_brunch',
#  'bars newamerican italian',
#  'bars newamerican pizza',
#  'bars newamerican tradamerican',
#  'bars pizza',
#  'bars pizza sandwiches',
#  'bars sandwiches',
#  'bars tradamerican',
#  'bars tradamerican pizza',
#  'bbq',
#  'bbq bars chicken_wings',
#  'bbq burgers',
#  'bbq burgers sandwiches',
#  'bbq burgers tradamerican',
#  'bbq chicken_wings',
#  'bbq sandwiches',
#  'bbq sandwiches hotdogs',
#  'bbq seafood',
#  'bbq seafood bars',
#  'bbq seafood newamerican',
#  'bbq tradamerican',
#  'breakfast_brunch',
#  'breakfast_brunch burgers tradamerican',
#  'breakfast_brunch mexican',
#  'breakfast_brunch pizza sandwiches',
#  'breakfast_brunch sandwiches',
#  'breakfast_brunch tradamerican',
#  'breakfast_brunch tradamerican sandwiches',
#  'burgers',
#  'burgers hotdogs',
#  'burgers pizza',
#  'burgers pizza sandwiches',
#  'burgers sandwiches',
#  'burgers sandwiches hotdogs',
#  'burgers tradamerican',
#  'burgers tradamerican hotdogs',
#  'burgers tradamerican sandwiches',
#  'chicken_wings',
#  'chicken_wings burgers tradamerican',
#  'chicken_wings grocery',
#  'chicken_wings hotdogs',
#  'chicken_wings italian',
#  'chicken_wings italian pizza',
#  'chicken_wings newamerican',
#  'chicken_wings newamerican burgers',
#  'chicken_wings newamerican sandwiches',
#  'chicken_wings pizza',
#  'chicken_wings pizza sandwiches',
#  'chicken_wings tradamerican',
#  'chicken_wings tradamerican pizza',
#  'chinese',
#  'chinese grocery',
#  'chinese hotdogs',
#  'coffee',
#  'coffee breakfast_brunch',
#  'coffee breakfast_brunch sandwiches',
#  'coffee breakfast_brunch tradamerican',
#  'coffee sandwiches',
#  'delis',
#  'delis breakfast_brunch',
#  'delis breakfast_brunch sandwiches',
#  'delis burgers',
#  'delis burgers sandwiches',
#  'delis grocery',
#  'delis grocery sandwiches',
#  'delis hotdogs',
#  'delis italian pizza',
#  'delis newamerican breakfast_brunch',
#  'delis newamerican sandwiches',
#  'delis pizza',
#  'delis sandwiches',
#  'delis sandwiches hotdogs',
#  'delis tradamerican',
#  'grocery',
#  'grocery mexican',
#  'hotdogs',
#  'italian',
#  'italian breakfast_brunch',
#  'italian breakfast_brunch pizza',
#  'italian pizza',
#  'italian pizza sandwiches',
#  'italian tradamerican',
#  'italian tradamerican pizza',
#  'mexican',
#  'mexican hotdogs',
#  nan,
#  'newamerican',
#  'newamerican breakfast_brunch',
#  'newamerican breakfast_brunch burgers',
#  'newamerican breakfast_brunch sandwiches',
#  'newamerican burgers',
#  'newamerican burgers sandwiches',
#  'newamerican chinese',
#  'newamerican coffee',
#  'newamerican italian',
#  'newamerican italian mexican',
#  'newamerican mexican',
#  'newamerican pizza',
#  'newamerican pizza sandwiches',
#  'newamerican sandwiches',
#  'newamerican sandwiches hotdogs',
#  'newamerican tradamerican',
#  'newamerican tradamerican sandwiches',
#  'pizza',
#  'pizza hotdogs',
#  'pizza sandwiches',
#  'salad',
#  'salad breakfast_brunch',
#  'salad breakfast_brunch sandwiches',
#  'salad breakfast_brunch tradamerican',
#  'salad burgers',
#  'salad burgers pizza',
#  'salad burgers sandwiches',
#  'salad burgers tradamerican',
#  'salad chicken_wings hotdogs',
#  'salad chicken_wings pizza',
#  'salad chicken_wings sandwiches',
#  'salad coffee sandwiches',
#  'salad delis sandwiches',
#  'salad hotdogs',
#  'salad italian',
#  'salad italian pizza',
#  'salad newamerican',
#  'salad newamerican burgers',
#  'salad newamerican pizza',
#  'salad newamerican sandwiches',
#  'salad pizza',
#  'salad pizza hotdogs',
#  'salad pizza sandwiches',
#  'salad sandwiches',
#  'salad tradamerican',
#  'salad tradamerican sandwiches',
#  'sandwiches',
#  'sandwiches hotdogs',
#  'seafood',
#  'seafood bars',
#  'seafood bars mexican',
#  'seafood chicken_wings sandwiches',
#  'seafood chinese',
#  'seafood italian',
#  'seafood italian breakfast_brunch',
#  'seafood mexican',
#  'seafood newamerican',
#  'seafood newamerican breakfast_brunch',
#  'seafood newamerican pizza',
#  'seafood newamerican sandwiches',
#  'seafood sandwiches',
#  'seafood tradamerican',
#  'sushi',
#  'sushi bbq',
#  'sushi burgers',
#  'sushi chinese',
#  'sushi pizza',
#  'sushi seafood',
#  'tradamerican',
#  'tradamerican hotdogs',
#  'tradamerican pizza',
#  'tradamerican pizza sandwiches',
#  'tradamerican sandwiches'}

# %%
df_yelp['type_foods'] = type_food
df_yelp
# Out:
#                                                      id  \
# 0        42nd-street-oyster-bar-rdu-airport-morrisville
# 1                                       aldi-foods-cary
# 2         luciano-pizzeria-ristorante-northwest-raleigh
# 3                olive-garden-italian-restaurant-wilson
# 4                                       subway-wilson-4
# 5                        trent-restaurant-pollocksville
# 6                                  bailey-cafe-bailey-2
# 7                                    bojangles-wilson-2
# 8                el-tapatio-mexican-restaurant-wilson-2
# 9                                 best-n-burgers-wilson
# 10                   san-jose-mexican-restaurant-wilson
# 11                           walmart-supercenter-wilson
# 12                     mcqueens-interiors-morehead-city
# 13                                            bp-wilson
# 14                                sonic-drive-in-wilson
# 15        olive-garden-italian-restaurant-rocky-mount-2
# 16    cracker-barrel-old-country-store-and-restauran...
# 17           gardners-barbecue-restaurant-rocky-mount-5
# 18                         la-perla-tapatia-rocky-mount
# 19           san-jose-mexican-restaurant-roanoke-rapids
# 20             seven-springs-restaurant-seven-springs-2
# 21                 la-casetta-italian-restaurant-bethel
# 22                natural-health-strategies-chapel-hill
# 23                        claudia-zamora-fayetteville-2
# 24                        one-vision-studios-greensboro
# 25            la-fiesta-restaurante-mexicano-burlington
# 26                             taqueria-guerrero-graham
# 27                      oak-city-fish-and-chips-raleigh
# 28                         clean-air-lawn-care-durham-2
# 29                       table-16-restaurant-greensboro
# ...                                                 ...
# 3658                                     milows-raleigh
# 3659                                      cruizers-cary
# 3660                                         exxon-cary
# 3661                     longleaf-dentistry-wake-forest
# 3662                               serene-smiles-cary-2
# 3663              triangle-family-dentistry-morrisville
# 3664                                dog-stylists-durham
# 3665                         life-time-athletic-raleigh
# 3666                       wakemed-apex-healthplex-apex
# 3667                          rex-healthcare-raleigh-10
# 3668          dharani-express-indian-restaurant-raleigh
# 3669                            sangam-mart-morrisville
# 3670  weymouth-center-for-the-arts-and-humanities-so...
# 3671                              nc-state-fair-raleigh
# 3672           skye-tower-restaurant-and-lounge-raleigh
# 3673                    taqueria-la-esquina-morrisville
# 3674                    imax-theatre-at-marbles-raleigh
# 3675                          black-creek-greenway-cary
# 3676                           jumpin-beans-wake-forest
# 3677                   elmcroft-of-northridge-raleigh-2
# 3678        crab-stop-the-northside-fish-market-raleigh
# 3679                         south-wake-storage-raleigh
# 3680                                 ajs-food-mart-apex
# 3681                            han-dee-hugos-raleigh-6
# 3682                                city-market-raleigh
# 3683                      carter-finley-stadium-raleigh
# 3684                     raleigh-little-theatre-raleigh
# 3685             sky-zone-trampoline-park-durham-durham
# 3686                     highgrove-estate-fuquay-varina
# 3687                    banfield-pet-hospital-raleigh-6
#
#                                                name  is_closed  rating  \
# 0              42nd street oyster bar - rdu airport      False     2.5
# 1                                        aldi foods      False     4.0
# 2                       luciano pizzeria ristorante      False     5.0
# 3                   olive garden italian restaurant      False     3.0
# 4                                            subway      False     3.5
# 5                                  trent restaurant      False     5.0
# 6                                       bailey cafe      False     4.5
# 7                                         bojangles      False     3.5
# 8                     el tapatio mexican restaurant      False     3.5
# 9                                    best-n-burgers      False     4.5
# 10                      san jose mexican restaurant      False     3.5
# 11                              walmart supercenter      False     3.5
# 12                              mcqueen's interiors      False     5.0
# 13                                               bp      False     5.0
# 14                                   sonic drive-in      False     3.5
# 15                  olive garden italian restaurant      False     3.0
# 16    cracker barrel old country store & restaurant      False     3.0
# 17                    gardner's barbecue restaurant      False     3.0
# 18                                 la perla tapatia      False     4.0
# 19                      san jose mexican restaurant      False     4.5
# 20                         seven springs restaurant      False     5.0
# 21                    la casetta italian restaurant      False     4.5
# 22                        natural health strategies      False     5.0
# 23                                   claudia zamora      False     5.0
# 24                               one vision studios      False     5.0
# 25                   la fiesta restaurante mexicano      False     4.0
# 26                                taqueria guerrero      False     3.5
# 27                            oak city fish & chips      False     4.0
# 28                              clean air lawn care      False     5.0
# 29                              table 16 restaurant      False     4.0
# ...                                             ...        ...     ...
# 3658                                        milow's      False     5.0
# 3659                                       cruizers      False     1.0
# 3660                                          exxon      False     3.0
# 3661                             longleaf dentistry      False     5.0
# 3662                                  serene smiles      False     5.0
# 3663                      triangle family dentistry      False     4.0
# 3664                              dog stylists inc.      False     5.0
# 3665                             life time athletic      False     4.0
# 3666                        wakemed apex healthplex      False     3.0
# 3667                                 rex healthcare      False     3.0
# 3668              dharani express indian restaurant      False     5.0
# 3669                                    sangam mart      False     4.0
# 3670      weymouth center for the arts & humanities      False     5.0
# 3671                                  nc state fair      False     4.0
# 3672                 skye tower restaurant & lounge      False     4.0
# 3673                            taqueria la esquina      False     3.5
# 3674                        imax theatre at marbles      False     4.0
# 3675                           black creek greenway      False     5.0
# 3676                                  jumpin' beans      False     2.0
# 3677                         elmcroft of northridge      False     2.0
# 3678            crab stop the northside fish market      False     4.0
# 3679                             south wake storage      False     5.0
# 3680                                 aj's food mart      False     4.0
# 3681                                 han-dee hugo's      False     4.0
# 3682                                    city market      False     3.0
# 3683                          carter-finley stadium      False     3.5
# 3684                         raleigh little theatre      False     3.5
# 3685               sky zone trampoline park, durham      False     4.0
# 3686                               highgrove estate      False     3.5
# 3687                          banfield pet hospital      False     2.0
#
#       review_count                  address1  zip_code   latitude  longitude  \
# 0               23   2400 John Brantley Blvd     27560  35.873808 -78.790896
# 1               17        2303 NW Maynard Rd     27519  35.802840 -78.785930
# 2                2      Crabtree Valley Mall     27612  35.839681 -78.678791
# 3               16    3401 Raleigh Rd Pkwy W     27893  35.743170 -77.964160
# 4                3           4934 Raleigh Rd     27896  35.762936 -77.999428
# 5                5               129 Main St     28573  35.007890 -77.219700
# 6               10          12544 Hanover St     27807  35.778950 -78.118400
# 7               21    5033 Raleigh Rd Pkwy W     27896  35.763565 -78.008926
# 8               15  2921 Raleigh Road Pkwy W     27896  35.738403 -77.956024
# 9               69             4916 Hayes Pl     27893  35.762290 -78.007200
# 10              22    1700 Raleigh Rd Pkwy W     27896  35.736134 -77.949745
# 11               3    2500 Forest Hills Rd W     27893  35.733920 -77.949590
# 12               1          4426 Arendell St     28557  34.730420 -76.777380
# 13               1         2825 US Hwy 301 S     27893  35.692385 -77.943700
# 14               3    2401 Forest Hills Rd W     27893  35.732780 -77.952700
# 15              12      1140 N Wesleyan Blvd     27804  35.972691 -77.805862
# 16              13         238 Enterprise Dr     27804  35.974949 -77.844521
# 17              11           3651 Sunset Ave     27804  35.963782 -77.853216
# 18              20        126 S Winstead Ave     27804  35.962441 -77.849572
# 19              46          309 Premier Blvd     27870  36.425014 -77.633066
# 20               4               400 Main St     28578  35.226116 -77.846352
# 21              10            7434 N Main St     27812  35.808788 -77.372749
# 22               3        50101 Governors Dr     27517  35.854662 -79.024967
# 23               5          1705 Calista Cir     28304  35.017716 -78.988295
# 24               1       2100 E Wendover Ave     27405  36.086896 -79.757725
# 25              42          1824 S Church St     27215  36.082570 -79.460190
# 26              10             921 S Main St     27253  36.051880 -79.399757
# 27              24       511 S Wilmington St     27601  35.773710 -78.638180
# 28               3                       NaN     27253  36.431580 -80.366960
# 29             111              600 S Elm St     27406  36.065906 -79.791045
# ...            ...                       ...       ...        ...        ...
# 3658             1        8320 Litchford Rd.     27615  35.892208 -78.599390
# 3659             1        1205 NE Maynard Rd     27513  35.794690 -78.762911
# 3660             1        1205 NE Maynard Rd     27513  35.794690 -78.762910
# 3661             5     1440 Brogden Woods Dr     27587  35.989501 -78.694581
# 3662             2    600 Gathering Park Cir     27519  35.821340 -78.855780
# 3663            39             3607 Davis Dr     27560  35.821820 -78.849410
# 3664            14   3207 Old Chapel Hill Rd     27707  35.966100 -78.945460
# 3665            21   8515 Falls of Neuse Rd.     27615  35.897492 -78.616116
# 3666             8        120 Healthplex Way     27502  35.739208 -78.867561
# 3667             9       4420 Lake Boone Trl     27607  35.815620 -78.703995
# 3668             3       3281 Avent Ferry Rd     27606  35.767800 -78.695484
# 3669             5              10300 Hwy 54     27560  35.872600 -78.851010
# 3670             1     555 E Connecticut Ave     28387  35.170370 -79.382670
# 3671            89        1025 Blue Ridge Rd     27607  35.795670 -78.712280
# 3672             3       320 Hillsborough St     27603  35.780680 -78.643660
# 3673             3      10500 Chapel Hill Rd     27560  35.841009 -78.831535
# 3674            58          201 E Hargett St     27601  35.778956 -78.636095
# 3675             1      Black Creek Greenway     27513  35.839011 -78.781868
# 3676            11            1839 S Main St     27587  35.951082 -78.526325
# 3677             2           600 Newton Road     27615  35.878380 -78.637130
# 3678             1   2275 New Hope Church Rd     27604  35.835186 -78.599472
# 3679             2    9300 Fayetteville Road     27603  35.648890 -78.709380
# 3680             1           6204 Ten-Ten Rd     27502  35.676670 -78.736671
# 3681             1         3220 Duraleigh Rd     27612  35.824989 -78.707970
# 3682             2           214 E Martin St     27601  35.776502 -78.635986
# 3683            23           4600 Trinity Rd     27607  35.801217 -78.719568
# 3684            24              301 Pogue St     27607  35.791430 -78.668820
# 3685            12             1720 Guess Rd     27701  36.020901 -78.914003
# 3686             4            1613 S Main St     27526  35.557201 -78.807747
# 3687             5         6300 Creedmoor Rd     27612  35.871144 -78.679313
#
#             price                                            phone  hotdogs  \
# 0              $$                                              NaN    False
# 1               $                                              NaN    False
# 2               $                                      12102230500    False
# 3              $$                                      12522061399    False
# 4               $                                      12522067187     True
# 5             $$$                                      12522247141    False
# 6               $                                      12522352767    False
# 7               $                                      12522370026     True
# 8              $$                                      12522370687    False
# 9               $                                      12522372555    False
# 10              $                                      12522377749    False
# 11              $                                      12522439300    False
# 12            NaN                                      12522473175    False
# 13            NaN                                      12522919777    False
# 14              $                                      12522930599     True
# 15             $$                                      12524421329    False
# 16              $                                      12524430679    False
# 17              $                                      12524433996    False
# 18             $$                                      12524510808    False
# 19             $$                                      12525375711    False
# 20              $                                      12525691521    False
# 21             $$                                      12528256699    False
# 22            NaN                                      13018010462    False
# 23            NaN                                      13057473004    False
# 24            NaN                                      13342184143    False
# 25             $$                                      13362270144    False
# 26              $                                      13362277133    False
# 27             $$                                      13362532219    False
# 28            NaN                                      13362618066    False
# 29            $$$                                      13362798525    False
# ...           ...                                              ...      ...
# 3658  19199869521                        comfortfood,chicken_wings    False
# 3659  19194660308                                      convenience    False
# 3660  19194660360                      convenience,servicestations    False
# 3661  19198884887                                 generaldentistry    False
# 3662  19194607025                generaldentistry,cosmeticdentists    False
# 3663  19194692122  generaldentistry,cosmeticdentists,periodontists    False
# 3664  19194899364                                          groomer    False
# 3665  19195827000                gyms,swimmingpools,healthtrainers    False
# 3666  19193870228                                        hospitals    False
# 3667  19197843100                            hospitals,urgent_care    False
# 3668  19198217991                                           indpak    False
# 3669            $                                      intlgrocery    False
# 3670  19106926261                                        landmarks    False
# 3671  19198217400                                      localflavor    False
# 3672  19198320501            lounges,breakfast_brunch,tradamerican    False
# 3673  19196000870                                          mexican    False
# 3674  19198824629                                    movietheaters    False
# 3675          NaN                                            parks    False
# 3676  19195214445                   playgrounds,arts,eventplanning    False
# 3677  19198484906                                 retirement_homes    False
# 3678  19198500891                                   seafoodmarkets    False
# 3679  19194362246                                      selfstorage    False
# 3680  19197793900                                  servicestations    False
# 3681  19197822594                          servicestations,carwash    False
# 3682            $                                  shoppingcenters    False
# 3683  19198344000                                   stadiumsarenas    False
# 3684  19198213111                                          theater    False
# 3685  19194250800                                       trampoline    False
# 3686  19195526154                                           venues    False
# 3687  19198473548                                              vet    False
#
#       sandwiches  pizza  tradamerican  burgers  mexican  grocery  \
# 0          False  False         False    False    False    False
# 1          False  False         False    False    False     True
# 2          False  False         False    False    False    False
# 3          False  False         False    False    False    False
# 4           True  False         False    False    False    False
# 5          False  False          True    False    False    False
# 6          False  False          True    False    False    False
# 7          False  False         False    False    False    False
# 8          False  False         False    False     True    False
# 9          False  False         False     True    False    False
# 10         False  False         False    False     True    False
# 11         False  False         False    False    False     True
# 12         False  False         False    False    False    False
# 13         False  False         False    False    False    False
# 14         False  False         False    False    False    False
# 15         False  False         False    False    False    False
# 16         False  False         False    False    False    False
# 17         False  False          True    False    False    False
# 18         False  False         False    False     True    False
# 19         False  False         False    False     True    False
# 20         False  False         False    False    False    False
# 21         False  False         False    False    False    False
# 22         False  False         False    False    False    False
# 23         False  False         False    False    False    False
# 24         False  False         False    False    False    False
# 25         False  False         False    False     True    False
# 26         False  False         False    False     True    False
# 27         False  False         False    False    False    False
# 28         False  False         False    False    False    False
# 29          True  False         False    False    False    False
# ...          ...    ...           ...      ...      ...      ...
# 3658       False  False         False    False    False    False
# 3659       False  False         False    False    False    False
# 3660       False  False         False    False    False    False
# 3661       False  False         False    False    False    False
# 3662       False  False         False    False    False    False
# 3663       False  False         False    False    False    False
# 3664       False  False         False    False    False    False
# 3665       False  False         False    False    False    False
# 3666       False  False         False    False    False    False
# 3667       False  False         False    False    False    False
# 3668       False  False         False    False    False    False
# 3669       False  False         False    False    False    False
# 3670       False  False         False    False    False    False
# 3671       False  False         False    False    False    False
# 3672       False  False          True    False    False    False
# 3673       False  False         False    False     True    False
# 3674       False  False         False    False    False    False
# 3675       False  False         False    False    False    False
# 3676       False  False         False    False    False    False
# 3677       False  False         False    False    False    False
# 3678       False  False         False    False    False    False
# 3679       False  False         False    False    False    False
# 3680       False  False         False    False    False    False
# 3681       False  False         False    False    False    False
# 3682       False  False         False    False    False    False
# 3683       False  False         False    False    False    False
# 3684       False  False         False    False    False    False
# 3685       False  False         False    False    False    False
# 3686       False  False         False    False    False    False
# 3687       False  False         False    False    False    False
#
#       breakfast_brunch  coffee  chinese  italian  newamerican  chicken_wings  \
# 0                 True   False    False    False         True          False
# 1                False   False    False    False        False          False
# 2                False   False    False     True        False          False
# 3                False   False    False     True        False          False
# 4                False   False    False    False        False          False
# 5                False   False    False    False        False          False
# 6                False   False    False    False        False          False
# 7                False   False    False    False        False          False
# 8                False   False    False    False        False          False
# 9                False   False    False    False        False          False
# 10               False   False    False    False        False          False
# 11               False   False    False    False        False          False
# 12               False   False    False    False        False          False
# 13               False   False    False    False        False          False
# 14               False   False    False    False        False          False
# 15               False   False    False     True        False          False
# 16                True   False    False    False         True          False
# 17               False   False    False    False        False          False
# 18               False   False    False    False        False          False
# 19               False   False    False    False        False          False
# 20               False   False    False    False        False          False
# 21               False   False    False     True        False          False
# 22               False   False    False    False        False          False
# 23               False   False    False    False        False          False
# 24               False   False    False    False        False          False
# 25               False   False    False    False        False          False
# 26               False   False    False    False        False          False
# 27               False   False    False    False        False          False
# 28               False   False    False    False        False          False
# 29               False   False    False    False         True          False
# ...                ...     ...      ...      ...          ...            ...
# 3658             False   False    False    False        False           True
# 3659             False   False    False    False        False          False
# 3660             False   False    False    False        False          False
# 3661             False   False    False    False        False          False
# 3662             False   False    False    False        False          False
# 3663             False   False    False    False        False          False
# 3664             False   False    False    False        False          False
# 3665             False   False    False    False        False          False
# 3666             False   False    False    False        False          False
# 3667             False   False    False    False        False          False
# 3668             False   False    False    False        False          False
# 3669             False   False    False    False        False          False
# 3670             False   False    False    False        False          False
# 3671             False   False    False    False        False          False
# 3672              True   False    False    False        False          False
# 3673             False   False    False    False        False          False
# 3674             False   False    False    False        False          False
# 3675             False   False    False    False        False          False
# 3676             False   False    False    False        False          False
# 3677             False   False    False    False        False          False
# 3678             False   False    False    False        False          False
# 3679             False   False    False    False        False          False
# 3680             False   False    False    False        False          False
# 3681             False   False    False    False        False          False
# 3682             False   False    False    False        False          False
# 3683             False   False    False    False        False          False
# 3684             False   False    False    False        False          False
# 3685             False   False    False    False        False          False
# 3686             False   False    False    False        False          False
# 3687             False   False    False    False        False          False
#
#       delis   bars  salad  seafood    bbq  bakeries  sushi  \
# 0     False  False  False     True  False     False  False
# 1     False  False  False    False  False     False  False
# 2     False  False  False    False  False     False  False
# 3     False  False   True    False  False     False  False
# 4     False  False  False    False  False     False  False
# 5     False  False  False    False  False     False  False
# 6     False  False  False    False  False     False  False
# 7     False  False  False    False  False     False  False
# 8     False  False  False    False  False     False  False
# 9     False  False  False    False  False     False  False
# 10    False  False  False    False  False     False  False
# 11    False  False  False    False  False     False  False
# 12    False  False  False    False  False     False  False
# 13    False  False  False    False  False     False  False
# 14    False  False  False    False  False     False  False
# 15    False  False   True    False  False     False  False
# 16    False  False  False    False  False     False  False
# 17    False  False  False    False   True     False  False
# 18    False  False  False    False  False     False  False
# 19    False  False  False    False  False     False  False
# 20    False  False  False    False  False     False  False
# 21    False  False  False    False  False     False  False
# 22    False  False  False    False  False     False  False
# 23    False  False  False    False  False     False  False
# 24    False  False  False    False  False     False  False
# 25    False  False  False    False  False     False  False
# 26    False  False  False    False  False     False  False
# 27    False  False  False    False  False     False  False
# 28    False  False  False    False  False     False  False
# 29    False  False  False    False  False     False  False
# ...     ...    ...    ...      ...    ...       ...    ...
# 3658  False  False  False    False  False     False  False
# 3659  False  False  False    False  False     False  False
# 3660  False  False  False    False  False     False  False
# 3661  False  False  False    False  False     False  False
# 3662  False  False  False    False  False     False  False
# 3663  False  False  False    False  False     False  False
# 3664  False  False  False    False  False     False  False
# 3665  False  False  False    False  False     False  False
# 3666  False  False  False    False  False     False  False
# 3667  False  False  False    False  False     False  False
# 3668  False  False  False    False  False     False  False
# 3669  False  False  False    False  False     False  False
# 3670  False  False  False    False  False     False  False
# 3671  False  False  False    False  False     False  False
# 3672  False  False  False    False  False     False  False
# 3673  False  False  False    False  False     False  False
# 3674  False  False  False    False  False     False  False
# 3675  False  False  False    False  False     False  False
# 3676  False  False  False    False  False     False  False
# 3677  False  False  False    False  False     False  False
# 3678  False  False  False    False  False     False  False
# 3679  False  False  False    False  False     False  False
# 3680  False  False  False    False  False     False  False
# 3681  False  False  False    False  False     False  False
# 3682  False  False  False    False  False     False  False
# 3683  False  False  False    False  False     False  False
# 3684  False  False  False    False  False     False  False
# 3685  False  False  False    False  False     False  False
# 3686  False  False  False    False  False     False  False
# 3687  False  False  False    False  False     False  False
#
#                                 type_foods
# 0     seafood newamerican breakfast_brunch
# 1                                  grocery
# 2                                  italian
# 3                            salad italian
# 4                       sandwiches hotdogs
# 5                             tradamerican
# 6                             tradamerican
# 7                                  hotdogs
# 8                                  mexican
# 9                                  burgers
# 10                                 mexican
# 11                                 grocery
# 12                                     NaN
# 13                                     NaN
# 14                                 hotdogs
# 15                           salad italian
# 16            newamerican breakfast_brunch
# 17                        bbq tradamerican
# 18                                 mexican
# 19                                 mexican
# 20                                     NaN
# 21                                 italian
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                 mexican
# 26                                 mexican
# 27                                     NaN
# 28                                     NaN
# 29                  newamerican sandwiches
# ...                                    ...
# 3658                         chicken_wings
# 3659                                   NaN
# 3660                                   NaN
# 3661                                   NaN
# 3662                                   NaN
# 3663                                   NaN
# 3664                                   NaN
# 3665                                   NaN
# 3666                                   NaN
# 3667                                   NaN
# 3668                                   NaN
# 3669                                   NaN
# 3670                                   NaN
# 3671                                   NaN
# 3672         breakfast_brunch tradamerican
# 3673                               mexican
# 3674                                   NaN
# 3675                                   NaN
# 3676                                   NaN
# 3677                                   NaN
# 3678                                   NaN
# 3679                                   NaN
# 3680                                   NaN
# 3681                                   NaN
# 3682                                   NaN
# 3683                                   NaN
# 3684                                   NaN
# 3685                                   NaN
# 3686                                   NaN
# 3687                                   NaN
#
# [3685 rows x 32 columns]

# %%
# df['address1'] = df['address1'].str.upper()
# yelp['address1'] = yelp['address1'].str.upper()

# %%
# df['name'] = df['name'].str.upper()
# yelp['name'] = yelp['name'].str.upper()

# %%
df_zip['zip'] = df_zip['zip'].apply(standardize_zipcode)

# %%
df_yelp=df_yelp.rename(columns = {'zip_code':'zip'})

# %%
df1=df1.rename(columns = {'postalcode':'zip'})

# %%
df_income_yelp = pd.merge(df_yelp,df_zip,  on=['zip'], how='inner')
df_income_insp = pd.merge(df1,df_zip,  on=['zip'], how='inner')

# %%
df_income_yelp = df_income_yelp.drop(columns=['is_closed','phone'])
df_income_yelp.head()
# Out:
#                                                   id  \
# 0     42nd-street-oyster-bar-rdu-airport-morrisville
# 1                  leaffilter-of-raleigh-morrisville
# 2  days-inn-raleigh-airport-research-triangle-par...
# 3                         delta-airlines-morrisville
# 4  microtel-inn-and-suites-by-wyndham-raleigh-dur...
#
#                                                 name  rating  review_count  \
# 0               42nd street oyster bar - rdu airport     2.5            23
# 1                              leaffilter of raleigh     3.0             2
# 2    days inn raleigh-airport-research triangle park     2.5            11
# 3                                     delta airlines     3.0            17
# 4  microtel inn & suites by wyndham raleigh durha...     2.5            20
#
#                   address1    zip   latitude  longitude price  hotdogs  \
# 0  2400 John Brantley Blvd  27560  35.873808 -78.790896    $$    False
# 1         175 Southport Dr  27560  35.796284 -78.803093   NaN    False
# 2        1000 Airport Blvd  27560  35.858090 -78.819540     $    False
# 3       John Brantley Blvd  27560  35.878308 -78.791346   NaN    False
# 4   104 Factory Shops Road  27560  35.861544 -78.818310     $    False
#
#    sandwiches  pizza  tradamerican  burgers  mexican  grocery  \
# 0       False  False         False    False    False    False
# 1       False  False         False    False    False    False
# 2       False  False         False    False    False    False
# 3       False  False         False    False    False    False
# 4       False  False         False    False    False    False
#
#    breakfast_brunch  coffee  chinese  italian  newamerican  chicken_wings  \
# 0              True   False    False    False         True          False
# 1             False   False    False    False        False          False
# 2             False   False    False    False        False          False
# 3             False   False    False    False        False          False
# 4             False   False    False    False        False          False
#
#    delis   bars  salad  seafood    bbq  bakeries  sushi  \
# 0  False  False  False     True  False     False  False
# 1  False  False  False    False  False     False  False
# 2  False  False  False    False  False     False  False
# 3  False  False  False    False  False     False  False
# 4  False  False  False    False  False     False  False
#
#                              type_foods  median_family_income_dollars  \
# 0  seafood newamerican breakfast_brunch                         97917
# 1                                   NaN                         97917
# 2                                   NaN                         97917
# 3                                   NaN                         97917
# 4                                   NaN                         97917
#
#    median_household_income_dollars  per_capita_income_dollars  \
# 0                            80324                      38830
# 1                            80324                      38830
# 2                            80324                      38830
# 3                            80324                      38830
# 4                            80324                      38830
#
#    percent_damilies_below_poverty_line  percent_snap_benefits  \
# 0                                  3.6                    3.9
# 1                                  3.6                    3.9
# 2                                  3.6                    3.9
# 3                                  3.6                    3.9
# 4                                  3.6                    3.9
#
#    percent_supplemental_security_income  percent_nonwhite
# 0                                   1.1              53.3
# 1                                   1.1              53.3
# 2                                   1.1              53.3
# 3                                   1.1              53.3
# 4                                   1.1              53.3

# %%
df_income_insp.head()
# Out:
#    index      hsisid                      date    zip                   name  \
# 0   6606  4092016447 2014-06-12 00:00:00+00:00  27612               WINE 101
# 1  13083  4092016290 2015-10-21 00:00:00+00:00  27612       MCDONALDS #15717
# 2  13715  4092010138 2015-12-03 00:00:00+00:00  27612             Char-Grill
# 3  14155  4092015324 2016-01-07 00:00:00+00:00  27612      MONKEY JOE`S #168
# 4  14228  4092011497 2016-01-12 00:00:00+00:00  27612  Barnes And Noble Cafe
#
#                address1          x          y     city  score  \
# 0     5910 DURALEIGH RD -78.711997  35.858720  raleigh   99.5
# 1    4121 BLUE RIDGE RD -78.676019  35.836296  raleigh   94.0
# 2  3211 EDWARDS MILL RD -78.705805  35.825553  raleigh   94.0
# 3     6220 GLENWOOD AVE -78.701367  35.857959  raleigh   94.0
# 4     4325 GLENWOOD AVE -78.681845  35.841838  raleigh   94.5
#
#    num_non_critical  num_critical  critical  total_num_inspections  \
# 0                 0             1         1                      2
# 1                12             7         1                      4
# 2                10             4         1                      5
# 3                 2             2         1                      6
# 4                12             5         1                      5
#
#    total_critical  total_non_critical facilitytype  \
# 0             2.0                 3.0   Restaurant
# 1            16.0                29.0   Restaurant
# 2            10.0                22.0   Restaurant
# 3            11.0                17.0   Restaurant
# 4            16.0                41.0   Restaurant
#
#    median_family_income_dollars  median_household_income_dollars  \
# 0                         98452                            68864
# 1                         98452                            68864
# 2                         98452                            68864
# 3                         98452                            68864
# 4                         98452                            68864
#
#    per_capita_income_dollars  percent_damilies_below_poverty_line  \
# 0                      45080                                  5.5
# 1                      45080                                  5.5
# 2                      45080                                  5.5
# 3                      45080                                  5.5
# 4                      45080                                  5.5
#
#    percent_snap_benefits  percent_supplemental_security_income  \
# 0                    4.8                                   1.3
# 1                    4.8                                   1.3
# 2                    4.8                                   1.3
# 3                    4.8                                   1.3
# 4                    4.8                                   1.3
#
#    percent_nonwhite
# 0              23.2
# 1              23.2
# 2              23.2
# 3              23.2
# 4              23.2

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %%
data1 = df_income_insp.filter(['zip','median_family_income_dollars',
                               'per_capita_income_dollars','total_num_inspections',
                              'total_critical','score'])

# %%
fig1 = pd.plotting.scatter_matrix(data1, figsize = (22,22))

# %%
data2 = df_income_yelp.filter(['zip','median_family_income_dollars',
                               'median_household_income_dollars',
                               'per_capita_income_dollars','total_num_inspections',
                              'rating','review_count'])

# %%
fig2 = pd.plotting.scatter_matrix(data2, figsize = (22,22))

# %%
data3 = pd.merge(data1,data2.filter(['zip','rating']), on='zip', how='inner')

# %%
fig3 = pd.plotting.scatter_matrix(data3, figsize = (22,22))

# %%
f2= sns.distplot((df_1['score']), bins=25, kde=False)

# %%
f3 = sns.distplot((df_1['rating'].loc[df_1['score']<94]), bins=25, kde=False)

# %%
fig = pd.plotting.scatter_matrix(df_1.filter(['rating','total_critical','total_non_critical','score']), figsize = (8,6))

# %%
df_1['facilitytype'].unique()

# %%
f4 = sns.distplot((df_1['score'].loc[df_1['facilitytype']=='Restaurant']), bins=25, kde=False)

# %%
f4 = sns.distplot((df_1['rating'].loc[df_1['facilitytype']=='Food Stand']), bins=25, kde=False)

# %%
f4 = sns.distplot((df_1['score'].loc[df_1['facilitytype']=='Food Stand']), bins=25, kde=False)

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# This information that I will be looking for is public hence I will have permission to use it since it is our right to know the grade of each restaurant’s food inspection. There are no privacy concerns regarding the datasets since it is public information. The data could have potential biases by the inspectors, as mention in the reference article (3), inspectors can be biased on how many violations they mark in a restaurant and this can affect the dataset. This could be an ethical problem since an inspector can affect a restaurant’s reputation, therefore we expect that each inspector’s review is not biased. For the issue of finding inspector biases what can be done is to assign two inspectors to do the same reviews of restaurants and look at both data sets. This will allow us to see if there are any biases in the process of an inspector. In case we see a discrepancy between two inspectors we can ask a third inspector to review the particular restaurant. This will only be able if the Department of Environmental Health of San Diego works closely with us. But this will help prevent collection bias in our process.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*
